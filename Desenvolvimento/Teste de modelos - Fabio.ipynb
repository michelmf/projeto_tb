# %% [markdown]
# # Análise dos dados - Trabalho Fabio
#
# Análise dos dados e testes de independência assumindo as features utilizadas no trabalho do Fábio, para averiguação.

# %% [markdown]
# ### Análise inicial dos dados

# %%
# Manipulação dos dados
import numpy  as np
import scipy  as sp
import pandas as pd

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn           as sns
# %matplotlib inline

# %%
# Carregando os dados
data = pd.read_csv('../Dados/labels.csv',low_memory=False)

# %%
# Visualização da tabela
data.head(5)
# Out:
#   TB_desfecho_final_Dri Tbafranio Obs_desfechoTB_Dri_Dani Data_inclusão  Nome  \
# 0                    TB       SIM                     NaN      3/abr/08   NaN
# 1                    TB       SIM                     NaN      3/out/06   NaN
# 2                    TB       SIM                     NaN     21/jun/07   NaN
# 3                    TB       SIM                     NaN     30/set/09   NaN
# 4                    TB       SIM                     NaN     19/jun/09   NaN
#
#   Desfecho_tuberculose_lista_Mauro Desfecho_TB_162_Revisão_ADRIANA  \
# 0                                9                              TB
# 1                               TB                              TB
# 2                               TB                              TB
# 3                               TB                              TB
# 4                               TB                          #NULL!
#
#   Observaça0_desfecho_TB Resultado_BAAR_1 Resultado_BAAR_2  \
# 0       TB PROBABILIDADE         Negativo         Negativo
# 1                    NaN         Negativo         Negativo
# 2          TB CONFIRMADA         Negativo         Negativo
# 3                    NaN         Negativo         Negativo
# 4                    NaN         Negativo         Negativo
#
#            ...          Perdeu_aula_hoje_CA Deixou_de_ganhar_dinheiro_hoje_CA  \
# 0          ...                          IGN                               IGN
# 1          ...                          IGN                               IGN
# 2          ...                          IGN                               IGN
# 3          ...                          IGN                               IGN
# 4          ...                          Não                               Não
#
#   Quanto_deixou_ganhar_CA Caso_acompanhado_quem_custeou_tudo_CA  \
# 0                Ignorado                                   IGN
# 1                Ignorado                                   IGN
# 2                Ignorado                                   IGN
# 3                Ignorado                                   IGN
# 4         "Não se aplica"                         não se aplica
#
#         Valor_CA  Avaliador_custo_CA Data_avaliação_custo_CA  \
# 0       ignorado                   9                9/set/99
# 1       ignorado                   9                9/set/99
# 2       ignorado                   9                9/set/99
# 3       ignorado                   9                9/set/99
# 4  não se aplica  Marcia  dos Santos               19/jun/09
#
#   Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER) ANO  de inclusao  \
# 0                                           Selected                  2008
# 1                                           Selected                  2006
# 2                                           Selected                  2007
# 3                                           Selected                  2009
# 4                                       Not Selected                  2009
#
#   Novocriteriotbafranio
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 281 columns]

# %%
# De acordo com o trabaho do Fabio, as seguintes features foram selecionadas por especialistas

features_selecionadas = ['Doença_pumonar_difusa','Transplante','Silicose','Tto_anterior_TB_INH','Tto_anterior_TB_RIF',
                         'Quimio_prévia', 'Quimio_INH', 'Quimio_RIF', 'Desfecho_quimio', 'HIV', 'Hepatopatia', 'Uso_corticoide',
                         'Neo_maligna', 'Asma', 'TTO_anterior_TB_triagem_enfermeiro','Cicatriz_BCG', 'Tto_anterior_TB_avaliação_médica',
                         'Comorbidades','Idade','Sexo','Raça','Estado_civil','Tem_companheiro','Tosse','Semanas_tosse','Expectoração',
                         'Hemoptóicos','Hemoptise','Sudorese_noturna','Febre','Dispnéia','Perda_de_apetite','Perda_peso_10percent',
                         'Dor_torácica','Internação_hospital_2anos','Prisão_2anos','Delegacia_2anos','Contato_TBP_2anos','TBP_Morava_com_vc',
                         'TBP_trabalhava_com_vc','TBP_amigo_parente_não_morava_com_vc','Contato_TBP_menor_3anos','Contato_TBP_Casa',
                         'Contato_TBP_Trabalho','Contato_TBP_Social','Fuma','Nenhuma_bebida_alcoólica','Etilismo','TB_desfecho_final_Dri']

# Não alterar o conjunto de dados original
data_reduced = data[features_selecionadas].copy()

# Informações sobre o conjunto de dados reduzido
print('Conjunto de dados reduzido.\nExemplos: {}\nFeatures: {}'.format(*data_reduced.shape))

# Renomeando o desfecho
data_reduced.rename(index=str,columns={'TB_desfecho_final_Dri':'desfecho'},inplace=True)

# Renomeando os labels do desfecho
data_reduced.replace(['Não TB','TB','8','IGN'],['TB-','TB+','ignorado','ignorado'],inplace=True)
# Out:
# Conjunto de dados reduzido.
# Exemplos: 4381
# Features: 49

# %%
# Realização dos testes de chi quadrado utilizando tabelas de contingência
from scipy.stats import chi2_contingency

# %%
# Tabelas de contingência entre o desfecho e cada variável.

for feature in list(features_selecionadas[:-1]):
    
    if data[feature].dtype != 'O':
        continue
        
    print('Tabela de Contingência entre o desfecho e {}\n'.format(feature))
    
    # Contingency table from pandas
    cross_tab = pd.crosstab(data_reduced[feature],data_reduced['desfecho'],margins=True)
    print(pd.crosstab(data_reduced[feature],data_reduced['desfecho'],margins=True))
    print()
    
    # Chi Squared Test 
    chi2, p, dof, expected =  chi2_contingency(cross_tab)
    print('Chi2: {}\tp-value: {}\tDOF: {}\nExpected_val: \n{}\n\n'.format(chi2,p,dof,expected))
# Out:
# Tabela de Contingência entre o desfecho e Doença_pumonar_difusa
#
# desfecho               TB+   TB-  ignorado   All
# Doença_pumonar_difusa
# Não                    116   161         2   279
# ignorado               755  1695      1652  4102
# All                    871  1856      1654  4381
#
# Chi2: 195.3686031450702	p-value: 1.8355135687635442e-39	DOF: 6
# Expected_val:
# [[   55.46884273   118.19767176   105.33348551   279.        ]
#  [  815.53115727  1737.80232824  1548.66651449  4102.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Transplante
#
# desfecho     TB+   TB-  ignorado   All
# Transplante
# Não          116   161         2   279
# ignorado     755  1695      1652  4102
# All          871  1856      1654  4381
#
# Chi2: 195.3686031450702	p-value: 1.8355135687635442e-39	DOF: 6
# Expected_val:
# [[   55.46884273   118.19767176   105.33348551   279.        ]
#  [  815.53115727  1737.80232824  1548.66651449  4102.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Silicose
#
# desfecho  TB+   TB-  ignorado   All
# Silicose
# Não       116   161         2   279
# ignorado  755  1695      1652  4102
# All       871  1856      1654  4381
#
# Chi2: 195.3686031450702	p-value: 1.8355135687635442e-39	DOF: 6
# Expected_val:
# [[   55.46884273   118.19767176   105.33348551   279.        ]
#  [  815.53115727  1737.80232824  1548.66651449  4102.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Tto_anterior_TB_INH
#
# desfecho             TB+  TB-  ignorado   All
# Tto_anterior_TB_INH
# Não                    2    1         0     3
# Sim                  119  181         5   305
# ignorado             268  473       935  1676
# All                  389  655       940  1984
#
# Chi2: 309.98932128437923	p-value: 1.9814930319032093e-61	DOF: 9
# Expected_val:
# [[  5.88205645e-01   9.90423387e-01   1.42137097e+00   3.00000000e+00]
#  [  5.98009073e+01   1.00693044e+02   1.44506048e+02   3.05000000e+02]
#  [  3.28610887e+02   5.53316532e+02   7.94072581e+02   1.67600000e+03]
#  [  3.89000000e+02   6.55000000e+02   9.40000000e+02   1.98400000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Tto_anterior_TB_RIF
#
# desfecho             TB+  TB-  ignorado   All
# Tto_anterior_TB_RIF
# Não                    2    2         0     4
# Sim                  118  179         5   302
# ignorado             268  474       935  1677
# All                  388  655       940  1983
#
# Chi2: 306.3808745287398	p-value: 1.1557812225601689e-60	DOF: 9
# Expected_val:
# [[  7.82652547e-01   1.32123046e+00   1.89611699e+00   4.00000000e+00]
#  [  5.90902673e+01   9.97528996e+01   1.43156833e+02   3.02000000e+02]
#  [  3.28127080e+02   5.53925870e+02   7.94947050e+02   1.67700000e+03]
#  [  3.88000000e+02   6.55000000e+02   9.40000000e+02   1.98300000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Quimio_prévia
#
# desfecho       TB+   TB-  ignorado   All
# Quimio_prévia
# Não            743   751        30  1524
# Sim              2     0         0     2
# ignorado        88   655      1042  1785
# All            833  1406      1072  3311
#
# Chi2: 1472.0563714560205	p-value: 2.077657715342e-311	DOF: 9
# Expected_val:
# [[  3.83416490e+02   6.47159166e+02   4.93424343e+02   1.52400000e+03]
#  [  5.03171247e-01   8.49290245e-01   6.47538508e-01   2.00000000e+00]
#  [  4.49080338e+02   7.57991543e+02   5.77928118e+02   1.78500000e+03]
#  [  8.33000000e+02   1.40600000e+03   1.07200000e+03   3.31100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Quimio_INH
#
# desfecho    TB+  TB-  ignorado   All
# Quimio_INH
# Não           0    1         0     1
# Sim           1    0         1     2
# ignorado    298  614       981  1893
# All         299  615       982  1896
#
# Chi2: 4.2201161338721445	p-value: 0.896336758254764	DOF: 9
# Expected_val:
# [[  1.57700422e-01   3.24367089e-01   5.17932489e-01   1.00000000e+00]
#  [  3.15400844e-01   6.48734177e-01   1.03586498e+00   2.00000000e+00]
#  [  2.98526899e+02   6.14026899e+02   9.80446203e+02   1.89300000e+03]
#  [  2.99000000e+02   6.15000000e+02   9.82000000e+02   1.89600000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Quimio_RIF
#
# desfecho    TB+  TB-  ignorado   All
# Quimio_RIF
# Não           0    0         1     1
# ignorado    299  615       981  1895
# All         299  615       982  1896
#
# Chi2: 0.9312447269854749	p-value: 0.9880848780007668	DOF: 6
# Expected_val:
# [[  1.57700422e-01   3.24367089e-01   5.17932489e-01   1.00000000e+00]
#  [  2.98842300e+02   6.14675633e+02   9.81482068e+02   1.89500000e+03]
#  [  2.99000000e+02   6.15000000e+02   9.82000000e+02   1.89600000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Desfecho_quimio
#
# desfecho         TB+  TB-  ignorado   All
# Desfecho_quimio
# Abandonou          1    0         0     1
# ignorado         349  601       981  1931
# All              350  601       981  1932
#
# Chi2: 4.52234075608493	p-value: 0.6063609749335719	DOF: 6
# Expected_val:
# [[  1.81159420e-01   3.11076605e-01   5.07763975e-01   1.00000000e+00]
#  [  3.49818841e+02   6.00688923e+02   9.80492236e+02   1.93100000e+03]
#  [  3.50000000e+02   6.01000000e+02   9.81000000e+02   1.93200000e+03]]
#
#
# Tabela de Contingência entre o desfecho e HIV
#
# desfecho                    TB+   TB-  ignorado   All
# HIV
# Negativo                     62    27         1    90
# Não realizado/Desconhecido  626   686        28  1340
# Positivo                     56    35         2    93
# ignorado                     90   646      1031  1767
# All                         834  1394      1062  3290
#
# Chi2: 1485.2695356641175	p-value: 5.6943390521333e-311	DOF: 12
# Expected_val:
# [[   22.81458967    38.1337386     29.05167173    90.        ]
#  [  339.68389058   567.76899696   432.54711246  1340.        ]
#  [   23.57507599    39.40486322    30.02006079    93.        ]
#  [  447.92644377   748.69240122   570.38115502  1767.        ]
#  [  834.          1394.          1062.          3290.        ]]
#
#
# Tabela de Contingência entre o desfecho e Hepatopatia
#
# desfecho     TB+   TB-  ignorado   All
# Hepatopatia
# Não          115   161         2   278
# Sim            1     0         0     1
# ignorado     755  1695      1652  4102
# All          871  1856      1654  4381
#
# Chi2: 197.88058054232766	p-value: 9.21335636944335e-38	DOF: 9
# Expected_val:
# [[  5.52700297e+01   1.17774024e+02   1.04955946e+02   2.78000000e+02]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  8.15531157e+02   1.73780233e+03   1.54866651e+03   4.10200000e+03]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Uso_corticoide
#
# desfecho        TB+   TB-  ignorado   All
# Uso_corticoide
# Não             115   160         2   277
# Sim               0     1         0     1
# ignorado        756  1695      1652  4103
# All             871  1856      1654  4381
#
# Chi2: 194.98383998834848	p-value: 3.7260853460157164e-37	DOF: 9
# Expected_val:
# [[  5.50712166e+01   1.17350377e+02   1.04578407e+02   2.77000000e+02]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  8.15729970e+02   1.73822598e+03   1.54904405e+03   4.10300000e+03]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Neo_maligna
#
# desfecho     TB+   TB-  ignorado   All
# Neo_maligna
# Não          115   160         2   277
# Sim            1     1         0     2
# ignorado     755  1695      1652  4102
# All          871  1856      1654  4381
#
# Chi2: 195.468999071833	p-value: 2.9487639305453963e-37	DOF: 9
# Expected_val:
# [[  5.50712166e+01   1.17350377e+02   1.04578407e+02   2.77000000e+02]
#  [  3.97626113e-01   8.47295138e-01   7.55078749e-01   2.00000000e+00]
#  [  8.15531157e+02   1.73780233e+03   1.54866651e+03   4.10200000e+03]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Asma
#
# desfecho  TB+   TB-  ignorado   All
# Asma
# #NULL!    841  1531      1654  4026
# Não        24   234         0   258
# Sim         6    91         0    97
# All       871  1856      1654  4381
#
# Chi2: 392.32538164128806	p-value: 5.941789617937064e-79	DOF: 9
# Expected_val:
# [[  800.42136499  1705.60511299  1519.97352203  4026.        ]
#  [   51.29376855   109.30107281    97.40515864   258.        ]
#  [   19.28486647    41.0938142     36.62131933    97.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e TTO_anterior_TB_triagem_enfermeiro
#
# desfecho                            TB+   TB-  ignorado   All
# TTO_anterior_TB_triagem_enfermeiro
# Não                                 668  1388      1331  3387
# Sim                                 202   453       308   963
# ignorado                              1    15        15    31
# All                                 871  1856      1654  4381
#
# Chi2: 23.27566322414021	p-value: 0.005606020055119315	DOF: 9
# Expected_val:
# [[  673.37982196  1434.89431637  1278.72586168  3387.        ]
#  [  191.45697329   407.97260899   363.57041771   963.        ]
#  [    6.16320475    13.13307464    11.70372061    31.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Cicatriz_BCG
#
# desfecho      TB+   TB-  ignorado   All
# Cicatriz_BCG
# Não           222   614       266  1102
# Sim           434   780       300  1514
# ignorado      215   462      1088  1765
# All           871  1856      1654  4381
#
# Chi2: 746.9149428389818	p-value: 5.633249955999208e-155	DOF: 9
# Expected_val:
# [[  219.09198813   466.85962109   416.04839078  1102.        ]
#  [  301.00296736   641.40241954   571.5946131   1514.        ]
#  [  350.90504451   747.73795937   666.35699612  1765.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Tto_anterior_TB_avaliação_médica
#
# desfecho                          TB+   TB-  ignorado   All
# Tto_anterior_TB_avaliação_médica
# Não                               589   539        24  1152
# Sim                               158   214         7   379
# ignorado                           87   641      1031  1759
# All                               834  1394      1062  3290
#
# Chi2: 1480.4828494865524	p-value: 0.0	DOF: 9
# Expected_val:
# [[  292.02674772   488.1118541    371.86139818  1152.        ]
#  [   96.07477204   160.58541033   122.33981763   379.        ]
#  [  445.89848024   745.30273556   567.79878419  1759.        ]
#  [  834.          1394.          1062.          3290.        ]]
#
#
# Tabela de Contingência entre o desfecho e Comorbidades
#
# desfecho      TB+   TB-  ignorado   All
# Comorbidades
# Não           385   404         3   792
# Sim           124   160         2   286
# ignorado      362  1292      1649  3303
# All           871  1856      1654  4381
#
# Chi2: 1101.6118545022557	p-value: 2.0827611009003705e-231	DOF: 9
# Expected_val:
# [[  157.45994065   335.52887469   299.01118466   792.        ]
#  [   56.86053412   121.16320475   107.97626113   286.        ]
#  [  656.67952522  1399.30792057  1247.01255421  3303.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Sexo
#
# desfecho   TB+   TB-  ignorado   All
# Sexo
# 2            0     2         3     5
# Feminino   297   905       876  2078
# Masculino  574   948       768  2290
# ignorado     0     1         7     8
# All        871  1856      1654  4381
#
# Chi2: 96.42451834392361	p-value: 2.784406562153794e-15	DOF: 12
# Expected_val:
# [[  9.94065282e-01   2.11823785e+00   1.88769687e+00   5.00000000e+00]
#  [  4.13133531e+02   8.80339648e+02   7.84526820e+02   2.07800000e+03]
#  [  4.55281899e+02   9.70152933e+02   8.64565168e+02   2.29000000e+03]
#  [  1.59050445e+00   3.38918055e+00   3.02031500e+00   8.00000000e+00]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Raça
#
# desfecho    TB+   TB-  ignorado   All
# Raça
# Branco      364   899       798  2061
# Não branco  503   948       832  2283
# ignorado      4     9        24    37
# All         871  1856      1654  4381
#
# Chi2: 24.693290348017676	p-value: 0.0033298667904267925	DOF: 9
# Expected_val:
# [[  409.7537092    873.13763981   778.10865099  2061.        ]
#  [  453.89020772   967.18740014   861.92239215  2283.        ]
#  [    7.35608309    15.67496005    13.96895686    37.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Estado_civil
#
# desfecho      TB+   TB-  ignorado   All
# Estado_civil
# 0               2     4         0     6
# Casado        213   625       519  1357
# Separado       35   121        88   244
# Solteiro      573   913       849  2335
# ignorado       13    25        25    63
# viúvo          33   168       173   374
# All           869  1856      1654  4379
#
# Chi2: 90.60179580632598	p-value: 1.1257653522172816e-11	DOF: 18
# Expected_val:
# [[  1.19068280e+00   2.54304636e+00   2.26627084e+00   6.00000000e+00]
#  [  2.69292761e+02   5.75152318e+02   5.12554921e+02   1.35700000e+03]
#  [  4.84211007e+01   1.03417219e+02   9.21616807e+01   2.44000000e+02]
#  [  4.63374058e+02   9.89668874e+02   8.81957068e+02   2.33500000e+03]
#  [  1.25021694e+01   2.67019868e+01   2.37958438e+01   6.30000000e+01]
#  [  7.42192281e+01   1.58516556e+02   1.41264216e+02   3.74000000e+02]
#  [  8.69000000e+02   1.85600000e+03   1.65400000e+03   4.37900000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Tem_companheiro
#
# desfecho         TB+   TB-  ignorado   All
# Tem_companheiro
# Não              444   828       751  2023
# Sim              410   990       868  2268
# ignorado          17    38        35    90
# All              871  1856      1654  4381
#
# Chi2: 10.37508737994361	p-value: 0.3209815566283443	DOF: 9
# Expected_val:
# [[  402.19881306   857.03903218   763.76215476  2023.        ]
#  [  450.90801187   960.8326866    856.25930153  2268.        ]
#  [   17.89317507    38.12828121    33.97854371    90.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Tosse
#
# desfecho  TB+   TB-  ignorado   All
# Tosse
# Não        76   203       426   705
# Sim       795  1652      1227  3674
# ignorado    0     1         1     2
# All       871  1856      1654  4381
#
# Chi2: 186.547574597534	p-value: 2.170945755327427e-35	DOF: 9
# Expected_val:
# [[  1.40163205e+02   2.98671536e+02   2.66165259e+02   7.05000000e+02]
#  [  7.30439169e+02   1.55648117e+03   1.38707966e+03   3.67400000e+03]
#  [  3.97626113e-01   8.47295138e-01   7.55078749e-01   2.00000000e+00]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Semanas_tosse
#
# desfecho        TB+   TB-  ignorado   All
# Semanas_tosse
# 0                23    81        98   202
# 1                58   208       230   496
# 10                3     5         4    12
# 104               1     0         0     1
# 12               75   109        80   264
# 13                1     0         0     1
# 14                0     2         0     2
# 144               0     0         1     1
# 15                0     1         1     2
# 16               38    32        27    97
# 18                6     5         3    14
# 180               2     1         0     3
# 19                0     1         0     1
# 2               127   365       228   720
# 20               15    13        12    40
# 24               22    34        29    85
# 28                2     1         2     5
# 3                65   171        94   330
# 30                0     1         1     2
# 32                3     9         4    16
# 36                2     2         0     4
# 38                0     0         1     1
# 4               159   274       188   621
# 40                4     4         0     8
# 44                0     1         0     1
# 448               0     1         0     1
# 48                7    17        19    43
# 5                23    36        17    76
# 50                0     1         1     2
# 52                1     3         2     6
# 56                0     1         0     1
# 58                0     2         3     5
# 6                30    50        30   110
# 7                 2     2         2     6
# 72                0     2         0     2
# 80                0     0         4     4
# 9                 5     3         0     8
# 96                1     1         1     3
# crônico+sempre    3    30        15    48
# ignorado        116   175       108   399
# não se aplica    77   212       449   738
# All             871  1856      1654  4381
#
# Chi2: 432.93376414578813	p-value: 4.075304715839047e-36	DOF: 123
# Expected_val:
# [[  4.01602374e+01   8.55768089e+01   7.62629537e+01   2.02000000e+02]
#  [  9.86112760e+01   2.10129194e+02   1.87259530e+02   4.96000000e+02]
#  [  2.38575668e+00   5.08377083e+00   4.53047249e+00   1.20000000e+01]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  5.24866469e+01   1.11842958e+02   9.96703949e+01   2.64000000e+02]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  3.97626113e-01   8.47295138e-01   7.55078749e-01   2.00000000e+00]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  3.97626113e-01   8.47295138e-01   7.55078749e-01   2.00000000e+00]
#  [  1.92848665e+01   4.10938142e+01   3.66213193e+01   9.70000000e+01]
#  [  2.78338279e+00   5.93106597e+00   5.28555124e+00   1.40000000e+01]
#  [  5.96439169e-01   1.27094271e+00   1.13261812e+00   3.00000000e+00]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  1.43145401e+02   3.05026250e+02   2.71828350e+02   7.20000000e+02]
#  [  7.95252226e+00   1.69459028e+01   1.51015750e+01   4.00000000e+01]
#  [  1.68991098e+01   3.60100434e+01   3.20908468e+01   8.50000000e+01]
#  [  9.94065282e-01   2.11823785e+00   1.88769687e+00   5.00000000e+00]
#  [  6.56083086e+01   1.39803698e+02   1.24587994e+02   3.30000000e+02]
#  [  3.97626113e-01   8.47295138e-01   7.55078749e-01   2.00000000e+00]
#  [  3.18100890e+00   6.77836110e+00   6.04062999e+00   1.60000000e+01]
#  [  7.95252226e-01   1.69459028e+00   1.51015750e+00   4.00000000e+00]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  1.23462908e+02   2.63085140e+02   2.34451952e+02   6.21000000e+02]
#  [  1.59050445e+00   3.38918055e+00   3.02031500e+00   8.00000000e+00]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  8.54896142e+00   1.82168455e+01   1.62341931e+01   4.30000000e+01]
#  [  1.51097923e+01   3.21972152e+01   2.86929925e+01   7.60000000e+01]
#  [  3.97626113e-01   8.47295138e-01   7.55078749e-01   2.00000000e+00]
#  [  1.19287834e+00   2.54188541e+00   2.26523625e+00   6.00000000e+00]
#  [  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  9.94065282e-01   2.11823785e+00   1.88769687e+00   5.00000000e+00]
#  [  2.18694362e+01   4.66012326e+01   4.15293312e+01   1.10000000e+02]
#  [  1.19287834e+00   2.54188541e+00   2.26523625e+00   6.00000000e+00]
#  [  3.97626113e-01   8.47295138e-01   7.55078749e-01   2.00000000e+00]
#  [  7.95252226e-01   1.69459028e+00   1.51015750e+00   4.00000000e+00]
#  [  1.59050445e+00   3.38918055e+00   3.02031500e+00   8.00000000e+00]
#  [  5.96439169e-01   1.27094271e+00   1.13261812e+00   3.00000000e+00]
#  [  9.54302671e+00   2.03350833e+01   1.81218900e+01   4.80000000e+01]
#  [  7.93264095e+01   1.69035380e+02   1.50638210e+02   3.99000000e+02]
#  [  1.46724036e+02   3.12651906e+02   2.78624058e+02   7.38000000e+02]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Expectoração
#
# desfecho      TB+   TB-  ignorado   All
# Expectoração
# Não           199   368       867  1434
# Sim           670  1485       784  2939
# ignorado        2     3         3     8
# All           871  1856      1654  4381
#
# Chi2: 470.73529868016357	p-value: 1.0545731220607723e-95	DOF: 9
# Expected_val:
# [[  2.85097923e+02   6.07510614e+02   5.41391463e+02   1.43400000e+03]
#  [  5.84311573e+02   1.24510021e+03   1.10958822e+03   2.93900000e+03]
#  [  1.59050445e+00   3.38918055e+00   3.02031500e+00   8.00000000e+00]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Hemoptóicos
#
# desfecho     TB+   TB-  ignorado   All
# Hemoptóicos
# Não          698  1495      1481  3674
# Sim          168   353       156   677
# ignorado       5     8        17    30
# All          871  1856      1654  4381
#
# Chi2: 77.34503876635321	p-value: 5.433060180397525e-13	DOF: 9
# Expected_val:
# [[  730.43916914  1556.48116868  1387.07966218  3674.        ]
#  [  134.59643917   286.80940425   255.59415659   677.        ]
#  [    5.96439169    12.70942707    11.32618124    30.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Hemoptise
#
# desfecho   TB+   TB-  ignorado   All
# Hemoptise
# Não        773  1692      1575  4040
# Sim         97   145        63   305
# ignorado     1    19        16    36
# All        871  1856      1654  4381
#
# Chi2: 56.97765385972671	p-value: 5.103536875424961e-09	DOF: 9
# Expected_val:
# [[  803.20474777  1711.53617895  1525.25907327  4040.        ]
#  [   60.6379822    129.21250856   115.14950924   305.        ]
#  [    7.15727003    15.25131249    13.59141748    36.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Sudorese_noturna
#
# desfecho          TB+   TB-  ignorado   All
# Sudorese_noturna
# 9                   3     6         8    17
# Não               471  1249      1283  3003
# Sim               397   601       363  1361
# All               871  1856      1654  4381
#
# Chi2: 151.68029411635592	p-value: 3.9562426900044175e-28	DOF: 9
# Expected_val:
# [[  3.37982196e+00   7.20200867e+00   6.41816937e+00   1.70000000e+01]
#  [  5.97035608e+02   1.27221365e+03   1.13375074e+03   3.00300000e+03]
#  [  2.70584570e+02   5.76584341e+02   5.13831089e+02   1.36100000e+03]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Febre
#
# desfecho  TB+   TB-  ignorado   All
# Febre
# Não       353  1113      1175  2641
# Sim       517   734       475  1726
# ignorado    1     9         4    14
# All       871  1856      1654  4381
#
# Chi2: 227.17280113104925	p-value: 6.479186589325117e-44	DOF: 9
# Expected_val:
# [[  5.25065282e+02   1.11885323e+03   9.97081488e+02   2.64100000e+03]
#  [  3.43151335e+02   7.31215704e+02   6.51632961e+02   1.72600000e+03]
#  [  2.78338279e+00   5.93106597e+00   5.28555124e+00   1.40000000e+01]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Dispnéia
#
# desfecho  TB+   TB-  ignorado   All
# Dispnéia
# 2           0     1         0     1
# Não       319   519       558  1396
# Sim       551  1333      1093  2977
# ignorado    1     3         3     7
# All       871  1856      1654  4381
#
# Chi2: 26.156858174150432	p-value: 0.010198422380448867	DOF: 12
# Expected_val:
# [[  1.98813056e-01   4.23647569e-01   3.77539375e-01   1.00000000e+00]
#  [  2.77543027e+02   5.91412006e+02   5.27044967e+02   1.39600000e+03]
#  [  5.91866469e+02   1.26119881e+03   1.12393472e+03   2.97700000e+03]
#  [  1.39169139e+00   2.96553298e+00   2.64277562e+00   7.00000000e+00]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Perda_de_apetite
#
# desfecho          TB+   TB-  ignorado   All
# Perda_de_apetite
# Não               258   754       478  1490
# Sim               308   623       263  1194
# ignorado          305   479       913  1697
# All               871  1856      1654  4381
#
# Chi2: 366.80895505402873	p-value: 1.6332756723150018e-73	DOF: 9
# Expected_val:
# [[  296.23145401   631.23487788   562.53366811  1490.        ]
#  [  237.38278932   505.83519744   450.78201324  1194.        ]
#  [  337.38575668   718.92992467   640.68431865  1697.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Perda_peso_10percent
#
# desfecho              TB+   TB-  ignorado   All
# Perda_peso_10percent
# Não                   439  1423      1277  3139
# Sim                   379   342       241   962
# ignorado               53    91       136   280
# All                   871  1856      1654  4381
#
# Chi2: 319.721685351476	p-value: 1.699510955788536e-63	DOF: 9
# Expected_val:
# [[  624.07418398  1329.82971924  1185.09609678  3139.        ]
#  [  191.25816024   407.54896142   363.19287834   962.        ]
#  [   55.66765579   118.62131933   105.71102488   280.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Dor_torácica
#
# desfecho      TB+   TB-  ignorado   All
# Dor_torácica
# Não           256   550       641  1447
# Sim           613  1305      1006  2924
# ignorado        2     1         7    10
# All           871  1856      1654  4381
#
# Chi2: 45.5660571199377	p-value: 7.248310892113253e-07	DOF: 9
# Expected_val:
# [[  2.87682493e+02   6.13018032e+02   5.46299475e+02   1.44700000e+03]
#  [  5.81329377e+02   1.23874549e+03   1.10392513e+03   2.92400000e+03]
#  [  1.98813056e+00   4.23647569e+00   3.77539375e+00   1.00000000e+01]
#  [  8.71000000e+02   1.85600000e+03   1.65400000e+03   4.38100000e+03]]
#
#
# Tabela de Contingência entre o desfecho e Internação_hospital_2anos
#
# desfecho                   TB+   TB-  ignorado   All
# Internação_hospital_2anos
# Não                        756  1587      1371  3714
# Sim                        108   256       266   630
# ignorado                     7    13        17    37
# All                        871  1856      1654  4381
#
# Chi2: 8.51475676311	p-value: 0.48321487443153444	DOF: 9
# Expected_val:
# [[  738.39169139  1573.42707144  1402.18123716  3714.        ]
#  [  125.25222552   266.8979685    237.84980598   630.        ]
#  [    7.35608309    15.67496005    13.96895686    37.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Prisão_2anos
#
# desfecho      TB+   TB-  ignorado   All
# Prisão_2anos
# Não           818  1818      1612  4248
# Sim            46    23        20    89
# ignorado        7    15        22    44
# All           871  1856      1654  4381
#
# Chi2: 60.39277699790905	p-value: 1.1261787545199384e-09	DOF: 9
# Expected_val:
# [[  844.5578635   1799.65487332  1603.78726318  4248.        ]
#  [   17.69436202    37.70463365    33.60100434    89.        ]
#  [    8.74777448    18.64049304    16.61173248    44.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Delegacia_2anos
#
# desfecho         TB+   TB-  ignorado   All
# Delegacia_2anos
# Não              824  1813      1614  4251
# Sim               38    28        19    85
# ignorado           9    15        21    45
# All              871  1856      1654  4381
#
# Chi2: 35.944674525776186	p-value: 4.055284473220768e-05	DOF: 9
# Expected_val:
# [[  845.15430267  1800.92581602  1604.91988131  4251.        ]
#  [   16.89910979    36.01004337    32.09084684    85.        ]
#  [    8.94658754    19.06414061    16.98927186    45.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Contato_TBP_2anos
#
# desfecho           TB+   TB-  ignorado   All
# Contato_TBP_2anos
# Não                584  1374      1254  3212
# Sim                280   458       375  1113
# ignorado             7    24        25    56
# All                871  1856      1654  4381
#
# Chi2: 29.279325267384394	p-value: 0.00058134094019912	DOF: 9
# Expected_val:
# [[  638.58753709  1360.75599178  1212.65647113  3212.        ]
#  [  221.27893175   471.51974435   420.2013239   1113.        ]
#  [   11.13353116    23.72426387    21.14220498    56.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e TBP_Morava_com_vc
#
# desfecho           TB+   TB-  ignorado   All
# TBP_Morava_com_vc
# Não                333   585       882  1800
# Sim                138   210       149   497
# ignorado            13    27        30    70
# não se aplica      387  1034       593  2014
# All                871  1856      1654  4381
#
# Chi2: 203.2435694817799	p-value: 6.9768054924449915e-37	DOF: 12
# Expected_val:
# [[  357.86350148   762.56562429   679.57087423  1800.        ]
#  [   98.81008902   210.55284182   187.63706916   497.        ]
#  [   13.91691395    29.65532983    26.42775622    70.        ]
#  [  400.40949555   853.22620406   760.36430039  2014.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e TBP_trabalhava_com_vc
#
# desfecho               TB+   TB-  ignorado   All
# TBP_trabalhava_com_vc
# Não                    446   751       996  2193
# Sim                     26    42        32   100
# ignorado                12    29        32    73
# não se aplica          387  1034       594  2015
# All                    871  1856      1654  4381
#
# Chi2: 147.61285655815965	p-value: 1.7281663718555434e-25	DOF: 12
# Expected_val:
# [[  435.99703264   929.05911892   827.94384844  2193.        ]
#  [   19.88130564    42.3647569     37.75393746   100.        ]
#  [   14.51335312    30.92627254    27.56037434    73.        ]
#  [  400.60830861   853.64985163   760.74183976  2015.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e TBP_amigo_parente_não_morava_com_vc
#
# desfecho                             TB+   TB-  ignorado   All
# TBP_amigo_parente_não_morava_com_vc
# Não                                  343   555       817  1715
# Sim                                  129   239       212   580
# ignorado                              12    28        31    71
# não se aplica                        387  1034       594  2015
# All                                  871  1856      1654  4381
#
# Chi2: 163.16251809491058	p-value: 1.1901119268373809e-28	DOF: 12
# Expected_val:
# [[  340.96439169   726.55558092   647.48002739  1715.        ]
#  [  115.3115727    245.71559005   218.97283725   580.        ]
#  [   14.115727      30.0789774     26.80529559    71.        ]
#  [  400.60830861   853.64985163   760.74183976  2015.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Contato_TBP_menor_3anos
#
# desfecho                 TB+   TB-  ignorado   All
# Contato_TBP_menor_3anos
# Não                      261   476       746  1483
# Sim                      207   312       280   799
# ignorado                  16    34        34    84
# não se aplica            387  1034       594  2015
# All                      871  1856      1654  4381
#
# Chi2: 196.25029595716438	p-value: 1.936326444393614e-35	DOF: 12
# Expected_val:
# [[  294.83976261   628.2693449    559.89089249  1483.        ]
#  [  158.85163205   338.49440767   301.65396028   799.        ]
#  [   16.70029674    35.5863958     31.71330746    84.        ]
#  [  400.60830861   853.64985163   760.74183976  2015.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Contato_TBP_Casa
#
# desfecho          TB+   TB-  ignorado   All
# Contato_TBP_Casa
# Não               325   569       846  1740
# Sim               145   222       180   547
# ignorado           14    31        34    79
# não se aplica     387  1034       594  2015
# All               871  1856      1654  4381
#
# Chi2: 186.00470434407697	p-value: 2.492332074780893e-33	DOF: 12
# Expected_val:
# [[  345.9347181    737.14677014   656.91851176  1740.        ]
#  [  108.75074184   231.73522027   206.51403789   547.        ]
#  [   15.70623145    33.46815795    29.82561059    79.        ]
#  [  400.60830861   853.64985163   760.74183976  2015.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Contato_TBP_Trabalho
#
# desfecho              TB+   TB-  ignorado   All
# Contato_TBP_Trabalho
# Não                   449   741       987  2177
# Sim                    22    50        38   110
# ignorado               13    31        35    79
# não se aplica         387  1034       594  2015
# All                   871  1856      1654  4381
#
# Chi2: 146.6067265097681	p-value: 2.7632656812730334e-25	DOF: 12
# Expected_val:
# [[  432.81602374   922.28075782   821.90321844  2177.        ]
#  [   21.8694362     46.6012326     41.5293312    110.        ]
#  [   15.70623145    33.46815795    29.82561059    79.        ]
#  [  400.60830861   853.64985163   760.74183976  2015.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Contato_TBP_Social
#
# desfecho            TB+   TB-  ignorado   All
# Contato_TBP_Social
# Não                 359   614       880  1853
# Sim                 112   178       149   439
# ignorado             13    30        31    74
# não se aplica       387  1034       594  2015
# All                 871  1856      1654  4381
#
# Chi2: 168.76656844095376	p-value: 8.532925294396609e-30	DOF: 12
# Expected_val:
# [[  368.40059347   785.01894545   699.58046108  1853.        ]
#  [   87.27893175   185.98128281   165.73978544   439.        ]
#  [   14.71216617    31.34992011    27.93791372    74.        ]
#  [  400.60830861   853.64985163   760.74183976  2015.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Fuma
#
# desfecho        TB+   TB-  ignorado   All
# Fuma
# Ex-fumante      219   512       463  1194
# Fumante         272   649       402  1323
# Jamais fumante  373   684       772  1829
# ignorado          7    11        17    35
# All             871  1856      1654  4381
#
# Chi2: 57.72200182373504	p-value: 5.852724658207888e-08	DOF: 12
# Expected_val:
# [[  237.38278932   505.83519744   450.78201324  1194.        ]
#  [  263.02967359   560.48573385   499.48459256  1323.        ]
#  [  363.62908012   774.85140379   690.51951609  1829.        ]
#  [    6.95845697    14.82766492    13.21387811    35.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Nenhuma_bebida_alcoólica
#
# desfecho                  TB+   TB-  ignorado   All
# Nenhuma_bebida_alcoólica
# Não                       504  1069       683  2256
# Sim                       364   778       953  2095
# ignorado                    3     9        18    30
# All                       871  1856      1654  4381
#
# Chi2: 113.5392905252981	p-value: 2.793443652931078e-20	DOF: 9
# Expected_val:
# [[  448.52225519   955.74891577   851.72882903  2256.        ]
#  [  416.51335312   887.54165716   790.94498973  2095.        ]
#  [    5.96439169    12.70942707    11.32618124    30.        ]
#  [  871.          1856.          1654.          4381.        ]]
#
#
# Tabela de Contingência entre o desfecho e Etilismo
#
# desfecho  TB+   TB-  ignorado   All
# Etilismo
# Não        19    68         0    87
# Sim        99    95         2   196
# ignorado  753  1693      1652  4098
# All       871  1856      1654  4381
#
# Chi2: 236.44227472119368	p-value: 7.226688609471393e-46	DOF: 9
# Expected_val:
# [[   17.29673591    36.85733851    32.84592559    87.        ]
#  [   38.96735905    83.03492353    73.99771742   196.        ]
#  [  814.73590504  1736.10773796  1547.156357    4098.        ]
#  [  871.          1856.          1654.          4381.        ]]
