# %% [markdown]
# # Seleção de Features usando o teste chi quadrado de independência

# %% [markdown]
# ## 1. Carregando módulos e dados

# %%
# Manipulação dos dados
import numpy  as np
import scipy  as sp
import pandas as pd

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn           as sns
# %matplotlib inline

# %%
# Carregando os dados
data = pd.read_excel('../../Dados/Banco labels.xlsx')

# %%
# Visualização da tabela
data.head(5)
# Out:
#   TB_desfecho_final_Dri Tbafranio Obs_desfechoTB_Dri_Dani Data_inclusão  Nome  \
# 0                    TB       SIM                     NaN    2008-04-03   NaN
# 1                    TB       SIM                     NaN    2006-10-03   NaN
# 2                    TB       SIM                     NaN    2007-06-21   NaN
# 3                    TB       SIM                     NaN    2009-09-30   NaN
# 4                    TB       SIM                     NaN    2009-06-19   NaN
#
#   Desfecho_tuberculose_lista_Mauro Desfecho_TB_162_Revisão_ADRIANA  \
# 0                                9                              TB
# 1                               TB                              TB
# 2                               TB                              TB
# 3                               TB                              TB
# 4                               TB                             NaN
#
#   Observaça0_desfecho_TB Resultado_BAAR_1 Resultado_BAAR_2  \
# 0       TB PROBABILIDADE         Negativo         Negativo
# 1                    NaN         Negativo         Negativo
# 2          TB CONFIRMADA         Negativo         Negativo
# 3                    NaN         Negativo         Negativo
# 4                    NaN         Negativo         Negativo
#
#            ...          Perdeu_aula_hoje_CA Deixou_de_ganhar_dinheiro_hoje_CA  \
# 0          ...                          IGN                               IGN
# 1          ...                          IGN                               IGN
# 2          ...                          IGN                               IGN
# 3          ...                          IGN                               IGN
# 4          ...                          Não                               Não
#
#   Quanto_deixou_ganhar_CA Caso_acompanhado_quem_custeou_tudo_CA  \
# 0                Ignorado                                   IGN
# 1                Ignorado                                   IGN
# 2                Ignorado                                   IGN
# 3                Ignorado                                   IGN
# 4         "Não se aplica"                         não se aplica
#
#         Valor_CA  Avaliador_custo_CA Data_avaliação_custo_CA  \
# 0       ignorado                   9              1999-09-09
# 1       ignorado                   9              1999-09-09
# 2       ignorado                   9              1999-09-09
# 3       ignorado                   9              1999-09-09
# 4  não se aplica  Marcia  dos Santos              2009-06-19
#
#   Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER) ANO  de inclusao  \
# 0                                           Selected                  2008
# 1                                           Selected                  2006
# 2                                           Selected                  2007
# 3                                           Selected                  2009
# 4                                       Not Selected                  2009
#
#   Novocriteriotbafranio
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 281 columns]

# %%
# Alterando o nome da variável TB_desfecho_final_Dri para desfecho
data.rename(columns={'TB_desfecho_final_Dri':'desfecho'},inplace=True)

# %%
# Carregando as features salvas na seleção inicial de variáveis
import pickle
features_selecionadas = pickle.load(open('../../Dados/features_filtradas.pkl', 'rb'))

# %%
# Exibindo as variáveis salvas
print(features_selecionadas)

# Criando um dataframe a partir das features pré-selecionadas
dados = data[features_selecionadas].copy()
# Out:
# ['desfecho', 'TTO_anterior_TB_triagem_enfermeiro', 'Cicatriz_BCG', 'Idade', 'Sexo', 'Raça', 'Estado_civil', 'Tem_companheiro', 'Peso_habitual', 'Peso_atual', 'Altura_cm', 'Tosse', 'Semanas_tosse', 'Expectoração', 'Semanas_expectoração', 'Hemoptóicos', 'Semanas_hemoptóicos', 'Hemoptise', 'Semanas_hemoptise', 'Quantidade_hemoptise', 'Sudorese_noturna', 'Semanas_sudorese', 'Febre', 'Semanas_febre', 'Dispnéia', 'Dispnéia_semanas', 'Perda_de_apetite', 'Perda_apetite_semanas', 'Perda_peso_10percent', 'Perda_peso_semanas', 'Dor_torácica', 'Dor_torácica_semanas', 'Internação_hospital_2anos', 'Prisão_2anos', 'Delegacia_2anos', 'Contato_TBP_2anos', 'Fuma', 'Número_cigarros_dia', 'CAGE']

# %% [markdown]
# ### 1.1 Pré-processamento dos dados

# %%
# Alterando os labels dos desfechos
dados.desfecho.replace(['TB', 'Não TB','IGN',8],['TB+','TB-','desconhecido','desconhecido'],inplace=True)

# Selecionando os desfechos que possuem diagnóstico conhecido: TB+ e TB-
dados = dados[(dados.desfecho == 'TB+') | (dados.desfecho == 'TB-')]

# %%
# Quantidade_hemoptise: Poucos valores significantes
dados.drop(['Quantidade_hemoptise'],axis=1,inplace=True)

# Peso atual/habitual: Não importa para o diagnóstico
dados.drop(['Peso_atual'],axis=1,inplace=True)
dados.drop(['Peso_habitual'],axis=1,inplace=True)

# Altura: Não importa para o diagnóstico
dados.drop(['Altura_cm'],axis=1,inplace=True)

# Número de cigarros
dados.drop(['Número_cigarros_dia'],axis=1,inplace=True)

# Número de cigarros
dados.drop(['Perda_apetite_semanas'],axis=1,inplace=True)

# %%
# Renomeando os valores IGN por ignorado
dados.replace(['IGN'],'ignorado',inplace=True)

# Substituindo os valores da variável Sexo
dados.Sexo.replace([8,2],['ignorado','ignorado'],inplace=True)
                    
# Substituindo os valores da variável Raça
dados.Raça.replace([8],'ignorado',inplace=True)
                    
# Substituindo os valores da variável Estado_civil
dados.Estado_civil.replace([np.nan, 8, 0],['ignorado','ignorado','ignorado'],inplace=True)        

# Substituindo os valores da variável Raça
dados.Raça.replace([8],'ignorado',inplace=True)

# Substituindo os valores da variável Semanas_tosse
dados.Semanas_tosse.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável Semanas_expectoração
dados.Semanas_expectoração.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável Semanas_tosse
dados.Semanas_hemoptóicos.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável Semanas_hemoptise
dados.Semanas_hemoptise.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Sudorese_noturna.replace([9],'ignorado',inplace=True)

# Substituindo os valores da variável 
dados.Semanas_sudorese.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Semanas_febre.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Dispnéia.replace([2],['ignorado'],inplace=True)

# Substituindo os valores da variável 
dados.Dispnéia_semanas.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Perda_peso_semanas.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Dor_torácica_semanas.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# %%
# Features presentes
print(dados.columns)
# Out:
# Index(['desfecho', 'TTO_anterior_TB_triagem_enfermeiro', 'Cicatriz_BCG',
#        'Idade', 'Sexo', 'Raça', 'Estado_civil', 'Tem_companheiro', 'Tosse',
#        'Semanas_tosse', 'Expectoração', 'Semanas_expectoração', 'Hemoptóicos',
#        'Semanas_hemoptóicos', 'Hemoptise', 'Semanas_hemoptise',
#        'Sudorese_noturna', 'Semanas_sudorese', 'Febre', 'Semanas_febre',
#        'Dispnéia', 'Dispnéia_semanas', 'Perda_de_apetite',
#        'Perda_peso_10percent', 'Perda_peso_semanas', 'Dor_torácica',
#        'Dor_torácica_semanas', 'Internação_hospital_2anos', 'Prisão_2anos',
#        'Delegacia_2anos', 'Contato_TBP_2anos', 'Fuma', 'CAGE'],
#       dtype='object')

# %%
# Substituindo os valores por nulos 
dados.replace(['ignorado'],np.nan,inplace=True)

# Remover todos os casos ignorados
dados = dados.dropna(how='any')

# %% [markdown]
# ## 2. Seleção de variáveis utilizando o teste do chi quadrado de independência
#
# O teste do chi quadrado verifica se existe a relação entre duas variáveis categóricas. Dessa forma, será verificada a relação entre as variáveis presentes e o desfecho, ou seja, se o atributo possui alguma relação com o diagnóstico da doença ou não.
#
# O teste do Chi-quadrado é realizado para a verificação de independência entre duas variáveis categóricas.
#
# - Hipótese nula $H_0$ : As variáveis são independentes.
# - Hipótese alternativa $H_a$: As variáveis são dependentes

# %%
# 
from scipy.stats import chi2_contingency

# Criando um DataFrame para o armazenamento dos valores

dict_features = dict()

for feature in list(dados.columns)[1:]:
    
    if dados[feature].dtype != 'O':
        continue
    
    print('Tabela de Contingência entre o desfecho e {}\n'.format(feature))
    
    # Contingency table from pandas
    cross_tab = pd.crosstab(dados[feature],dados['desfecho'],margins=True)
    print(pd.crosstab(dados[feature],dados['desfecho'],margins=True))
    print()
    
    # Chi Squared Test 
    chi2, p, dof, expected =  chi2_contingency(cross_tab)
    print('Chi2: {}\tp-value: {}\tDOF: {}\nExpected_val: \n{}\n\n'.format(chi2,p,dof,expected))
    
    dict_features[feature] = [chi2,p,dof,(len(dados[feature].unique()) - 1),]
# Out:
# Tabela de Contingência entre o desfecho e TTO_anterior_TB_triagem_enfermeiro
#
# desfecho                            TB+  TB-   All
# TTO_anterior_TB_triagem_enfermeiro
# Não                                 329  698  1027
# Sim                                  77  222   299
# All                                 406  920  1326
#
# Chi2: 4.302714575568573	p-value: 0.36658529994135014	DOF: 4
# Expected_val:
# [[  314.45098039   712.54901961  1027.        ]
#  [   91.54901961   207.45098039   299.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Cicatriz_BCG
#
# desfecho      TB+  TB-   All
# Cicatriz_BCG
# Não           135  422   557
# Sim           271  498   769
# All           406  920  1326
#
# Chi2: 18.41110548169797	p-value: 0.0010254530312541828	DOF: 4
# Expected_val:
# [[  170.54449472   386.45550528   557.        ]
#  [  235.45550528   533.54449472   769.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Sexo
#
# desfecho   TB+  TB-   All
# Sexo
# Feminino   135  446   581
# Masculino  271  474   745
# All        406  920  1326
#
# Chi2: 26.531105654219957	p-value: 2.4724767372252624e-05	DOF: 4
# Expected_val:
# [[  177.89291101   403.10708899   581.        ]
#  [  228.10708899   516.89291101   745.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Raça
#
# desfecho    TB+  TB-   All
# Raça
# Branco      172  455   627
# Não branco  234  465   699
# All         406  920  1326
#
# Chi2: 5.6839318636382075	p-value: 0.22402856009829406	DOF: 4
# Expected_val:
# [[  191.97737557   435.02262443   627.        ]
#  [  214.02262443   484.97737557   699.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Estado_civil
#
# desfecho      TB+  TB-   All
# Estado_civil
# Casado         98  304   402
# Separado       16   65    81
# Solteiro      277  474   751
# viúvo          15   77    92
# All           406  920  1326
#
# Chi2: 34.62273005925783	p-value: 3.131765005523066e-05	DOF: 8
# Expected_val:
# [[  123.08597285   278.91402715   402.        ]
#  [   24.80090498    56.19909502    81.        ]
#  [  229.94419306   521.05580694   751.        ]
#  [   28.16892911    63.83107089    92.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Tem_companheiro
#
# desfecho         TB+  TB-   All
# Tem_companheiro
# Não              207  423   630
# Sim              199  497   696
# All              406  920  1326
#
# Chi2: 2.831756978213923	p-value: 0.5863634237761848	DOF: 4
# Expected_val:
# [[  192.8959276   437.1040724   630.       ]
#  [  213.1040724   482.8959276   696.       ]
#  [  406.          920.         1326.       ]]
#
#
# Tabela de Contingência entre o desfecho e Tosse
#
# desfecho  TB+  TB-   All
# Tosse
# Não        40   83   123
# Sim       366  837  1203
# All       406  920  1326
#
# Chi2: 0.23085671489070655	p-value: 0.9938292684219199	DOF: 4
# Expected_val:
# [[   37.66063348    85.33936652   123.        ]
#  [  368.33936652   834.66063348  1203.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Expectoração
#
# desfecho      TB+  TB-   All
# Expectoração
# Não            94  151   245
# Sim           312  769  1081
# All           406  920  1326
#
# Chi2: 8.494588405950479	p-value: 0.07505143134942101	DOF: 4
# Expected_val:
# [[   75.01508296   169.98491704   245.        ]
#  [  330.98491704   750.01508296  1081.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Hemoptóicos
#
# desfecho     TB+  TB-   All
# Hemoptóicos
# Não          338  739  1077
# Sim           68  181   249
# All          406  920  1326
#
# Chi2: 1.5802907757499185	p-value: 0.8123300555594373	DOF: 4
# Expected_val:
# [[  329.760181   747.239819  1077.      ]
#  [   76.239819   172.760181   249.      ]
#  [  406.         920.        1326.      ]]
#
#
# Tabela de Contingência entre o desfecho e Hemoptise
#
# desfecho   TB+  TB-   All
# Hemoptise
# Não        373  862  1235
# Sim         33   58    91
# All        406  920  1326
#
# Chi2: 1.4657860758127916	p-value: 0.8326842586989696	DOF: 4
# Expected_val:
# [[  378.1372549   856.8627451  1235.       ]
#  [   27.8627451    63.1372549    91.       ]
#  [  406.          920.         1326.       ]]
#
#
# Tabela de Contingência entre o desfecho e Sudorese_noturna
#
# desfecho          TB+  TB-   All
# Sudorese_noturna
# Não               219  605   824
# Sim               187  315   502
# All               406  920  1326
#
# Chi2: 16.72862131350748	p-value: 0.0021822366715558692	DOF: 4
# Expected_val:
# [[  252.29562594   571.70437406   824.        ]
#  [  153.70437406   348.29562594   502.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Febre
#
# desfecho  TB+  TB-   All
# Febre
# Não       171  552   723
# Sim       235  368   603
# All       406  920  1326
#
# Chi2: 36.32644926950391	p-value: 2.4790218695555955e-07	DOF: 4
# Expected_val:
# [[  221.37104072   501.62895928   723.        ]
#  [  184.62895928   418.37104072   603.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Dispnéia
#
# desfecho  TB+  TB-   All
# Dispnéia
# Não       130  228   358
# Sim       276  692   968
# All       406  920  1326
#
# Chi2: 7.48561758543469	p-value: 0.11234517131672671	DOF: 4
# Expected_val:
# [[  109.61387632   248.38612368   358.        ]
#  [  296.38612368   671.61387632   968.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Perda_de_apetite
#
# desfecho          TB+  TB-   All
# Perda_de_apetite
# Não               179  480   659
# Sim               227  440   667
# All               406  920  1326
#
# Chi2: 7.3660099395832885	p-value: 0.11776490429407381	DOF: 4
# Expected_val:
# [[  201.77526395   457.22473605   659.        ]
#  [  204.22473605   462.77526395   667.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Perda_peso_10percent
#
# desfecho              TB+  TB-   All
# Perda_peso_10percent
# Não                   233  769  1002
# Sim                   173  151   324
# All                   406  920  1326
#
# Chi2: 104.70660966387351	p-value: 9.781600647093862e-22	DOF: 4
# Expected_val:
# [[  306.79638009   695.20361991  1002.        ]
#  [   99.20361991   224.79638009   324.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Dor_torácica
#
# desfecho      TB+  TB-   All
# Dor_torácica
# Não           115  250   365
# Sim           291  670   961
# All           406  920  1326
#
# Chi2: 0.1871329750919816	p-value: 0.995886358550049	DOF: 4
# Expected_val:
# [[  111.7571644   253.2428356   365.       ]
#  [  294.2428356   666.7571644   961.       ]
#  [  406.          920.         1326.       ]]
#
#
# Tabela de Contingência entre o desfecho e Internação_hospital_2anos
#
# desfecho                   TB+  TB-   All
# Internação_hospital_2anos
# Não                        359  801  1160
# Sim                         47  119   166
# All                        406  920  1326
#
# Chi2: 0.4746401927011436	p-value: 0.9759223373284371	DOF: 4
# Expected_val:
# [[  355.173454   804.826546  1160.      ]
#  [   50.826546   115.173454   166.      ]
#  [  406.         920.        1326.      ]]
#
#
# Tabela de Contingência entre o desfecho e Prisão_2anos
#
# desfecho      TB+  TB-   All
# Prisão_2anos
# Não           382  907  1289
# Sim            24   13    37
# All           406  920  1326
#
# Chi2: 21.01343168616859	p-value: 0.00031473328508679107	DOF: 4
# Expected_val:
# [[  394.67119155   894.32880845  1289.        ]
#  [   11.32880845    25.67119155    37.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Delegacia_2anos
#
# desfecho         TB+  TB-   All
# Delegacia_2anos
# Não              383  907  1290
# Sim               23   13    36
# All              406  920  1326
#
# Chi2: 19.28181161495664	p-value: 0.0006918093162252239	DOF: 4
# Expected_val:
# [[  394.97737557   895.02262443  1290.        ]
#  [   11.02262443    24.97737557    36.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Contato_TBP_2anos
#
# desfecho           TB+  TB-   All
# Contato_TBP_2anos
# Não                270  680   950
# Sim                136  240   376
# All                406  920  1326
#
# Chi2: 7.614657684755439	p-value: 0.10675836740713246	DOF: 4
# Expected_val:
# [[  290.87481146   659.12518854   950.        ]
#  [  115.12518854   260.87481146   376.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e Fuma
#
# desfecho        TB+  TB-   All
# Fuma
# Ex-fumante       98  233   331
# Fumante         132  324   456
# Jamais fumante  176  363   539
# All             406  920  1326
#
# Chi2: 1.8090722138943263	p-value: 0.9363940790976502	DOF: 6
# Expected_val:
# [[  101.34690799   229.65309201   331.        ]
#  [  139.6199095    316.3800905    456.        ]
#  [  165.0331825    373.9668175    539.        ]
#  [  406.           920.          1326.        ]]
#
#
# Tabela de Contingência entre o desfecho e CAGE
#
# desfecho  TB+  TB-   All
# CAGE
# Negativo  311  718  1029
# Positivo   95  202   297
# All       406  920  1326
#
# Chi2: 0.3372197586035285	p-value: 0.987286533447153	DOF: 4
# Expected_val:
# [[  315.06334842   713.93665158  1029.        ]
#  [   90.93665158   206.06334842   297.        ]
#  [  406.           920.          1326.        ]]

# %%
# Criando um DataFrame a partir do dicionário criado anteriormente
chi2_dict = pd.DataFrame.from_dict(dict_features,orient='index')
chi2_dict.columns = ['chi2','pval','dof','dof_real']

# Dataframe criado
chi2_dict
# Out:
#                                           chi2          pval  dof  dof_real
# CAGE                                  0.337220  9.872865e-01    4         1
# Hemoptóicos                           1.580291  8.123301e-01    4         1
# Febre                                36.326449  2.479022e-07    4         1
# Cicatriz_BCG                         18.411105  1.025453e-03    4         1
# Perda_peso_10percent                104.706610  9.781601e-22    4         1
# Tem_companheiro                       2.831757  5.863634e-01    4         1
# Dispnéia                              7.485618  1.123452e-01    4         1
# Internação_hospital_2anos             0.474640  9.759223e-01    4         1
# Prisão_2anos                         21.013432  3.147333e-04    4         1
# Estado_civil                         34.622730  3.131765e-05    8         3
# Sexo                                 26.531106  2.472477e-05    4         1
# Delegacia_2anos                      19.281812  6.918093e-04    4         1
# Dor_torácica                          0.187133  9.958864e-01    4         1
# Sudorese_noturna                     16.728621  2.182237e-03    4         1
# Raça                                  5.683932  2.240286e-01    4         1
# Hemoptise                             1.465786  8.326843e-01    4         1
# TTO_anterior_TB_triagem_enfermeiro    4.302715  3.665853e-01    4         1
# Fuma                                  1.809072  9.363941e-01    6         2
# Tosse                                 0.230857  9.938293e-01    4         1
# Expectoração                          8.494588  7.505143e-02    4         1
# Perda_de_apetite                      7.366010  1.177649e-01    4         1
# Contato_TBP_2anos                     7.614658  1.067584e-01    4         1

# %%
variaveis_dependentes = chi2_dict[chi2_dict.pval < 0.05]
variaveis_independentes = chi2_dict[chi2_dict.pval > 0.05]

# %%
variaveis_dependentes
# Out:
#                             chi2          pval  dof  dof_real
# Febre                  36.326449  2.479022e-07    4         1
# Cicatriz_BCG           18.411105  1.025453e-03    4         1
# Perda_peso_10percent  104.706610  9.781601e-22    4         1
# Prisão_2anos           21.013432  3.147333e-04    4         1
# Estado_civil           34.622730  3.131765e-05    8         3
# Sexo                   26.531106  2.472477e-05    4         1
# Delegacia_2anos        19.281812  6.918093e-04    4         1
# Sudorese_noturna       16.728621  2.182237e-03    4         1

# %%
variaveis_independentes
# Out:
#                                         chi2      pval  dof  dof_real
# CAGE                                0.337220  0.987287    4         1
# Hemoptóicos                         1.580291  0.812330    4         1
# Tem_companheiro                     2.831757  0.586363    4         1
# Dispnéia                            7.485618  0.112345    4         1
# Internação_hospital_2anos           0.474640  0.975922    4         1
# Dor_torácica                        0.187133  0.995886    4         1
# Raça                                5.683932  0.224029    4         1
# Hemoptise                           1.465786  0.832684    4         1
# TTO_anterior_TB_triagem_enfermeiro  4.302715  0.366585    4         1
# Fuma                                1.809072  0.936394    6         2
# Tosse                               0.230857  0.993829    4         1
# Expectoração                        8.494588  0.075051    4         1
# Perda_de_apetite                    7.366010  0.117765    4         1
# Contato_TBP_2anos                   7.614658  0.106758    4         1
