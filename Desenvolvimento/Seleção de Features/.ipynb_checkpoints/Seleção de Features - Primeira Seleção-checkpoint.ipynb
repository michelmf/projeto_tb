# %% [markdown]
# # Análise dos dados - Primeira seleção
#
# Este notebook mostra a análise exploratória dos dados e o processo de seleção de features para a composição do modelo computacional a ser usado como suporte à triagem de pacientes com suspeita de tuberculose.

# %%
# Manipulação dos dados
import numpy  as np
import scipy  as sp
import pandas as pd

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn           as sns
# %matplotlib inline

# %%
# Carregando os dados
data = pd.read_excel('../../Dados/Banco labels.xlsx')

# %%
# Visualização da tabela
data.head(5)
# Out:
#   TB_desfecho_final_Dri Tbafranio Obs_desfechoTB_Dri_Dani Data_inclusão  Nome  \
# 0                    TB       SIM                     NaN    2008-04-03   NaN
# 1                    TB       SIM                     NaN    2006-10-03   NaN
# 2                    TB       SIM                     NaN    2007-06-21   NaN
# 3                    TB       SIM                     NaN    2009-09-30   NaN
# 4                    TB       SIM                     NaN    2009-06-19   NaN
#
#   Desfecho_tuberculose_lista_Mauro Desfecho_TB_162_Revisão_ADRIANA  \
# 0                                9                              TB
# 1                               TB                              TB
# 2                               TB                              TB
# 3                               TB                              TB
# 4                               TB                             NaN
#
#   Observaça0_desfecho_TB Resultado_BAAR_1 Resultado_BAAR_2  \
# 0       TB PROBABILIDADE         Negativo         Negativo
# 1                    NaN         Negativo         Negativo
# 2          TB CONFIRMADA         Negativo         Negativo
# 3                    NaN         Negativo         Negativo
# 4                    NaN         Negativo         Negativo
#
#            ...          Perdeu_aula_hoje_CA Deixou_de_ganhar_dinheiro_hoje_CA  \
# 0          ...                          IGN                               IGN
# 1          ...                          IGN                               IGN
# 2          ...                          IGN                               IGN
# 3          ...                          IGN                               IGN
# 4          ...                          Não                               Não
#
#   Quanto_deixou_ganhar_CA Caso_acompanhado_quem_custeou_tudo_CA  \
# 0                Ignorado                                   IGN
# 1                Ignorado                                   IGN
# 2                Ignorado                                   IGN
# 3                Ignorado                                   IGN
# 4         "Não se aplica"                         não se aplica
#
#         Valor_CA  Avaliador_custo_CA Data_avaliação_custo_CA  \
# 0       ignorado                   9              1999-09-09
# 1       ignorado                   9              1999-09-09
# 2       ignorado                   9              1999-09-09
# 3       ignorado                   9              1999-09-09
# 4  não se aplica  Marcia  dos Santos              2009-06-19
#
#   Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER) ANO  de inclusao  \
# 0                                           Selected                  2008
# 1                                           Selected                  2006
# 2                                           Selected                  2007
# 3                                           Selected                  2009
# 4                                       Not Selected                  2009
#
#   Novocriteriotbafranio
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 281 columns]

# %%
# Tipos de dados presentes
data.dtypes.value_counts()
# Out:
# object            239
# datetime64[ns]     19
# int64              14
# float64             9
# dtype: int64

# %%
# Verificando os dados do tipo float64
print('Features do tipo float64: \n{}'.format(list(data.select_dtypes(include=['float64']).columns)))

# Verificando os dados do tipo int64
print('\nFeatures do tipo int64: \n{}'.format(list(data.select_dtypes(include=['int64']).columns)))

# Verificando os dados do tipo object
print('\nFeatures do tipo object: \n{}'.format(list(data.select_dtypes(include=['object']).columns)))

# Verificando os dados do tipo datetime64[ns]
print('\nFeatures do tipo datetime64[ns]: \n{}'.format(list(data.select_dtypes(include=['datetime64[ns]']).columns)))
# Out:
# Features do tipo float64:
# ['Nome', 'Prontuário_PAAP', 'Número_cultura', 'Número_cultura_segunda_amostra', 'N°_TB', 'Peso_habitual', 'Peso_atual', 'Altura_cm', 'Valor_comida_bebida_CA']
#
# Features do tipo int64:
# ['Probabilidade_TBP_sem_RX_ou_BAAR', 'Probabilidade_TBP_com_RX_e_BAAR', 'Número_geral', 'Idade', 'Telefone_1', 'Telefone_2', 'CEP', 'Valor_pts_escore', 'Descrever_outros_fármacos', 'Valor_pernoite_CA', 'Valor_algo_CA', 'Valor_algo_posto_CA', 'ANO  de inclusao', 'Novocriteriotbafranio']
#
# Features do tipo object:
# ['TB_desfecho_final_Dri', 'Tbafranio', 'Obs_desfechoTB_Dri_Dani', 'Desfecho_tuberculose_lista_Mauro', 'Desfecho_TB_162_Revisão_ADRIANA', 'Observaça0_desfecho_TB', 'Resultado_BAAR_1', 'Resultado_BAAR_2', 'Resultado_Cultutra_1', 'Resultado_Cultura_2', 'identificado_tb_ntb', 'Houve_desfecho_consulta_médica__inicial', 'Compareceram_consulta_medica', 'TTO_TB_confirmação_bacteriológica', 'TTO_TB_probabilidade', 'Transferência_internação_não_TB_outra_especialidade', 'TTO_pneumologia_patologia_não_TB', 'Alta', 'Descrever_outra_patologia', 'Asma', 'Em_caso_tto_TB_marcar_opções', 'TTO_anterior_TB_triagem_enfermeiro', 'Fator_risco_TBP_MDR', 'Médico_avaliador', 'Cavitação_alta_média_probabilidade', 'RX_Padrão_TÍPICO_alta_média_probabilidade', 'RX_padrão_COMPATIVEL_alta_média_probabilidade', 'RX_Padrão_ATÍPICO_alta_média_probabilidade', 'RX_baixa_probabilidade_TB_INATIVA_SEQUELA', 'RX_baixa_probabilidade_TB_OUTRA_DOENÇA2', 'RX_baixa_probabilidade_NORMAL', 'Data_RX', 'Tto_TB_prescrito', 'Rifampicina_TTO_TB', 'Isoniazida_TTO_TB', 'Pirazinamida_TTO_TB', 'Etambutol_TTO_TB', 'Espécime_1', 'Espécime_2', 'Número_cruzes_BAAR_1', 'Número_cruzes_BAAR_2', 'Resultado_BAAR_Final', 'Número_Cruzes_Cultura_1', 'Número_cruzes_Cultura_2', 'Escore_Cat', 'Probabilidade_médica_TB_ativa', 'Probabilidade_TBP_com_RX', 'Probabilidade_TBP_comRX_e_sem_BAAR', 'Probabilidade_TBP_com_RX_sem_BAAR_percent', 'Probabilidade_TBP_com_2_BAAR_negativos', 'Resultado_cultura_final', 'Realizou_RX', 'Karen_amostra', 'TSA', 'Óbito', 'Causa_óbito', 'Número_laboratório', 'Detect_TB_Primeira_amostra', 'Detect_TB_Segunda_amostra', 'Biometrix_inserido_tabela_por_nomes', 'Resultado_biometrix_CTMtb', 'Resultados_biometrix_CTinterno', 'Resultado_biometrix_bula', 'Cicatriz_BCG', 'Desfecho_TB', 'Tto_anterior_TB_avaliação_médica', 'Tto_anterior_TB_INH', 'Tto_anterior_TB_RIF', 'Esquema_utilizado_tto_anterior', 'Quimio_prévia', 'Quimio_INH', 'Quimio_RIF', 'Desfecho_quimio', 'HIV', 'Comorbidades', 'Nome_mãe', 'Endereço2', 'Bairro_Residência', 'Cidade_residência', 'Naturalidade_cidade', 'Naturalidade_estado2', 'Mora_no_Rio_há_quantos_anos', 'Sexo', 'Raça', 'Raça_2', 'Estado_civil', 'Tem_companheiro', 'Tosse', 'Semanas_tosse', 'Expectoração', 'Semanas_expectoração', 'Hemoptóicos', 'Semanas_hemoptóicos', 'Hemoptise', 'Semanas_hemoptise', 'Quantidade_hemoptise', 'Sudorese_noturna', 'Semanas_sudorese', 'Febre', 'Semanas_febre', 'Dispnéia', 'Dispnéia_semanas', 'Perda_de_apetite', 'Perda_apetite_semanas', 'Perda_peso_10percent', 'Perda_peso_semanas', 'Dor_torácica', 'Dor_torácica_semanas', 'Total_escore_Paulo', 'Internação_hospital_2anos', 'Prisão_2anos', 'Delegacia_2anos', 'Contato_TBP_2anos', 'TBP_Morava_com_vc', 'TBP_trabalhava_com_vc', 'TBP_amigo_parente_não_morava_com_vc', 'Contato_TBP_menor_3anos', 'Contato_TBP_Casa', 'Contato_TBP_Trabalho', 'Contato_TBP_Social', 'Fuma', 'Número_cigarros_dia', 'Número_anos', 'Cerveja', 'Vinho', 'Whisky', 'Cachaça', 'Outras_bebidas_alcoólicas', 'Nenhuma_bebida_alcoólica', 'CAGE', 'Desfecho_enfermeiro', 'Descrever_outros_defechos', 'Incluído_TB_Adapt', 'Critério_1_TB_Adapt_tosse_por_mais_2_semanas', 'Critério_2_TB_Adapt_assinou_TCLE', 'Aplicou_PPD', 'Leu_PT', 'Resultado_PPT_mm', 'Leitor_PT', 'Enfemeiro_avaliação', 'IRC', 'Hepatopatia', 'Etilismo', 'Uso_corticoide', 'Neo_maligna', 'Transplante', 'DM_NID', 'DM_ID', 'Silicose', 'DPOC', 'Doença_pumonar_difusa', 'Outras', 'descrever_outras_comorbidades2', 'Critério_de_entrada_perfil_bacteriologico_Fup', 'Etionamida_TTO_TB', 'Estreptomicina_TTO_TB', 'Ofolxacino_TTO_TB', 'Outros_fármacos', 'Reação_Adversa_Fármacos_TTO_TB', 'Reação_adversa_maior', 'Exantema', 'Confusão_mental', 'Icterícia', 'Hepatotoxicidade', 'Vertigem', 'Hipoacusia', 'Crise_convulsiva', 'Encefalopatia', 'Psicose', 'Neurite_óptica', 'Plaquetopenia_leucopenia_eosinofilia', 'Anemia_hemolítica_vasculite', 'Choque_púrpura', 'Nefrite', 'Insuficiência_renal_rabdomiólise', 'Reação_adversa_menor', 'Prurido', 'Anorexia', 'Náuseas_vômitos', 'Dor_abdominal', 'Dor_ar ...
#
# Features do tipo datetime64[ns]:
# ['Data_inclusão', 'Data_avaliação_médica', 'Data_início_TTO', 'Data_coleta_escarro_1', 'Data_coleta_escarro_2', 'VAR00003', 'Data_TB_passado', 'Data_quimio', 'Data_nascimento', 'Data_assinatura_TCLE', 'Data_aplicação__PT', 'Data_leitura_PT', 'Data_avaliação', 'Data_HIV', 'Data_mudança', 'Data_RX_Fup', 'Data_anti_HIV', 'Data_Fup', 'Data_avaliação_custo_CA']

# %% [markdown]
# ## Seleção de features
#
# Durante o período de coleta de informações dos pacientes, várias informações sobre o tratamento foram coletadas, tais como datas de exames, sintomas, resultados de exames, entre outras informações. Nem todas as informações coletadas no estudo são úteis para a composição do Sistema de Apoio à Decisão(SAD), objetivo desse estudo. Dessa forma, features desnecessárias e não correlacionadas com a doença serão ignoradas para a composição do sistema.

# %% [markdown]
# ### Seleção de features: primeiro filtro
#
# A primeira avaliação de features é realizada de forma manual, tendo como objetivo eliminar variáveis que, obviamente, não possuem informação sobre a predição da doença. Tais variáveis a serem eliminadas são: informações pessoais do paciente, datas de exames, profissional avaliador, entre outras.

# %% [markdown]
# #### Features do tipo datetime64[ns]
#
# Features do tipo <i>datetime64[ns]</i> representam datas de exames e procedimentos. Tais informações são irrelevantes para o estudo em questão, e podem ser removidas qualquer prejuízo.
#
# Dessa forma, <b>19 features</b> podem ser eliminadas.

# %% [markdown]
# #### Features do tipo float64 e int64

# %% [markdown]
# As features do tipo float64 e int64 representam informações representadas em números, colhidas durante o estudo. De acordo com os atributos mostrados anteriormente, somente informações sobre idade, peso e altura serão considerados para análise futuras.
#
# - Features não removidas: 'Peso_habitual', 'Peso_atual', 'Altura_cm', 'Idade'
# - Dessa forma, as seguintes features são desconsideradas: 'Nome', 'Prontuário_PAAP', 'Número_cultura', 'Número_cultura_segunda_amostra', 'N°_TB', 'Valor_comida_bebida_CA', 'Probabilidade_TBP_sem_RX_ou_BAAR', 'Probabilidade_TBP_com_RX_e_BAAR', 'Número_geral', 'Telefone_1', 'Telefone_2', 'CEP', 'Valor_pts_escore', 'Descrever_outros_fármacos', 'Valor_pernoite_CA', 'Valor_algo_CA', 'Valor_algo_posto_CA', 'ANO  de inclusao', 'Novocriteriotbafranio'
#
# Ao todo, <b>19 features</b> foram desconsideradas.

# %% [markdown]
# #### Features do tipo Object
#
# Features consideradas do tipo Object são informações armazenadas como strings no banco de dados. As features a serem desconsideradas seguem o mesmo critério de seleção descrito anteriormente.

# %% [markdown]
# ##### Desfecho ou target
#
# Somente a feature <i>TB_desfecho_final_Dri</i> é considerada como o target ou desfecho do estudo, enquanto os outros atributos serão desconsiderados.
#
# - Feature considera como desfecho: <i>TB_desfecho_final_Dri</i>
# - Features desconsideradas (9 features): 'Tbafranio', 'Obs_desfechoTB_Dri_Dani', 'Data_inclusão','Desfecho_tuberculose_lista_Mauro', 'Desfecho_TB_162_Revisão_ADRIANA', 'Observaça0_desfecho_TB','Desfecho_enfermeiro', 'Descrever_outros_defechos', 'Desfecho_TB'

# %% [markdown]
# ##### Outras features presentes do tipo Object
#
# As seguintes features foram desconsideradas nesse momento:
#
# - Features relacionadas à informações pessoais do paciente, que não são relevantes para diagnóstico, além de informações relacionadas a profissionais encarregados de procedimentos médicos (61 features): 'Onde_vc_mora_CA', 'Transporte_CA', 'Custo_transporte_reais_CA', 'Acompanhado_CA', 'Número_pessoas_CA', 'Horas_saiu_de_casa_CA', 'Horas_Chegou_posto_CA', 'Horas_viu_profissional_CA', 'Tempo_até_o_posto_minutos_CA', 'Caso_FORA_DO_RJ_retorno_onde_pernoitar_CA', 'Pagará_pernoite', 'Trouxe_algo_amigos_CA', 'Comeu_bebeu_CA', 'Pagou_algo_no_posto_CA', 'Profissão_CA', 'Perdeu_aula_hoje_CA', 'Deixou_de_ganhar_dinheiro_hoje_CA', 'Quanto_deixou_ganhar_CA', 'Caso_acompanhado_quem_custeou_tudo_CA', 'Valor_CA','Nome_mãe', 'Endereço2', 'Bairro_Residência', 'Cidade_residência', 'Naturalidade_cidade', 'Naturalidade_estado2', 'Mora_no_Rio_há_quantos_anos', 'Avaliador_custo_CA', 'Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER)', 'Karen\_amostra', 'Óbito', 'Causa_óbito', 'Número_laboratório', 'Biometrix_inserido_tabela_por_nomes', 'Resultado_biometrix_CTMtb', 'Resultados_biometrix_CTinterno', 'Resultado_biometrix_bula', 'Total_escore_Paulo', 'Leitor_PT', 'Enfemeiro_avaliação','Motivo_mudança','Descrever_outro_motivo_mudança','Médico_avaliador_Fup', 'Médico_avaliador_Fup', 'HIV_teste_Fup', 'Diagnóstico_90_dias', 'Outro_diagnóstico_Fup', 'Descrever_outro_diagnóstico','Motivo_mudança', 'Descrever_outro_motivo_mudança', 'Peso_atual_Fup', 'Médico_avaliador', 'Descrever_outra_patologia', 'Compareceram_consulta_medica','Escore_Cat', 'Data_RX', 'Esquema_utilizado_tto_anterior', 'Em_caso_tto_TB_marcar_opções',  'Mudança_esquema_tto_TB', 'Outros_farmacos_mudança_tto2', 'Descrever_outros_farmacos_mudança_tto2'
#
# - Features representando a probabilidade da doença presente. Essas probabilidades são estimadas de acordo com os dados obtidos durante o projeto, portanto podem ser consideradas como redundantes(15 features): 'Probabilidade_TB_com_RX_Fup', 'TTO_TB_probabilidade','Probabilidade_TB_com_RX_Fup','Cavitação_alta_média_probabilidade', 'RX_Padrão_TÍPICO_alta_média_probabilidade', 'RX_padrão_COMPATIVEL_alta_média_probabilidade', 'RX_Padrão_ATÍPICO_alta_média_probabilidade', 'RX_baixa_probabilidade_TB_INATIVA_SEQUELA', 'RX_baixa_probabilidade_TB_OUTRA_DOENÇA2', 'RX_baixa_probabilidade_NORMAL','Probabilidade_médica_TB_ativa',
# 'Probabilidade_TBP_com_RX', 'Probabilidade_TBP_comRX_e_sem_BAAR', 'Probabilidade_TBP_com_RX_sem_BAAR_percent', 'Probabilidade_TBP_com_2_BAAR_negativos'
#
#
# Ao todo, <b>85 features</b> foram desconsideradas.

# %% [markdown]
# #### Resumo da primeira avaliação
#
# Ao todo, 118 features foram desconsideras na primeira filtragem, realizada manualmente. Dessa forma, de 280 variáveis presentes(desconsiderando o desfecho), existem 163 features a serem avaliadas.

# %%
features_filtradas = ['Data_inclusão', 'Data_avaliação_médica', 'Data_início_TTO', 'Data_coleta_escarro_1', 'Data_coleta_escarro_2', 
                      'VAR00003', 'Data_TB_passado', 'Data_quimio', 'Data_nascimento', 'Data_assinatura_TCLE', 'Data_aplicação__PT', 
                      'Data_leitura_PT', 'Data_avaliação', 'Data_HIV', 'Data_mudança', 'Data_RX_Fup', 'Data_anti_HIV', 'Data_Fup', 
                      'Data_avaliação_custo_CA', 'Nome', 'Prontuário_PAAP', 'Número_cultura', 'Número_cultura_segunda_amostra', 
                      'N°_TB', 'Valor_comida_bebida_CA', 'Probabilidade_TBP_sem_RX_ou_BAAR', 'Probabilidade_TBP_com_RX_e_BAAR', 
                      'Número_geral', 'Telefone_1', 'Telefone_2','ANO  de inclusao', 'CEP', 'Valor_pts_escore', 'Descrever_outros_fármacos', 'Valor_pernoite_CA', 
                      'Valor_algo_CA', 'Valor_algo_posto_CA','Novocriteriotbafranio', 'Tbafranio', 'Obs_desfechoTB_Dri_Dani', 
                      'Data_inclusão','Desfecho_tuberculose_lista_Mauro', 'Desfecho_TB_162_Revisão_ADRIANA', 'Observaça0_desfecho_TB','Desfecho_enfermeiro', 
                      'Descrever_outros_defechos', 'Desfecho_TB','Onde_vc_mora_CA', 'Transporte_CA', 'Custo_transporte_reais_CA', 'Acompanhado_CA', 
                      'Número_pessoas_CA', 'Horas_saiu_de_casa_CA', 'Horas_Chegou_posto_CA', 'Horas_viu_profissional_CA', 'Tempo_até_o_posto_minutos_CA', 
                      'Caso_FORA_DO_RJ_retorno_onde_pernoitar_CA', 'Pagará_pernoite', 'Trouxe_algo_amigos_CA', 'Comeu_bebeu_CA', 'Pagou_algo_no_posto_CA', 
                      'Profissão_CA', 'Perdeu_aula_hoje_CA', 'Deixou_de_ganhar_dinheiro_hoje_CA', 'Quanto_deixou_ganhar_CA', 'Caso_acompanhado_quem_custeou_tudo_CA', 
                      'Valor_CA','Nome_mãe', 'Endereço2', 'Bairro_Residência', 'Cidade_residência', 'Naturalidade_cidade', 'Naturalidade_estado2', 
                      'Mora_no_Rio_há_quantos_anos', 'Avaliador_custo_CA', 'Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER)', 'Karen_amostra', 'Óbito', 
                      'Causa_óbito', 'Número_laboratório', 'Biometrix_inserido_tabela_por_nomes', 'Resultado_biometrix_CTMtb', 'Resultados_biometrix_CTinterno', 
                      'Resultado_biometrix_bula', 'Total_escore_Paulo', 'Leitor_PT', 'Enfemeiro_avaliação','Motivo_mudança','Descrever_outro_motivo_mudança', 
                      'Médico_avaliador_Fup', 'Médico_avaliador_Fup', 'HIV_teste_Fup', 'Diagnóstico_90_dias', 'Outro_diagnóstico_Fup', 'Descrever_outro_diagnóstico',
                      'Motivo_mudança', 'Descrever_outro_motivo_mudança', 'Peso_atual_Fup', 'Médico_avaliador', 'Descrever_outra_patologia', 
                      'Compareceram_consulta_medica','Escore_Cat', 'Data_RX', 'Esquema_utilizado_tto_anterior', 'Em_caso_tto_TB_marcar_opções', 'Mudança_esquema_tto_TB', 
                      'Outros_farmacos_mudança_tto2', 'Descrever_outros_farmacos_mudança_tto2','Probabilidade_TB_com_RX_Fup', 'TTO_TB_probabilidade',
                      'Probabilidade_TB_com_RX_Fup','Cavitação_alta_média_probabilidade', 'RX_Padrão_TÍPICO_alta_média_probabilidade', 
                      'RX_padrão_COMPATIVEL_alta_média_probabilidade', 'RX_Padrão_ATÍPICO_alta_média_probabilidade', 'RX_baixa_probabilidade_TB_INATIVA_SEQUELA', 
                      'RX_baixa_probabilidade_TB_OUTRA_DOENÇA2', 'RX_baixa_probabilidade_NORMAL','Probabilidade_médica_TB_ativa', 'Probabilidade_TBP_com_RX', 
                      'Probabilidade_TBP_comRX_e_sem_BAAR', 'Probabilidade_TBP_com_RX_sem_BAAR_percent', 'Probabilidade_TBP_com_2_BAAR_negativos']

dados_filtrados = data.drop(features_filtradas,axis=1)

# %%
# Dados presentes
dados_filtrados.dtypes.value_counts()
# Out:
# object     159
# float64      3
# int64        1
# dtype: int64

# %%
# Verificando os dados do tipo float64
print('Features do tipo float64: \n{}'.format(list(dados_filtrados.select_dtypes(include=['float64']).columns)))

# Verificando os dados do tipo int64
print('\nFeatures do tipo int64: \n{}'.format(list(dados_filtrados.select_dtypes(include=['int64']).columns)))

# Verificando os dados do tipo object
print('\nFeatures do tipo object: \n{}'.format(list(dados_filtrados.select_dtypes(include=['object']).columns)))
# Out:
# Features do tipo float64:
# ['Peso_habitual', 'Peso_atual', 'Altura_cm']
#
# Features do tipo int64:
# ['Idade']
#
# Features do tipo object:
# ['TB_desfecho_final_Dri', 'Resultado_BAAR_1', 'Resultado_BAAR_2', 'Resultado_Cultutra_1', 'Resultado_Cultura_2', 'identificado_tb_ntb', 'Houve_desfecho_consulta_médica__inicial', 'TTO_TB_confirmação_bacteriológica', 'Transferência_internação_não_TB_outra_especialidade', 'TTO_pneumologia_patologia_não_TB', 'Alta', 'Asma', 'TTO_anterior_TB_triagem_enfermeiro', 'Fator_risco_TBP_MDR', 'Tto_TB_prescrito', 'Rifampicina_TTO_TB', 'Isoniazida_TTO_TB', 'Pirazinamida_TTO_TB', 'Etambutol_TTO_TB', 'Espécime_1', 'Espécime_2', 'Número_cruzes_BAAR_1', 'Número_cruzes_BAAR_2', 'Resultado_BAAR_Final', 'Número_Cruzes_Cultura_1', 'Número_cruzes_Cultura_2', 'Resultado_cultura_final', 'Realizou_RX', 'TSA', 'Detect_TB_Primeira_amostra', 'Detect_TB_Segunda_amostra', 'Cicatriz_BCG', 'Tto_anterior_TB_avaliação_médica', 'Tto_anterior_TB_INH', 'Tto_anterior_TB_RIF', 'Quimio_prévia', 'Quimio_INH', 'Quimio_RIF', 'Desfecho_quimio', 'HIV', 'Comorbidades', 'Sexo', 'Raça', 'Raça_2', 'Estado_civil', 'Tem_companheiro', 'Tosse', 'Semanas_tosse', 'Expectoração', 'Semanas_expectoração', 'Hemoptóicos', 'Semanas_hemoptóicos', 'Hemoptise', 'Semanas_hemoptise', 'Quantidade_hemoptise', 'Sudorese_noturna', 'Semanas_sudorese', 'Febre', 'Semanas_febre', 'Dispnéia', 'Dispnéia_semanas', 'Perda_de_apetite', 'Perda_apetite_semanas', 'Perda_peso_10percent', 'Perda_peso_semanas', 'Dor_torácica', 'Dor_torácica_semanas', 'Internação_hospital_2anos', 'Prisão_2anos', 'Delegacia_2anos', 'Contato_TBP_2anos', 'TBP_Morava_com_vc', 'TBP_trabalhava_com_vc', 'TBP_amigo_parente_não_morava_com_vc', 'Contato_TBP_menor_3anos', 'Contato_TBP_Casa', 'Contato_TBP_Trabalho', 'Contato_TBP_Social', 'Fuma', 'Número_cigarros_dia', 'Número_anos', 'Cerveja', 'Vinho', 'Whisky', 'Cachaça', 'Outras_bebidas_alcoólicas', 'Nenhuma_bebida_alcoólica', 'CAGE', 'Incluído_TB_Adapt', 'Critério_1_TB_Adapt_tosse_por_mais_2_semanas', 'Critério_2_TB_Adapt_assinou_TCLE', 'Aplicou_PPD', 'Leu_PT', 'Resultado_PPT_mm', 'IRC', 'Hepatopatia', 'Etilismo', 'Uso_corticoide', 'Neo_maligna', 'Transplante', 'DM_NID', 'DM_ID', 'Silicose', 'DPOC', 'Doença_pumonar_difusa', 'Outras', 'descrever_outras_comorbidades2', 'Critério_de_entrada_perfil_bacteriologico_Fup', 'Etionamida_TTO_TB', 'Estreptomicina_TTO_TB', 'Ofolxacino_TTO_TB', 'Outros_fármacos', 'Reação_Adversa_Fármacos_TTO_TB', 'Reação_adversa_maior', 'Exantema', 'Confusão_mental', 'Icterícia', 'Hepatotoxicidade', 'Vertigem', 'Hipoacusia', 'Crise_convulsiva', 'Encefalopatia', 'Psicose', 'Neurite_óptica', 'Plaquetopenia_leucopenia_eosinofilia', 'Anemia_hemolítica_vasculite', 'Choque_púrpura', 'Nefrite', 'Insuficiência_renal_rabdomiólise', 'Reação_adversa_menor', 'Prurido', 'Anorexia', 'Náuseas_vômitos', 'Dor_abdominal', 'Dor_articular', 'Neurite_periférica', 'Euforia', 'Insônia_sonolência', 'Ansiedade', 'Cefaléia', 'Acne', 'Hiperuricemia', 'Febre_AD', 'Hipotensão_ortostática', 'Ginecomastia', 'Rifampicina_mudança_tto', 'Pirazinamida_mudança_tto', 'Isoniazida_mudança_tto', 'Etambutol_mudança_tto', 'Etionamida_mudança_tto', 'Estreptomicina_mudança_tto', 'Ofloxacino_mudança_tto', 'Tosse_diminuída', 'Cavitação__RX_Fup_Alta_média', 'Padrão_RX_TIPICO_Fup_Alta_média', 'Padrão_RX_COMPATIVEL_Fup_Alta_Média', 'Padrão_RX_ATIPICO_Fup_Alta_Media', 'Padrão_RX_Fup_Baixa', 'Fup_RX']

# %% [markdown]
# ### Seleção de features: segundo filtro
#
# Features que são resultados de exames (tais como baciloscopia, cultura, raio-X e outros) não podem ser utilizadas como atributos em um processo de triagem de pacientes. Outras features que representam fármacos utilizados durante o tratamento de pacientes com TB positiva também são descartadas.
#
# Features desconsideradas (51 features): 'Resultado_BAAR_1', 'Resultado_BAAR_2', 'Resultado_Cultutra_1', 'Resultado_Cultura_2', 'identificado_tb_ntb', 'Houve_desfecho_consulta_médica__inicial', 'TTO_TB_confirmação_bacteriológica', 'Transferência_internação_não_TB_outra_especialidade', 'TTO_pneumologia_patologia_não_TB', 'Alta', 'Número_cruzes_BAAR_1', 'Número_cruzes_BAAR_2', 'Resultado_BAAR_Final', 'Número_Cruzes_Cultura_1', 'Número_cruzes_Cultura_2', 'Resultado_cultura_final', 'Realizou_RX', 'TSA', 'Detect_TB_Primeira_amostra', 'Detect_TB_Segunda_amostra', 'Cavitação__RX_Fup_Alta_média', 'Padrão_RX_TIPICO_Fup_Alta_média', 'Padrão_RX_COMPATIVEL_Fup_Alta_Média', 'Padrão_RX_ATIPICO_Fup_Alta_Media', 'Padrão_RX_Fup_Baixa', 'Fup_RX', 'Fator_risco_TBP_MDR','Número_anos', 'Resultado_PPT_mm', 'Critério_de_entrada_perfil_bacteriologico_Fup', 'Outros_fármacos', 'Reação_Adversa_Fármacos_TTO_TB', 'Reação_adversa_maior', 'Reação_adversa_menor', 'Rifampicina_mudança_tto', 'Pirazinamida_mudança_tto', 'Isoniazida_mudança_tto', 'Etambutol_mudança_tto', 'Etionamida_mudança_tto', 'Estreptomicina_mudança_tto', 'Ofloxacino_mudança_tto', 'Tosse_diminuída', 'Incluído_TB_Adapt', 'Critério_1_TB_Adapt_tosse_por_mais_2_semanas', 'Critério_2_TB_Adapt_assinou_TCLE', 'Aplicou_PPD', 'Leu_PT', 'Outras', 'descrever_outras_comorbidades2','Espécime_1', 'Espécime_2'

# %% [markdown]
# #### Resumo da segunda avaliação
#
# Ao final da segunda avaliação, mais 51 features foram eliminadas. Assim, 112 atributos ainda necessitam ser avaliados.

# %%
features_filtradas     = ['Resultado_BAAR_1', 'Resultado_BAAR_2', 'Resultado_Cultutra_1', 'Resultado_Cultura_2', 'identificado_tb_ntb', 
                          'Houve_desfecho_consulta_médica__inicial', 'TTO_TB_confirmação_bacteriológica', 'Transferência_internação_não_TB_outra_especialidade', 
                          'TTO_pneumologia_patologia_não_TB', 'Alta', 'Número_cruzes_BAAR_1', 'Número_cruzes_BAAR_2', 'Resultado_BAAR_Final', 
                          'Número_Cruzes_Cultura_1', 'Número_cruzes_Cultura_2', 'Resultado_cultura_final', 'Realizou_RX', 'TSA', 'Detect_TB_Primeira_amostra', 
                          'Detect_TB_Segunda_amostra', 'Cavitação__RX_Fup_Alta_média', 'Padrão_RX_TIPICO_Fup_Alta_média', 'Padrão_RX_COMPATIVEL_Fup_Alta_Média', 
                          'Padrão_RX_ATIPICO_Fup_Alta_Media', 'Padrão_RX_Fup_Baixa', 'Fup_RX', 'Fator_risco_TBP_MDR','Número_anos', 'Resultado_PPT_mm', 
                          'Critério_de_entrada_perfil_bacteriologico_Fup', 'Outros_fármacos', 'Reação_Adversa_Fármacos_TTO_TB', 'Reação_adversa_maior', 
                          'Reação_adversa_menor', 'Rifampicina_mudança_tto', 'Pirazinamida_mudança_tto', 'Isoniazida_mudança_tto', 'Etambutol_mudança_tto', 
                          'Etionamida_mudança_tto', 'Estreptomicina_mudança_tto', 'Ofloxacino_mudança_tto', 'Tosse_diminuída', 'Incluído_TB_Adapt', 
                          'Critério_1_TB_Adapt_tosse_por_mais_2_semanas', 'Critério_2_TB_Adapt_assinou_TCLE', 'Aplicou_PPD', 'Leu_PT', 'Outras', 
                          'descrever_outras_comorbidades2','Espécime_1', 'Espécime_2'] 

dados_filtrados = dados_filtrados.drop(features_filtradas,axis=1)

# %%
# Dados presentes
dados_filtrados.dtypes.value_counts()
# Out:
# object     108
# float64      3
# int64        1
# dtype: int64

# %%
# Verificando os dados do tipo float64
print('Features do tipo float64: \n{}'.format(list(dados_filtrados.select_dtypes(include=['float64']).columns)))

# Verificando os dados do tipo int64
print('\nFeatures do tipo int64: \n{}'.format(list(dados_filtrados.select_dtypes(include=['int64']).columns)))

# Verificando os dados do tipo object
print('\nFeatures do tipo object: \n{}'.format(list(dados_filtrados.select_dtypes(include=['object']).columns)))
# Out:
# Features do tipo float64:
# ['Peso_habitual', 'Peso_atual', 'Altura_cm']
#
# Features do tipo int64:
# ['Idade']
#
# Features do tipo object:
# ['TB_desfecho_final_Dri', 'Asma', 'TTO_anterior_TB_triagem_enfermeiro', 'Tto_TB_prescrito', 'Rifampicina_TTO_TB', 'Isoniazida_TTO_TB', 'Pirazinamida_TTO_TB', 'Etambutol_TTO_TB', 'Cicatriz_BCG', 'Tto_anterior_TB_avaliação_médica', 'Tto_anterior_TB_INH', 'Tto_anterior_TB_RIF', 'Quimio_prévia', 'Quimio_INH', 'Quimio_RIF', 'Desfecho_quimio', 'HIV', 'Comorbidades', 'Sexo', 'Raça', 'Raça_2', 'Estado_civil', 'Tem_companheiro', 'Tosse', 'Semanas_tosse', 'Expectoração', 'Semanas_expectoração', 'Hemoptóicos', 'Semanas_hemoptóicos', 'Hemoptise', 'Semanas_hemoptise', 'Quantidade_hemoptise', 'Sudorese_noturna', 'Semanas_sudorese', 'Febre', 'Semanas_febre', 'Dispnéia', 'Dispnéia_semanas', 'Perda_de_apetite', 'Perda_apetite_semanas', 'Perda_peso_10percent', 'Perda_peso_semanas', 'Dor_torácica', 'Dor_torácica_semanas', 'Internação_hospital_2anos', 'Prisão_2anos', 'Delegacia_2anos', 'Contato_TBP_2anos', 'TBP_Morava_com_vc', 'TBP_trabalhava_com_vc', 'TBP_amigo_parente_não_morava_com_vc', 'Contato_TBP_menor_3anos', 'Contato_TBP_Casa', 'Contato_TBP_Trabalho', 'Contato_TBP_Social', 'Fuma', 'Número_cigarros_dia', 'Cerveja', 'Vinho', 'Whisky', 'Cachaça', 'Outras_bebidas_alcoólicas', 'Nenhuma_bebida_alcoólica', 'CAGE', 'IRC', 'Hepatopatia', 'Etilismo', 'Uso_corticoide', 'Neo_maligna', 'Transplante', 'DM_NID', 'DM_ID', 'Silicose', 'DPOC', 'Doença_pumonar_difusa', 'Etionamida_TTO_TB', 'Estreptomicina_TTO_TB', 'Ofolxacino_TTO_TB', 'Exantema', 'Confusão_mental', 'Icterícia', 'Hepatotoxicidade', 'Vertigem', 'Hipoacusia', 'Crise_convulsiva', 'Encefalopatia', 'Psicose', 'Neurite_óptica', 'Plaquetopenia_leucopenia_eosinofilia', 'Anemia_hemolítica_vasculite', 'Choque_púrpura', 'Nefrite', 'Insuficiência_renal_rabdomiólise', 'Prurido', 'Anorexia', 'Náuseas_vômitos', 'Dor_abdominal', 'Dor_articular', 'Neurite_periférica', 'Euforia', 'Insônia_sonolência', 'Ansiedade', 'Cefaléia', 'Acne', 'Hiperuricemia', 'Febre_AD', 'Hipotensão_ortostática', 'Ginecomastia']

# %% [markdown]
# ### Seleção de features: Terceiro filtro
#
# Features com números superiores a 30% de ignorados serão descartadas.

# %%
# Alterando o nome do atributo TB_desfecho_final_Dri para desfecho
dados_filtrados.rename(index=str,columns={'TB_desfecho_final_Dri':'desfecho'},inplace=True)

# Renomeando os labels do desfecho
dados_filtrados['desfecho'].replace(['Não TB','TB',8,'IGN'],['TB-','TB+','ignorado','ignorado'],inplace=True)

# Dados somente de diagnósticos conhecidos: TB+/-
dados_filtrados = dados_filtrados[(dados_filtrados.desfecho == 'TB-') | (dados_filtrados.desfecho == 'TB+')]

# Renomeando os labels do desfecho
dados_filtrados.replace([np.nan,'IGN'],['ignorado','ignorado'],inplace=True)

# %%
# Mostrando a proporção de valores para cada feature 
for feature in list(dados_filtrados.columns):
    
    values = (dados_filtrados[feature].value_counts(dropna=False)/len(dados_filtrados))    
    print('Feature ' + feature)
    print(100 * values)
    print()
# Out:
# Feature desfecho
# TB-    68.060139
# TB+    31.939861
# Name: desfecho, dtype: float64
#
# Feature Asma
# ignorado    86.982032
# Não          9.460946
# Sim          3.557022
# Name: Asma, dtype: float64
#
# Feature TTO_anterior_TB_triagem_enfermeiro
# Não         75.394206
# Sim         24.019069
# ignorado     0.586725
# Name: TTO_anterior_TB_triagem_enfermeiro, dtype: float64
#
# Feature Tto_TB_prescrito
# ignorado    74.330766
# Sim         17.161716
# Não          8.507517
# Name: Tto_TB_prescrito, dtype: float64
#
# Feature Rifampicina_TTO_TB
# ignorado           69.783645
# Sim                16.538320
# "não se aplica"    13.531353
# Não                 0.146681
# Name: Rifampicina_TTO_TB, dtype: float64
#
# Feature Isoniazida_TTO_TB
# ignorado           69.783645
# Sim                16.538320
# "não se aplica"    13.531353
# Não                 0.146681
# Name: Isoniazida_TTO_TB, dtype: float64
#
# Feature Pirazinamida_TTO_TB
# ignorado           69.746975
# Sim                16.685002
# "não se aplica"    13.531353
# Não                 0.036670
# Name: Pirazinamida_TTO_TB, dtype: float64
#
# Feature Etambutol_TTO_TB
# ignorado           69.966997
# "não se aplica"    13.604694
# Não                13.054639
# Sim                 3.373671
# Name: Etambutol_TTO_TB, dtype: float64
#
# Feature Cicatriz_BCG
# Sim         44.517785
# Não         30.656399
# ignorado    24.825816
# Name: Cicatriz_BCG, dtype: float64
#
# Feature Tto_anterior_TB_avaliação_médica
# ignorado    44.994499
# Não         41.364136
# Sim         13.641364
# Name: Tto_anterior_TB_avaliação_médica, dtype: float64
#
# Feature Tto_anterior_TB_INH
# ignorado    88.888889
# Sim         11.001100
# Não          0.110011
# Name: Tto_anterior_TB_INH, dtype: float64
#
# Feature Tto_anterior_TB_RIF
# ignorado    88.962230
# Sim         10.891089
# Não          0.146681
# Name: Tto_anterior_TB_RIF, dtype: float64
#
# Feature Quimio_prévia
# Não         54.785479
# ignorado    45.141181
# Sim          0.073341
# Name: Quimio_prévia, dtype: float64
#
# Feature Quimio_INH
# ignorado    99.926659
# Não          0.036670
# Sim          0.036670
# Name: Quimio_INH, dtype: float64
#
# Feature Quimio_RIF
# ignorado    100.0
# Name: Quimio_RIF, dtype: float64
#
# Feature Desfecho_quimio
# ignorado     99.96333
# Abandonou     0.03667
# Name: Desfecho_quimio, dtype: float64
#
# Feature HIV
# Não realizado/Desconhecido    48.111478
# ignorado                      45.287862
# Positivo                       3.337000
# Negativo                       3.263660
# Name: HIV, dtype: float64
#
# Feature Comorbidades
# ignorado    43.381005
# Não         28.932893
# 8           17.271727
# Sim         10.414375
# Name: Comorbidades, dtype: float64
#
# Feature Idade
# 47     2.493583
# 49     2.236890
# 51     2.163550
# 53     2.090209
# 46     2.090209
# 33     2.053539
# 52     2.053539
# 57     2.016868
# 30     1.980198
# 44     1.980198
# 56     1.943528
# 27     1.943528
# 50     1.943528
# 43     1.943528
# 42     1.943528
# 60     1.906857
# 24     1.906857
# 45     1.906857
# 23     1.906857
# 36     1.870187
# 22     1.833517
# 34     1.796846
# 28     1.760176
# 54     1.723506
# 32     1.723506
# 59     1.686835
# 35     1.650165
# 37     1.650165
# 26     1.613495
# 64     1.576824
#          ...
# 17     1.063440
# 16     0.916758
# 66     0.880088
# 14     0.843418
# 70     0.843418
# 77     0.733407
# 15     0.586725
# 78     0.550055
# 73     0.550055
# 74     0.513385
# 80     0.476714
# 75     0.440044
# 79     0.366703
# 76     0.366703
# 13     0.330033
# 81     0.330033
# 83     0.293363
# 84     0.256692
# 82     0.220022
# 999    0.110011
# 86     0.110011
# 88     0.110011
# 85     0.110011
# 87     0.110011
# 12     0.110011
# 92     0.073341
# 93     0.073341
# 89     0.073341
# 9      0.036670
# 91     0.036670
# Name: Idade, dtype: float64
#
# Feature Sexo
# Masculino    55.812248
# Feminino     44.077741
# 2             0.073341
# ignorado      0.036670
# Name: Sexo, dtype: float64
#
# Feature Raça
# Não branco    53.208654
# Branco        46.314631
# ignorado       0.440044
# 8              0.036670
# Name: Raça, dtype: float64
#
# Feature Raça_2
# Não se aplica    50.201687
# Mulato           23.872387
# Negro            16.685002
# ignorado          9.057572
# Índio             0.110011
# Asiático          0.036670
# Não sabe          0.036670
# Name: Raça_2, dtype: float64
#
# Feature Estado_civil
# Solteiro    54.492116
# Casado      30.729740
# viúvo        7.370737
# Separado     5.720572
# ignorado     1.466813
# 0            0.220022
# Name: Estado_civil, dtype: float64
#
# Feature Tem_companheiro
# Sim         51.338467
# Não         46.644664
# ignorado     2.016868
# Name: Tem_companheiro, dtype: float64
#
# Feature Peso_habitual
# 999.0    5.243858
# 60.0     5.097176
# 65.0     4.363770
# 62.0     3.703704
# 55.0     3.520352
# 70.0     3.263660
# 64.0     2.860286
# 52.0     2.860286
# 58.0     2.823616
# 56.0     2.786945
# 50.0     2.786945
# 63.0     2.676934
# 68.0     2.493583
# 53.0     2.310231
# 72.0     2.273561
# 59.0     2.163550
# 54.0     2.163550
# 57.0     2.053539
# 80.0     1.980198
# 74.0     1.980198
# 67.0     1.943528
# 61.0     1.870187
# 75.0     1.833517
# 69.0     1.650165
# 78.0     1.576824
# 66.0     1.576824
# 73.0     1.576824
# 51.0     1.540154
# 45.0     1.320132
# 48.0     1.283462
#            ...
# 109.0    0.036670
# 60.6     0.036670
# 111.0    0.036670
# 113.0    0.036670
# 125.0    0.036670
# 126.7    0.036670
# 127.0    0.036670
# 130.0    0.036670
# 139.5    0.036670
# 140.0    0.036670
# 144.0    0.036670
# 148.0    0.036670
# 155.0    0.036670
# 41.5     0.036670
# 42.2     0.036670
# 46.5     0.036670
# 47.5     0.036670
# 50.3     0.036670
# 51.5     0.036670
# 54.7     0.036670
# 56.8     0.036670
# 57.2     0.036670
# 58.2     0.036670
# 64.9     0.036670
# 67.5     0.036670
# 66.9     0.036670
# 68.8     0.036670
# 70.5     0.036670
# 73.8     0.036670
# 3.0      0.036670
# Name: Peso_habitual, dtype: float64
#
# Feature Peso_atual
# 999.0000    2.933627
# 60.0000     2.420242
# 61.0000     2.383572
# 58.0000     2.346901
# 62.0000     2.310231
# 50.0000     2.310231
# 56.0000     2.236890
# 52.0000     2.126879
# 53.0000     2.126879
# 51.0000     2.090209
# 57.0000     2.090209
# 54.0000     2.090209
# 59.0000     1.943528
# 55.0000     1.906857
# 68.0000     1.686835
# 71.0000     1.686835
# 66.0000     1.686835
# 49.0000     1.650165
# 65.0000     1.613495
# 70.0000     1.503484
# 47.0000     1.466813
# 63.0000     1.430143
# 69.0000     1.430143
# 48.0000     1.393473
# 46.0000     1.320132
# 64.0000     1.246791
# 45.0000     1.246791
# 67.0000     1.210121
# 72.0000     1.210121
# 78.0000     1.173451
#               ...
# 72.1000     0.036670
# 55.2000     0.036670
# 75.2000     0.036670
# 76.2000     0.036670
# 53.7162     0.036670
# 47.2000     0.036670
# 79.9000     0.036670
# 81.3000     0.036670
# 80.5000     0.036670
# 62.8000     0.036670
# 82.2000     0.036670
# 43.3000     0.036670
# 71.6000     0.036670
# 81.5000     0.036670
# 86.8000     0.036670
# 80.7000     0.036670
# 83.9000     0.036670
# 42.8000     0.036670
# 82.8000     0.036670
# 85.5000     0.036670
# 87.7000     0.036670
# 88.7000     0.036670
# 68.3000     0.036670
# 60.8000     0.036670
# 39.5000     0.036670
# 49.2000     0.036670
# 96.5000     0.036670
# 66.3000     0.036670
# 69.5400     0.036670
# 73.6000     0.036670
# Name: Peso_atual, dtype: float64
#
# Feature Altura_cm
# 165.0    4.877154
# 160.0    4.473781
# 168.0    4.143748
# 163.0    3.777044
# 166.0    3.630363
# 172.0    3.593693
# 999.0    3.520352
# 170.0    3.520352
# 167.0    3.447011
# 162.0    3.337000
# 158.0    3.263660
# 161.0    3.226989
# 156.0    3.116978
# 171.0    3.116978
# 155.0    3.043638
# 164.0    3.006967
# 169.0    2.676934
# 175.0    2.640264
# 157.0    2.603594
# 159.0    2.530253
# 174.0    2.456912
# 154.0    2.383572
# 153.0    2.310231
# 173.0    2.126879
# 152.0    2.016868
# 176.0    1.943528
# 151.0    1.760176
# 178.0    1.723506
# 150.0    1.613495
# 177.0    1.320132
#            ...
# 179.0    1.026769
# 147.0    0.990099
# 181.0    0.880088
# 144.0    0.806747
# 182.0    0.806747
# 148.0    0.770077
# 146.0    0.733407
# 185.0    0.586725
# 183.0    0.586725
# 142.0    0.550055
# 145.0    0.476714
# 140.0    0.256692
# 187.0    0.256692
# 143.0    0.256692
# 190.0    0.220022
# 188.0    0.220022
# 186.0    0.146681
# 191.0    0.110011
# 184.0    0.110011
# 189.0    0.073341
# 141.0    0.036670
# 133.0    0.036670
# 138.5    0.036670
# 156.5    0.036670
# 138.0    0.036670
# 192.0    0.036670
# 195.0    0.036670
# 196.0    0.036670
# 198.0    0.036670
# 127.0    0.036670
# Name: Altura_cm, dtype: float64
#
# Feature Tosse
# Sim         89.732307
# Não         10.231023
# ignorado     0.036670
# Name: Tosse, dtype: float64
#
# Feature Semanas_tosse
# 2                 18.041804
# 4                 15.878254
# não se aplica     10.597726
# 8                 10.121012
# 1                  9.754309
# 3                  8.654199
# 12                 6.747341
# 0                  3.813715
# 6                  2.933627
# 16                 2.566923
# 5                  2.163550
# 24                 2.053539
# crônico+sempre     1.210121
# 20                 1.026769
# 48                 0.880088
# ignorado           0.550055
# 32                 0.440044
# 18                 0.403374
# 40                 0.293363
# 9                  0.293363
# 10                 0.293363
# 36                 0.146681
# 7                  0.146681
# 52                 0.146681
# 28                 0.110011
# 180                0.110011
# 96                 0.073341
# 72                 0.073341
# 58                 0.073341
# 14                 0.073341
# 56                 0.036670
# 13                 0.036670
# 44                 0.036670
# 15                 0.036670
# 50                 0.036670
# 104                0.036670
# 19                 0.036670
# 30                 0.036670
# 448                0.036670
# Name: Semanas_tosse, dtype: float64
#
# Feature Expectoração
# Sim         79.024569
# Não         20.792079
# ignorado     0.183352
# Name: Expectoração, dtype: float64
#
# Feature Semanas_expectoração
# não se aplica     21.048772
# 2                 15.951595
# 4                 14.191419
# 1                 10.634397
# 8                  8.764210
# 3                  6.967363
# 12                 4.693803
# 0                  4.547121
# 6                  2.823616
# 16                 2.053539
# 24                 1.760176
# 5                  1.540154
# ignorado           0.916758
# crônico+sempre     0.806747
# 48                 0.660066
# 20                 0.586725
# 40                 0.293363
# 32                 0.256692
# 18                 0.256692
# 52                 0.183352
# 9                  0.183352
# 10                 0.146681
# 7                  0.110011
# 96                 0.110011
# 14                 0.073341
# 104                0.036670
# 72                 0.036670
# 58                 0.036670
# 50                 0.036670
# 28                 0.036670
# 44                 0.036670
# 30                 0.036670
# 13                 0.036670
# 15                 0.036670
# 36                 0.036670
# 19                 0.036670
# 333                0.036670
# Name: Semanas_expectoração, dtype: float64
#
# Feature Hemoptóicos
# Não         80.418042
# Sim         19.105244
# ignorado     0.476714
# Name: Hemoptóicos, dtype: float64
#
# Feature Semanas_hemoptóicos
# não se aplica     80.528053
# 0                  7.444078
# 1                  4.657132
# 2                  2.016868
# ignorado           1.943528
# 4                  1.430143
# 3                  0.770077
# 8                  0.403374
# 12                 0.220022
# 16                 0.146681
# 6                  0.073341
# 5                  0.036670
# crônico+sempre     0.036670
# 9                  0.036670
# 18                 0.036670
# 24                 0.036670
# 32                 0.036670
# 48                 0.036670
# 52                 0.036670
# 88                 0.036670
# 15                 0.036670
# Name: Semanas_hemoptóicos, dtype: float64
#
# Feature Hemoptise
# Não         90.392373
# Sim          8.874221
# ignorado     0.733407
# Name: Hemoptise, dtype: float64
#
# Feature Semanas_hemoptise
# não se aplica    90.685735
# 1                 3.006967
# 0                 2.786945
# ignorado          1.356802
# 2                 0.806747
# 4                 0.586725
# 3                 0.220022
# 12                0.183352
# 8                 0.183352
# 15                0.073341
# 32                0.036670
# 16                0.036670
# 6                 0.036670
# Name: Semanas_hemoptise, dtype: float64
#
# Feature Quantidade_hemoptise
# 888                    65.639897
# Não se aplica          22.552255
# < 1 copinho de café     7.590759
# ignorado                1.613495
# > 1 copinho de café     1.210121
# 999                     1.063440
# >= 1 copo de geléia     0.330033
# Name: Quantidade_hemoptise, dtype: float64
#
# Feature Sudorese_noturna
# Não    63.072974
# Sim    36.596993
# 9       0.330033
# Name: Sudorese_noturna, dtype: float64
#
# Feature Semanas_sudorese
# não se aplica     62.889622
# 1                  7.737440
# 2                  7.004034
# 4                  5.793913
# 0                  4.217088
# 3                  3.190319
# 8                  2.860286
# 12                 1.650165
# ignorado           1.430143
# 6                  0.953429
# 16                 0.550055
# 5                  0.403374
# 24                 0.366703
# 20                 0.183352
# 18                 0.146681
# 48                 0.146681
# 9                  0.110011
# 88                 0.073341
# 19                 0.036670
# 14                 0.036670
# 10                 0.036670
# 28                 0.036670
# 32                 0.036670
# 36                 0.036670
# 96                 0.036670
# crônico+sempre     0.036670
# Name: Semanas_sudorese, dtype: float64
#
# Feature Febre
# Não         53.758709
# Sim         45.874587
# ignorado     0.366703
# Name: Febre, dtype: float64
#
# Feature Semanas_febre
# não se aplica     55.592226
# 1                 11.441144
# 2                  8.690869
# 0                  6.453979
# 4                  6.233957
# 3                  3.447011
# 8                  3.006967
# ignorado           1.210121
# 12                 1.173451
# 6                  0.843418
# 16                 0.476714
# 20                 0.293363
# 5                  0.256692
# 24                 0.220022
# 18                 0.146681
# 10                 0.110011
# 88                 0.110011
# 9                  0.073341
# crônico+sempre     0.073341
# 7                  0.036670
# 28                 0.036670
# 48                 0.036670
# 96                 0.036670
# Name: Semanas_febre, dtype: float64
#
# Feature Dispnéia
# Sim         69.086909
# Não         30.729740
# ignorado     0.146681
# 2            0.036670
# Name: Dispnéia, dtype: float64
#
# Feature Dispnéia_semanas
# não se aplica     30.986432
# 2                 12.541254
# 1                 10.927759
# 4                 10.267693
# 8                  6.674001
# 0                  5.170517
# 3                  4.767143
# 12                 3.960396
# ignorado           2.676934
# crônico+sempre     2.236890
# 6                  1.906857
# 24                 1.650165
# 16                 1.613495
# 5                  1.320132
# 48                 0.770077
# 20                 0.660066
# 32                 0.330033
# 10                 0.293363
# 40                 0.256692
# 18                 0.256692
# 9                  0.220022
# 14                 0.073341
# 58                 0.073341
# 104                0.073341
# 15                 0.036670
# 44                 0.036670
# 52                 0.036670
# 7                  0.036670
# 19                 0.036670
# 28                 0.036670
# 56                 0.036670
# 80                 0.036670
# Name: Dispnéia_semanas, dtype: float64
#
# Feature Perda_de_apetite
# Não         37.110378
# Sim         34.140081
# ignorado    28.749542
# Name: Perda_de_apetite, dtype: float64
#
# Feature Perda_apetite_semanas
# não se aplica     37.440411
# ignorado          29.922992
# 2                  6.307297
# 1                  6.013935
# 4                  5.647231
# 0                  3.740374
# 8                  2.823616
# 3                  2.090209
# 12                 1.906857
# 6                  1.063440
# 16                 0.806747
# 5                  0.623396
# 24                 0.513385
# 20                 0.440044
# crônico+sempre     0.220022
# 10                 0.073341
# 9                  0.073341
# 32                 0.073341
# 48                 0.073341
# 14                 0.036670
# 18                 0.036670
# 7                  0.036670
# 52                 0.036670
# Name: Perda_apetite_semanas, dtype: float64
#
# Feature Perda_peso_10percent
# Não         68.280161
# Sim         26.439311
# ignorado     5.280528
# Name: Perda_peso_10percent, dtype: float64
#
# Feature Perda_peso_semanas
# não se aplica     69.710304
# ignorado           7.187385
# 4                  4.437110
# 8                  3.593693
# 12                 3.190319
# 2                  1.796846
# 16                 1.650165
# 24                 1.613495
# 6                  1.210121
# 1                  1.100110
# 3                  1.063440
# 48                 0.696736
# 20                 0.586725
# 10                 0.256692
# 0                  0.256692
# 32                 0.256692
# 40                 0.256692
# 9                  0.183352
# 5                  0.183352
# 36                 0.110011
# crônico+sempre     0.110011
# 18                 0.110011
# 17                 0.073341
# 104                0.073341
# 15                 0.036670
# 30                 0.036670
# 29                 0.036670
# 52                 0.036670
# 90                 0.036670
# 96                 0.036670
# 8888               0.036670
# 28                 0.036670
# Name: Perda_peso_semanas, dtype: float64
#
# Feature Dor_torácica
# Sim         70.333700
# Não         29.556289
# ignorado     0.110011
# Name: Dor_torácica, dtype: float64
#
# Feature Dor_torácica_semanas
# não se aplica     29.666300
# 2                 13.788045
# 1                 10.927759
# 4                 10.707737
# 0                  7.334067
# 8                  6.820682
# 3                  4.803814
# 12                 4.107077
# ignorado           2.676934
# 6                  2.236890
# 16                 1.503484
# 24                 1.283462
# 5                  1.026769
# 20                 0.843418
# crônico+sempre     0.586725
# 48                 0.403374
# 32                 0.220022
# 40                 0.183352
# 18                 0.146681
# 10                 0.110011
# 14                 0.073341
# 9                  0.073341
# 7                  0.073341
# 52                 0.073341
# 58                 0.073341
# 104                0.073341
# 28                 0.036670
# 50                 0.036670
# 56                 0.036670
# 96                 0.036670
# 19                 0.036670
# Name: Dor_torácica_semanas, dtype: float64
#
# Feature Internação_hospital_2anos
# Não         85.918592
# Sim         13.348001
# ignorado     0.733407
# Name: Internação_hospital_2anos, dtype: float64
#
# Feature Prisão_2anos
# Não         96.663000
# Sim          2.530253
# ignorado     0.806747
# Name: Prisão_2anos, dtype: float64
#
# Feature Delegacia_2anos
# Não         96.699670
# Sim          2.420242
# ignorado     0.880088
# Name: Delegacia_2anos, dtype: float64
#
# Feature Contato_TBP_2anos
# Não         71.800513
# Sim         27.062706
# ignorado     1.136780
# Name: Contato_TBP_2anos, dtype: float64
#
# Feature TBP_Morava_com_vc
# não se aplica    52.108544
# Não              33.663366
# Sim              12.761276
# ignorado          1.466813
# Name: TBP_Morava_com_vc, dtype: float64
#
# Feature TBP_trabalhava_com_vc
# não se aplica    52.108544
# Não              43.894389
# Sim               2.493583
# ignorado          1.503484
# Name: TBP_trabalhava_com_vc, dtype: float64
#
# Feature TBP_amigo_parente_não_morava_com_vc
# não se aplica    52.108544
# Não              32.929960
# Sim              13.494683
# ignorado          1.466813
# Name: TBP_amigo_parente_não_morava_com_vc, dtype: float64
#
# Feature Contato_TBP_menor_3anos
# não se aplica    52.108544
# Não              27.026036
# Sim              19.031903
# ignorado          1.833517
# Name: Contato_TBP_menor_3anos, dtype: float64
#
# Feature Contato_TBP_Casa
# não se aplica    52.108544
# Não              32.783278
# Sim              13.458012
# ignorado          1.650165
# Name: Contato_TBP_Casa, dtype: float64
#
# Feature Contato_TBP_Trabalho
# não se aplica    52.108544
# Não              43.637697
# Sim               2.640264
# ignorado          1.613495
# Name: Contato_TBP_Trabalho, dtype: float64
#
# Feature Contato_TBP_Social
# não se aplica    52.108544
# Não              35.680235
# Sim              10.634397
# ignorado          1.576824
# Name: Contato_TBP_Social, dtype: float64
#
# Feature Fuma
# Jamais fumante    38.760543
# Fumante           33.773377
# Ex-fumante        26.806014
# ignorado           0.660066
# Name: Fuma, dtype: float64
#
# Feature Número_cigarros_dia
# não se aplica    27.539421
# 20               20.022002
# ignorado         12.797946
# 40                8.544188
# 10                7.480748
# 30                3.263660
# 5                 2.933627
# 15                2.456912
# 60                2.346901
# 3                 2.236890
# 2                 1.906857
# 4                 1.870187
# 6                 1.430143
# 1                 1.283462
# 7                 0.953429
# 8                 0.843418
# 12                0.476714
# 50                0.440044
# 18                0.256692
# 80                0.256692
# 25                0.256692
# 35                0.073341
# 120               0.036670
# 99                0.036670
# 55                0.036670
# 21                0.036670
# 45                0.036670
# 13                0.036670
# 14                0.036670
# 16                0.036670
# 9                 0.036670
# Name: Número_cigarros_dia, dtype: float64
#
# Feature Cerveja
# Sim         49.981665
# Não         49.578291
# ignorado     0.440044
# Name: Cerveja, dtype: float64
#
# Feature Vinho
# Não         80.748075
# Sim         18.775211
# ignorado     0.440044
# 10           0.036670
# Name: Vinho, dtype: float64
#
# Feature Whisky
# Não         97.836450
# Sim          1.723506
# ignorado     0.440044
# Name: Whisky, dtype: float64
#
# Feature Cachaça
# Não         90.539054
# Sim          9.020902
# ignorado     0.440044
# Name: Cachaça, dtype: float64
#
# Feature Outras_bebidas_alcoólicas
# Não         91.822516
# Sim          7.737440
# ignorado     0.440044
# Name: Outras_bebidas_alcoólicas, dtype: float64
#
# Feature Nenhuma_bebida_alcoólica
# Não         57.682435
# Sim         41.877521
# ignorado     0.440044
# Name: Nenhuma_bebida_alcoólica, dtype: float64
#
# Feature CAGE
# Negativo    76.567657
# Positivo    23.212321
# ignorado     0.220022
# Name: CAGE, dtype: float64
#
# Feature IRC
# ignorado    44.921159
# 8           44.921159
# Não         10.047671
# Sim          0.110011
# Name: IRC, dtype: float64
#
# Feature Hepatopatia
# ignorado    44.921159
# 8           44.921159
# Não         10.121012
# Sim          0.036670
# Name: Hepatopatia, dtype: float64
#
# Feature Etilismo
# 8           44.884488
# ignorado    44.811148
# Sim          7.114045
# Não          3.190319
# Name: Etilismo, dtype: float64
#
# Feature Uso_corticoide
# ignorado    44.957829
# 8           44.921159
# Não         10.084342
# Sim          0.036670
# Name: Uso_corticoide, dtype: float64
#
# Feature Neo_maligna
# ignorado    44.921159
# 8           44.921159
# Não         10.084342
# Sim          0.073341
# Name: Neo_maligna, dtype: float64
#
# Feature Transplante
# ignorado    44.921159
# 8           44.921159
# Não         10.157682
# Name: Transplante, dtype: float64
#
# Feature DM_NID
# ignorado    44.921159
# 8           44.921159
# Não          9.460946
# Sim          0.696736
# Name: DM_NID, dtype: float64
#
# Feature DM_ID
# 8           44.921159
# ignorado    44.884488
# Não          9.937660
# Sim          0.256692
# Name: DM_ID, dtype: float64
#
# Feature Silicose
# ignorado    44.921159
# 8           44.921159
# Não         10.157682
# Name: Silicose, dtype: float64
#
# Feature DPOC
# ignorado    44.921159
# 8           44.921159
# Não          9.644298
# Sim          0.513385
# Name: DPOC, dtype: float64
#
# Feature Doença_pumonar_difusa
# ignorado    44.921159
# 8           44.921159
# Não         10.157682
# Name: Doença_pumonar_difusa, dtype: float64
#
# Feature Etionamida_TTO_TB
# ignorado           77.191052
# "não se aplica"    13.127979
# Não                 9.534287
# Sim                 0.146681
# Name: Etionamida_TTO_TB, dtype: float64
#
# Feature Estreptomicina_TTO_TB
# ignorado           77.191052
# "não se aplica"    13.164650
# Não                 9.387605
# Sim                 0.256692
# Name: Estreptomicina_TTO_TB, dtype: float64
#
# Feature Ofolxacino_TTO_TB
# ignorado           77.191052
# "não se aplica"    13.164650
# Não                 9.644298
# Name: Ofolxacino_TTO_TB, dtype: float64
#
# Feature Exantema
# ignorado         82.178218
# não se aplica    17.638431
# Sim               0.146681
# Não               0.036670
# Name: Exantema, dtype: float64
#
# Feature Confusão_mental
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Confusão_mental, dtype: float64
#
# Feature Icterícia
# ignorado         82.214888
# não se aplica    17.638431
# Não               0.110011
# Sim               0.036670
# Name: Icterícia, dtype: float64
#
# Feature Hepatotoxicidade
# ignorado         82.178218
# não se aplica    17.638431
# Não               0.110011
# Sim               0.073341
# Name: Hepatotoxicidade, dtype: float64
#
# Feature Vertigem
# ignorado         82.178218
# não se aplica    17.638431
# Não               0.110011
# Sim               0.073341
# Name: Vertigem, dtype: float64
#
# Feature Hipoacusia
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Hipoacusia, dtype: float64
#
# Feature Crise_convulsiva
# ignorado         82.214888
# não se aplica    17.638431
# Não               0.073341
# Sim               0.073341
# Name: Crise_convulsiva, dtype: float64
#
# Feature Encefalopatia
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Encefalopatia, dtype: float64
#
# Feature Psicose
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Psicose, dtype: float64
#
# Feature Neurite_óptica
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Neurite_óptica, dtype: float64
#
# Feature Plaquetopenia_leucopenia_eosinofilia
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Plaquetopenia_leucopenia_eosinofilia, dtype: float64
#
# Feature Anemia_hemolítica_vasculite
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Anemia_hemolítica_vasculite, dtype: float64
#
# Feature Choque_púrpura
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Choque_púrpura, dtype: float64
#
# Feature Nefrite
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Nefrite, dtype: float64
#
# Feature Insuficiência_renal_rabdomiólise
# ignorado         82.251558
# não se aplica    17.638431
# Não               0.110011
# Name: Insuficiência_renal_rabdomiólise, dtype: float64
#
# Feature Prurido
# ignorado         81.848185
# não se aplica    16.611661
# Não               1.026769
# Sim               0.513385
# Name: Prurido, dtype: float64
#
# Feature Anorexia
# ignorado         82.178218
# não se aplica    16.611661
# Não               1.136780
# Sim               0.073341
# Name: Anorexia, dtype: float64
#
# Feature Náuseas_vômitos
# ignorado         81.114778
# não se aplica    16.611661
# Sim               1.576824
# Não               0.696736
# Name: Náuseas_vômitos, dtype: float64
#
# Feature Dor_abdominal
# ignorado         81.738174
# não se aplica    16.611661
# Não               0.880088
# Sim               0.770077
# Name: Dor_abdominal, dtype: float64
#
# Feature Dor_articular
# ignorado         81.041437
# não se aplica    16.611661
# Sim               1.540154
# Não               0.806747
# Name: Dor_articular, dtype: float64
#
# Feature Neurite_periférica
# ignorado         82.104877
# não se aplica    16.611661
# Não               1.100110
# Sim               0.183352
# Name: Neurite_periférica, dtype: float64
#
# Feature Euforia
# ignorado         82.251558
# não se aplica    16.611661
# Não               1.136780
# Name: Euforia, dtype: float64
#
# Feature Insônia_sonolência
# ignorado         82.104877
# não se aplica    16.611661
# Não               1.136780
# Sim               0.146681
# Name: Insônia_sonolência, dtype: float64
#
# Feature Ansiedade
# ignorado         82.251558
# não se aplica    16.611661
# Não               1.136780
# Name: Ansiedade, dtype: float64
#
# Feature Cefaléia
# ignorado         82.251558
# não se aplica    16.611661
# Não               1.136780
# Name: Cefaléia, dtype: float64
#
# Feature Acne
# ignorado         81.848185
# não se aplica    16.611661
# Não               1.063440
# Sim               0.476714
# Name: Acne, dtype: float64
#
# Feature Hiperuricemia
# ignorado         82.214888
# não se aplica    16.611661
# Não               1.136780
# Sim               0.036670
# Name: Hiperuricemia, dtype: float64
#
# Feature Febre_AD
# ignorado         82.251558
# não se aplica    16.611661
# Não               1.136780
# Name: Febre_AD, dtype: float64
#
# Feature Hipotensão_ortostática
# ignorado         82.251558
# não se aplica    16.611661
# Não               1.136780
# Name: Hipotensão_ortostática, dtype: float64
#
# Feature Ginecomastia
# ignorado         82.251558
# não se aplica    16.611661
# Não               1.136780
# Name: Ginecomastia, dtype: float64

# %%
# Selecionando features que possuem a quantidade de ignorados maior que 30%
features_ignoradas = ['Asma','Tto_TB_prescrito','Rifampicina_TTO_TB','Isoniazida_TTO_TB','Pirazinamida_TTO_TB',
                      'Etambutol_TTO_TB','Tto_anterior_TB_avaliação_médica','Tto_anterior_TB_INH','Tto_anterior_TB_RIF',
                      'Quimio_prévia','Quimio_INH','Quimio_RIF','Desfecho_quimio','HIV','TBP_Morava_com_vc','TBP_trabalhava_com_vc',
                      'TBP_amigo_parente_não_morava_com_vc','Contato_TBP_menor_3anos','Contato_TBP_Casa','Contato_TBP_Trabalho',
                      'Contato_TBP_Social','IRC','Hepatopatia','Etilismo','Uso_corticoide','Neo_maligna','Transplante','DM_NID','DM_ID',
                      'Silicose','DPOC','Doença_pumonar_difusa','Etionamida_TTO_TB','Estreptomicina_TTO_TB','Ofolxacino_TTO_TB','Exantema',
                      'Confusão_mental','Icterícia','Hepatotoxicidade','Vertigem','Hipoacusia','Crise_convulsiva','Encefalopatia','Psicose',
                      'Neurite_óptica','Plaquetopenia_leucopenia_eosinofilia','Anemia_hemolítica_vasculite','Choque_púrpura','Nefrite','Insuficiência_renal_rabdomiólise',
                      'Prurido','Anorexia','Náuseas_vômitos','Dor_abdominal','Dor_articular','Neurite_periférica','Euforia','Insônia_sonolência','Ansiedade',
                      'Cefaléia','Acne','Hiperuricemia','Febre_AD','Hipotensão_ortostática','Ginecomastia','Comorbidades','Raça_2',
                      'Cachaça', 'Cerveja', 'Nenhuma_bebida_alcoólica', 'Outras_bebidas_alcoólicas', 'Whisky', 'Vinho'
                     ]

dados_filtrados = dados_filtrados.drop(features_ignoradas,axis=1)

# %%
features_selecionadas = list(dados_filtrados.columns)

# Exibindo as variáveis salvas
print(features_selecionadas)
# Out:
# ['desfecho', 'TTO_anterior_TB_triagem_enfermeiro', 'Cicatriz_BCG', 'Idade', 'Sexo', 'Raça', 'Estado_civil', 'Tem_companheiro', 'Peso_habitual', 'Peso_atual', 'Altura_cm', 'Tosse', 'Semanas_tosse', 'Expectoração', 'Semanas_expectoração', 'Hemoptóicos', 'Semanas_hemoptóicos', 'Hemoptise', 'Semanas_hemoptise', 'Quantidade_hemoptise', 'Sudorese_noturna', 'Semanas_sudorese', 'Febre', 'Semanas_febre', 'Dispnéia', 'Dispnéia_semanas', 'Perda_de_apetite', 'Perda_apetite_semanas', 'Perda_peso_10percent', 'Perda_peso_semanas', 'Dor_torácica', 'Dor_torácica_semanas', 'Internação_hospital_2anos', 'Prisão_2anos', 'Delegacia_2anos', 'Contato_TBP_2anos', 'Fuma', 'Número_cigarros_dia', 'CAGE']

# %%
# Criando um dataframe a partir das features pré-selecionadas
dados = dados_filtrados[features_selecionadas].copy()

for feature in list(dados.columns):
    print(feature)
    print(dados[feature].unique(),'\n')
# Out:
# desfecho
# ['TB+' 'TB-']
#
# TTO_anterior_TB_triagem_enfermeiro
# ['Sim' 'Não' 'ignorado']
#
# Cicatriz_BCG
# ['Sim' 'ignorado' 'Não']
#
# Idade
# [ 30  53  84  18  36  71  26  22  54  52  57  32  21  23  50  24  27  19
#   58  47  63  46  20  12  33  17  31  51  66  59  62  41  34  29  14  16
#   70  61  43  44  42  37  73  56  49  39  25  35  45  48  64  68  40  75
#   72  28  55  38  92  67  15  85  65  82  60  13  78  69  74  77  81  86
#   88  79 999  76  93  80  83  89  87  91   9]
#
# Sexo
# ['Masculino' 'Feminino' 2 'ignorado']
#
# Raça
# ['Não branco' 'Branco' 'ignorado' 8]
#
# Estado_civil
# ['Solteiro' 'ignorado' 'viúvo' 'Casado' 'Separado' 0]
#
# Tem_companheiro
# ['Não' 'Sim' 'ignorado']
#
# Peso_habitual
# [  62.    75.    56.    51.    63.    76.    65.    55.    70.    69.    45.
#    60.    44.    48.    58.    53.    92.    33.3   95.    64.    87.
#    70.5   90.    34.    67.   999.    49.    78.    68.    59.    74.    66.
#    80.    52.    91.    82.   100.    50.    54.    73.    42.    89.    83.
#    77.    47.    58.4   62.5   61.    72.    79.    58.2   46.    81.   110.
#    53.5   57.    70.3   86.5  140.    86.    71.    55.9  120.    88.    43.
#    57.2   40.    57.4  112.    41.    84.2   46.6   53.8   38.    35.    84.
#    54.7   85.   108.    47.5   42.2   47.8   36.    98.   115.   102.
#    87.5   49.5   96.    57.1  130.    77.9   93.    94.    57.5   99.   117.
#    56.1   46.5    8.    66.9  107.    61.5   77.5   66.7   71.6  105.
#    58.8  148.    68.8  113.    56.8  111.    81.5  144.    49.2   71.4
#    51.5   48.1    3.    73.8   56.7  106.   104.3   68.5   58.5   97.
#    54.3  111.7  155.    66.2  125.    60.6   41.5   61.9  107.7   45.6
#   123.   101.    50.3   54.5   88.8  104.    76.8   30.   127.    49.4
#    75.6   89.4   54.4  109.    64.9   49.8  139.5   39.   126.7   67.5]
#
# Peso_atual
# [  62.       76.       48.       58.       69.       66.       49.4      58.5
#    43.       63.       52.       42.       58.7      56.       54.5      55.
#    72.3      84.       33.       74.5      66.5      85.       65.       70.5
#    92.5      50.       32.       64.       57.       70.       47.       92.3
#   999.       72.5      38.       35.       57.3      59.5      53.       68.
#    71.       61.5      75.       51.       67.       51.3      59.       48.2
#    78.       66.8      45.2      91.      101.       44.       53.7      60.
#    57.8      61.       36.5      73.5      91.3      81.       41.3      89.
#    50.5      92.       59.8      93.3      82.       47.5      68.4      54.
#    55.5      79.       58.3      87.5      52.5      46.       64.5      41.5
#    51.5      49.5      66.3      55.4      49.       45.       73.       59.9
#    67.7      51.2      58.2      55.7      53.5      36.4      79.5      72.
#   103.       80.3      62.4      43.6      86.5     126.2      79.3      71.5
#    36.       65.3      55.1      48.7      61.4      41.2      68.5      58.8
#    56.6      48.5      71.4      72.1      48.3      40.       63.8      41.
#    45.4      78.2      53.8      80.       40.6      44.6      61.1      83.
#    58.9      43.1      56.9      79.9      56.4      68.3      62.9      55.3
#    52.4      47.8      38.8      57.2      62.7      43.5      74.8      54.7
#    37.       56.5      75.5      40.5      45.3      45.5      56.7      78.8
#    57.4      86.       59.3      62.5      54.8      44.5      39.       90.
#    46.7      56.1      43.7      51.4      45.1      58.6      74.       38.5
#    64.7      66.9      53.7162   39.8      49.7      34.       52.2      47.3
#    28.       69.3      61.2      55.2      48.8      77.4      63.3      63.5
#    87.       59.4      52.7      78.3      96.       85.1      60.3      39.7
#    77.       73.8      57.5      94.       49.2      60.9      87.7      69.7
#    52.9      50.6      82.6      84.8      46.8      41.4      97.       52.8
#    79.1      65.7      83.5      64.8      60.5      88.       77.9      46.5
#    70.3      39.2      95.       49.8      93.       78.5      53.6      65.5
#    82.8      45.7      51.8      65.8      61.3      84.2      45.8     102.
#    43.2      99.      117.       93.2      54.6      59.2      88.5      73.7
#    67.5      38.7      74.3      44.1      56.8      61.7     105.       61.8
#    51.9     110.5      69.54     63.6      53.2      76.5      73.9      74.7
#    77.8      85.5      48.4      67.6      80.7      52.6      78.9      74.4
#    65.4      60.8      65.9      48.9      42.7      66.7      63.9      75.6
#    64.6     109.       68.2      55.9      65.6      57.7      76.8      38.6
#    49.3     140.       60.2      54.4     104.4      62.8     112.5      33.7
#    70.1     111.       71.6      79.8     144.       67.4      72.4      80.5
#    68.7      62.2      93.5      59.6      57.6      76.2      91.5      59.7
#   104.6      72.2      69.5      74.2      67.1      49.6      78.7      54.2
#   100.       68.8      53.3      54.9      60.6      89.6      47.1      58.4
#    71.2      77.5      67.2     106.       32.3      54.3      89.5      36.3
#    46.3      81.2     110.      155.       97.4      81.5     100.5      96.6
#    92.4     116.7      73.4      70.8      43.9      47.2      69.6      65.1
#    50.8      73.3      67.9      44.2      40.2      61.9      96.5     105.3
#    42.5      39.3      50.2      47.4     123.       34.5      63.4      92.8
#    75.2      37.5      68.6      71.7      72.7      80.9      83.9      64.9
#    50.4      74.1      77.1      88.7      71.9      71.1      66.1      62.6
#    57.1      64.2      67.3      67.8      98.      104.      119.       95.8
#    86.8      52.3      42.8      87.6      82.2      41.9      30.       68.9
#    38.3     127.       37.2      39.5      89.4     138.       73.6     107.
#   139.       82.5      73.2     125.       45.6      84.4     112.      118.
#    93.8      43.3      75.8      40.3      63.2      81.3      76.7   ]
#
# Altura_cm
# [ 172.   159.   150.   168.   174.   165.   164.   162.   157.   163.   188.
#   181.   160.   169.   180.   175.   183.   154.   176.   167.   177.   133.
#   166.   999.   178.   170.   182.   155.   145.   161.   158.   156.   171.
#   151.   149.   153.   187.   146.   173.   179.   152.   144.   185.   142.
#   192.   147.   156.5  189.   190.   148.   198.   186.   191.   196.   140.
#   195.   184.   143.   138.5  138.   141.   127. ]
#
# Tosse
# ['Sim' 'Não' 'ignorado']
#
# Semanas_tosse
# ['ignorado' 2 3 20 4 104 5 1 8 0 48 'não se aplica' 18 12 6
#  'crônico+sempre' 16 72 10 24 52 28 32 9 40 7 13 180 36 14 19 448 44 50 30
#  96 15 56 58]
#
# Expectoração
# ['Não' 'Sim' 'ignorado']
#
# Semanas_expectoração
# ['não se aplica' 2 3 4 104 5 1 8 0 18 9 6 20 24 12 16 48 32 10 40
#  'ignorado' 13 7 36 'crônico+sempre' 52 14 96 19 44 50 30 333 72 15 28 58]
#
# Hemoptóicos
# ['Não' 'Sim' 'ignorado']
#
# Semanas_hemoptóicos
# ['não se aplica' 0 52 3 1 4 'ignorado' 2 8 5 6 18 12 16 15 9 48 32 88
#  'crônico+sempre' 24]
#
# Hemoptise
# ['Não' 'Sim' 'ignorado']
#
# Semanas_hemoptise
# ['não se aplica' 3 0 4 1 'ignorado' 2 8 12 6 15 16 32]
#
# Quantidade_hemoptise
# [888 '< 1 copinho de café' 'Não se aplica' '> 1 copinho de café' 'ignorado'
#  999 '>= 1 copo de geléia']
#
# Sudorese_noturna
# ['Não' 'Sim' 9]
#
# Semanas_sudorese
# ['não se aplica' 0 3 1 4 8 2 5 'ignorado' 20 6 18 12 24 48 9 10 16
#  'crônico+sempre' 14 19 32 88 36 28 96]
#
# Febre
# ['Não' 'Sim' 'ignorado']
#
# Semanas_febre
# ['não se aplica' 3 0 1 4 2 8 5 'ignorado' 20 6 18 10 12 16 88 24 48 9
#  'crônico+sempre' 7 28 96]
#
# Dispnéia
# ['Não' 'Sim' 'ignorado' 2]
#
# Dispnéia_semanas
# ['não se aplica' 2 20 4 104 1 5 8 48 3 'ignorado' 12 0 18 6 24 32
#  'crônico+sempre' 16 9 10 40 7 14 19 44 52 15 56 58 28 80]
#
# Perda_de_apetite
# ['Não' 'ignorado' 'Sim']
#
# Perda_apetite_semanas
# ['não se aplica' 'ignorado' 4 3 1 8 0 5 9 20 6 2 16 12 24 32 18 52 10
#  'crônico+sempre' 7 48 14]
#
# Perda_peso_10percent
# ['Não' 'Sim' 'ignorado']
#
# Perda_peso_semanas
# ['não se aplica' 3 4 8 12 9 'ignorado' 2 6 20 48 24 16 1 5 'crônico+sempre'
#  17 18 10 32 90 0 40 8888 30 36 15 104 29 52 28 96]
#
# Dor_torácica
# ['Não' 'Sim' 'ignorado']
#
# Dor_torácica_semanas
# ['não se aplica' 3 20 0 104 2 1 5 8 4 'ignorado' 6 18 24 12 32 50 16 48 9
#  10 7 40 'crônico+sempre' 14 19 52 96 56 58 28]
#
# Internação_hospital_2anos
# ['Sim' 'Não' 'ignorado']
#
# Prisão_2anos
# ['Não' 'Sim' 'ignorado']
#
# Delegacia_2anos
# ['Não' 'ignorado' 'Sim']
#
# Contato_TBP_2anos
# ['Não' 'Sim' 'ignorado']
#
# Fuma
# ['Fumante' 'Ex-fumante' 'Jamais fumante' 'ignorado']
#
# Número_cigarros_dia
# [5 20 'ignorado' 'não se aplica' 30 40 1 60 15 6 4 10 12 8 7 3 2 25 50 35
#  18 13 80 9 120 55 21 14 45 99 16]
#
# CAGE
# ['Negativo' 'Positivo' 'ignorado']

# %%
# Alterando os labels dos desfechos
dados.desfecho.replace(['TB', 'Não TB','IGN',8],['TB+','TB-','desconhecido','desconhecido'],inplace=True)

# Alterando os outros labels dos outros atributos
dados.replace(['IGN',np.nan],['ignorado','ignorado'],inplace=True)

# Selecionando os desfechos que possuem diagnóstico conhecido: TB+ e TB-
dados = dados[(dados.desfecho == 'TB+') | (dados.desfecho == 'TB-')]

# Quantidade_hemoptise: Poucos valores significantes
dados.drop(['Quantidade_hemoptise'],axis=1,inplace=True)

# # Peso atual/habitual: Não importa para o diagnóstico
# dados.drop(['Peso_atual'],axis=1,inplace=True)
# dados.drop(['Peso_habitual'],axis=1,inplace=True)

# # Altura: Não importa para o diagnóstico
# dados.drop(['Altura_cm'],axis=1,inplace=True)

# # Número de cigarros
# dados.drop(['Número_cigarros_dia'],axis=1,inplace=True)

# # Número de cigarros
# dados.drop(['Perda_apetite_semanas'],axis=1,inplace=True)

# %%
# Substituindo os valores da variável Sexo
dados.Sexo.replace([8,2],['ignorado','ignorado'],inplace=True)
                    
# Substituindo os valores da variável Raça
dados.Raça.replace([8],'ignorado',inplace=True)
                    
# Substituindo os valores da variável Estado_civil
dados.Estado_civil.replace([np.nan, 8, 0],['ignorado','ignorado','ignorado'],inplace=True)        

# Substituindo os valores da variável Semanas_tosse
dados.Semanas_tosse.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável Semanas_expectoração
dados.Semanas_expectoração.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável Semanas_tosse
dados.Semanas_hemoptóicos.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável Semanas_hemoptise
dados.Semanas_hemoptise.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Sudorese_noturna.replace([9],'ignorado',inplace=True)

# Substituindo os valores da variável 
dados.Semanas_sudorese.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Semanas_febre.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Dispnéia.replace([2],['ignorado'],inplace=True)

# Substituindo os valores da variável 
dados.Dispnéia_semanas.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Perda_peso_semanas.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável 
dados.Dor_torácica_semanas.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# Substituindo os valores da variável Número_cigarros_dia
dados.Número_cigarros_dia.replace(['não se aplica','crônico+sempre'],[0,180],inplace=True)

# %%
len(dados.columns)
# Out:
# 38

# %%
# Armazenando as features pré-selecionadas em um arquivo csv
dados.to_csv('../../Dados/preprocessed.csv',index=False,columns=list(dados.columns))
