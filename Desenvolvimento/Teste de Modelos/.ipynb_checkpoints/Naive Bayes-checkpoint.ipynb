# %% [markdown]
# # Avaliação do naive Bayes

# %%
# Manipulação dos dados
import numpy  as np
import scipy  as sp
import pandas as pd

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn           as sns
# %matplotlib inline

# %%
# Importando o classificador
from sklearn.naive_bayes import MultinomialNB as NB

# %%
# Conjunto de treinamento e teste - normal
training_data = pd.read_csv('../../Dados/treinamento-one-hot.csv')
test_data     = pd.read_csv('../../Dados/teste-one-hot.csv')

# %%
# Conjunto de treinamento e teste - full
training_data_full = pd.read_csv('../../Dados/treinamento-one-hot_full.csv')
test_data_full     = pd.read_csv('../../Dados/teste-one-hot_full.csv')

# %% [markdown]
# ### Carregando o dataset do chi quadrado para obter a lista de features

# %%
normal = pd.read_csv('../../Dados/one-hot-chi2.csv')
full   = pd.read_csv('../../Dados/one-hot-full-chi2.csv')

# %%
normal
# Out:
#      Prisão_2anos       Sexo Perda_peso_10percent Cicatriz_BCG Dispnéia  \
# 0             Não  Masculino                  Não          Sim      Não
# 1             Não   Feminino                  Não     ignorado      Sim
# 2             Não   Feminino                  Sim          Não      Não
# 3             Não   Feminino                  Não          Sim      Sim
# 4             Não  Masculino                  Não     ignorado      Sim
# 5             Não  Masculino                  Não          Sim      Sim
# 6             Não  Masculino                  Não          Não      Sim
# 7             Não   Feminino                  Não          Sim      Sim
# 8             Não  Masculino                  Sim          Não      Sim
# 9             Não  Masculino                  Não          Sim      Sim
# 10            Não  Masculino                  Sim          Sim      Sim
# 11            Não   Feminino                  Não     ignorado      Sim
# 12            Não  Masculino                  Sim          Sim      Sim
# 13            Não  Masculino                  Sim          Sim      Sim
# 14            Não   Feminino                  Não          Sim      Não
# 15            Não   Feminino                  Não          Sim      Não
# 16            Não  Masculino                  Não          Sim      Não
# 17            Não  Masculino                  Não     ignorado      Sim
# 18            Não   Feminino                  Não          Sim      Não
# 19            Não  Masculino                  Não     ignorado      Sim
# 20            Não  Masculino                  Não          Sim      Sim
# 21            Não  Masculino                  Sim          Não      Sim
# 22            Não   Feminino                  Não          Sim      Sim
# 23            Não  Masculino                  Sim          Sim      Sim
# 24            Não   Feminino                  Não          Sim      Não
# 25            Não  Masculino                  Não          Não      Sim
# 26            Não  Masculino                  Não     ignorado      Não
# 27            Não  Masculino                  Não          Sim      Sim
# 28            Não  Masculino                  Não     ignorado      Não
# 29            Não  Masculino                  Não          Sim      Não
# ...           ...        ...                  ...          ...      ...
# 2697          Não   Feminino                  Não          Não      Sim
# 2698          Não  Masculino                  Não          Sim      Sim
# 2699          Não  Masculino                  Não          Sim      Sim
# 2700          Não  Masculino                  Sim          Sim      Não
# 2701          Não  Masculino                  Não          Sim      Sim
# 2702          Não  Masculino                  Não     ignorado      Sim
# 2703          Não  Masculino                  Não          Sim      Sim
# 2704          Não   Feminino                  Não          Sim      Sim
# 2705          Não   Feminino                  Não          Não      Sim
# 2706          Não   Feminino                  Não     ignorado      Sim
# 2707          Não   Feminino                  Não          Sim      Não
# 2708          Não  Masculino                  Não          Sim      Não
# 2709          Não   Feminino                  Não     ignorado      Não
# 2710          Não  Masculino                  Sim     ignorado      Não
# 2711          Não  Masculino             ignorado          Sim      Não
# 2712          Não   Feminino                  Não     ignorado      Sim
# 2713          Não   Feminino             ignorado     ignorado      Sim
# 2714          Não  Masculino                  Não     ignorado      Sim
# 2715          Sim  Masculino                  Sim     ignorado      Não
# 2716          Não   Feminino             ignorado     ignorado      Sim
# 2717          Não  Masculino                  Não          Não      Sim
# 2718          Não   Feminino                  Sim          Sim      Sim
# 2719          Não   Feminino                  Não          Sim      Sim
# 2720          Não   Feminino             ignorado          Não      Sim
# 2721          Não   Feminino                  Sim          Sim      Sim
# 2722          Não  Masculino                  Não     ignorado      Sim
# 2723          Não  Masculino                  Não     ignorado      Sim
# 2724          Não  Masculino                  Não     ignorado      Sim
# 2725          Não  Masculino                  Não     ignorado      Sim
# 2726          Não  Masculino                  Não     ignorado      Não
#
#      Semanas_tosse Sudorese_noturna Febre  Estado_civil_viúvo Delegacia_2anos  \
# 0         ignorado              Não   Não                 0.0             Não
# 1              Não              Não   Não                 0.0             Não
# 2              Sim              Não   Sim                 1.0             Não
# 3              Sim              Não   Não                 0.0             Não
# 4              Não              Sim   Não                 0.0             Não
# 5              Sim              Sim   Sim                 0.0             Não
# 6              Sim              Não   Não                 0.0             Não
# 7              Não              Não   Não                 0.0             Não
# 8              Sim              Sim   Sim                 0.0             Não
# 9              Sim              Não   Não                 0.0             Não
# 10             Sim              Não   Sim                 0.0             Não
# 11             Não              Sim   Sim                 0.0             Não
# 12             Sim              Sim   Sim                 0.0             Não
# 13             Sim              Sim   Sim                 0.0             Não
# 14             Não              Não   Sim                 0.0             Não
# 15             Sim              Não   Sim                 0.0             Não
# 16             Não              Não   Não                 0.0             Não
# 17             Sim              Não   Sim                 0.0             Não
# 18             Não              Não   Não                 0.0             Não
# 19             Sim              Não   Sim                 0.0             Não
# 20             Sim              Sim   Sim                 0.0             Não
# 21             Sim              Sim   Não                 0.0             Não
# 22             Sim              Sim   Sim                 0.0             Não
# 23             Não              Sim   Sim                 0.0             Não
# 24             Sim              Sim   Não                 0.0             Não
# 25             Sim              Não   Não                 0.0             Não
# 26             Sim              Não   Sim                 0.0             Não
# 27             Sim              Não   Sim                 0.0             Não
# 28             Sim              Não   Não                 0.0             Não
# 29             Não              Sim   Sim                 0.0             Não
# ...            ...              ...   ...                 ...             ...
# 2697           Não              Não   Não                 0.0             Não
# 2698           Não              Não   Não                 0.0             Não
# 2699           Não              Sim   Sim                 0.0             Não
# 2700           Não              Não   Sim                 0.0             Não
# 2701           Não              Sim   Não                 0.0             Não
# 2702           Sim              Sim   Sim                 0.0             Não
# 2703           Não              Sim   Sim                 0.0             Não
# 2704           Sim              Não   Sim                 0.0             Não
# 2705           Não              Não   Sim                 0.0             Não
# 2706           Não              Não   Não                 0.0             Não
# 2707           Não              Não   Não                 0.0             Não
# 2708           Sim              Sim   Não                 0.0             Não
# 2709           Não              Não   Sim                 0.0             Não
# 2710           Não              Sim   Sim                 0.0             Não
# 2711           Sim              Não   Sim                 0.0             Não
# 2712           Não              Não   Sim                 0.0             Não
# 2713           Sim              Não   Não                 0.0             Não
# 2714           Sim              Sim   Não                 0.0             Não
# 2715           Não              Sim   Sim                 0.0             Sim
# 2716           Sim              Sim   Não                 0.0             Não
# 2717           Não              Sim   Não                 0.0             Não
# 2718           Sim              Sim   Não                 0.0             Não
# 2719           Sim              Não   Sim                 0.0             Não
# 2720           Não              Não   Não                 0.0             Não
# 2721           Não              Sim   Sim                 0.0             Não
# 2722           Sim              Não   Sim                 0.0             Não
# 2723           Não              Não   Não                 1.0             Não
# 2724           Não              Não   Sim                 0.0             Não
# 2725           Não              Sim   Não                 0.0             Não
# 2726           Sim              Não   Não                 0.0             Não
#
#       Estado_civil_Casado  Estado_civil_Solteiro Expectoração desfecho  Idade
# 0                     0.0                    1.0          Não      TB+     30
# 1                     0.0                    0.0          Sim      TB+     53
# 2                     0.0                    0.0          Sim      TB+     84
# 3                     0.0                    1.0          Não      TB+     18
# 4                     0.0                    1.0          Sim      TB+     36
# 5                     1.0                    0.0          Sim      TB+     71
# 6                     0.0                    1.0          Sim      TB+     26
# 7                     0.0                    1.0          Não      TB+     22
# 8                     1.0                    0.0          Sim      TB+     54
# 9                     0.0                    1.0          Não      TB+     52
# 10                    0.0                    1.0          Sim      TB+     57
# 11                    0.0                    1.0          Sim      TB+     32
# 12                    0.0                    1.0          Sim      TB+     21
# 13                    0.0                    1.0          Sim      TB+     23
# 14                    1.0                    0.0          Sim      TB+     50
# 15                    0.0                    1.0          Não      TB+     23
# 16                    0.0                    1.0          Sim      TB+     18
# 17                    0.0                    1.0          Sim      TB+     24
# 18                    0.0                    1.0          Sim      TB+     27
# 19                    0.0                    1.0          Não      TB+     19
# 20                    0.0                    1.0          Sim      TB+     36
# 21                    0.0                    1.0          Sim      TB+     58
# 22                    0.0                    1.0          Não      TB+     32
# 23                    1.0                    0.0          Sim      TB+     47
# 24                    1.0                    0.0          Sim      TB+     30
# 25                    1.0                    0.0          Sim      TB+     63
# 26                    1.0                    0.0          Não      TB+     46
# 27                    0.0                    1.0          Sim      TB+     22
# 28                    1.0                    0.0          Não      TB+     52
# 29                    0.0                    1.0          Sim      TB+     20
# ...                   ...                    ...          ...      ...    ...
# 2697                  1.0                    0.0          Não      TB-     65
# 2698                  1.0                    0.0          Não      TB-     57
# 2699                  0.0                    1.0          Não      TB-     18
# 2700                  0.0                    1.0          Sim      TB-     35
# 2701                  0.0                    1.0          Não      TB-     45
# 2702                  0.0                    1.0          Não      TB-     25
# 2703                  1.0                    0.0          Sim      TB-     44
# 2704                  0.0                    1.0          Sim      TB-     36
# 2705                  1.0                    0.0          Não      TB-     62
# 2706                  1.0                    0.0          Não      TB-     38
# 2707                  0.0                    1.0          Não      TB-     24
# 2708                  0.0                    1.0          Não      TB+     24
# 2709                  0.0                    1.0          Não      TB+     24
# 2710                  0.0                    1.0          Não      TB+     29
# 2711                  0.0                    1.0          Sim      TB-     29
# 2712                  1.0                    0.0          Não      TB-     61
# 2713                  0.0                    0.0          Sim      TB-     59
# 2714                  1.0                    0.0          Não      TB-     58
# 2715                  0.0                    1.0          Sim      TB+     28
# 2716                  0.0                    1.0          Não      TB+     37
# 2717                  1.0                    0.0          Não      TB-     49
# 2718                  0.0                    1.0          Sim      TB-     44
# 2719                  0.0                    0.0          Sim      TB-     43
# 2720                  1.0                    0.0          Sim      TB-     33
# 2721                  1.0                    0.0          Sim      TB-     34
# 2722                  1.0                    0.0          Sim      TB-     60
# 2723                  0.0                    0.0          Sim      TB-     60
# 2724                  0.0                    1.0          Sim      TB-     18
# 2725                  1.0                    0.0          Não      TB-     43
# 2726                  0.0                    1.0          Não      TB+     42
#
# [2727 rows x 15 columns]

# %%
normal.columns
# Out:
# Index(['Prisão_2anos', 'Sexo', 'Perda_peso_10percent', 'Cicatriz_BCG',
#        'Dispnéia', 'Semanas_tosse', 'Sudorese_noturna', 'Febre',
#        'Estado_civil_viúvo', 'Delegacia_2anos', 'Estado_civil_Casado',
#        'Estado_civil_Solteiro', 'Expectoração', 'desfecho', 'Idade'],
#       dtype='object')

# %%
a = pd.qcut(normal.Idade,4)

# %%
x = normal.Idade

# %%
plt.title('Boxplot das idades dos pacientes',)
plt.boxplot(normal.Idade.values,vert=False)

plt.show()

# %% [markdown]
# ### 1. Resultados para a seleção utilizando qui-quadrado

# %%
normal.shape
# Out:
# (2727, 15)

# %%
full.columns
full.drop(['Idade.2','Idade.1',
       'Idade.3'],axis=1,inplace=True)

# %%
#
features_normal = list(normal.columns)
features_full   = list(full.columns)

# %%
# One-hot encoding parcial
training_data_chi2 = training_data[features_normal].copy()
test_data_chi2     = test_data[features_normal].copy()

# %%
# One-hot encoding full
training_data_full_chi2 = training_data_full[features_full].copy()
test_data_full_chi2     = test_data_full[features_full].copy()

# %%
# Pré-processamento dos dados
training_data_chi2.replace(['Sim','Não','ignorado','Branco','Não branco','Masculino', 'Feminino','TB+','TB-'],[+1,-1,0,1,0,1,0,1,0],inplace=True)
test_data_chi2.replace(['Sim','Não','ignorado','Branco','Não branco','Masculino', 'Feminino','TB+','TB-'],[+1,-1,0,1,0,1,0,1,0],inplace=True)

# %%
training_data_full_chi2.replace(['Sim','Não','ignorado','Branco','Não branco','Masculino', 'Feminino','TB+','TB-'],[+1,-1,0,1,0,1,0,1,0],inplace=True)
test_data_full_chi2.replace(['Sim','Não','ignorado','Branco','Não branco','Masculino', 'Feminino','TB+','TB-'],[+1,-1,0,1,0,1,0,1,0],inplace=True)

# %%
pd.qcut(normal.Idade,4)
# Out:
# 0        [9, 30]
# 1       (45, 58]
# 2       (58, 93]
# 3        [9, 30]
# 4       (30, 45]
# 5       (58, 93]
# 6        [9, 30]
# 7        [9, 30]
# 8       (45, 58]
# 9       (45, 58]
# 10      (45, 58]
# 11      (30, 45]
# 12       [9, 30]
# 13       [9, 30]
# 14      (45, 58]
# 15       [9, 30]
# 16       [9, 30]
# 17       [9, 30]
# 18       [9, 30]
# 19       [9, 30]
# 20      (30, 45]
# 21      (45, 58]
# 22      (30, 45]
# 23      (45, 58]
# 24       [9, 30]
# 25      (58, 93]
# 26      (45, 58]
# 27       [9, 30]
# 28      (45, 58]
# 29       [9, 30]
#           ...
# 2697    (58, 93]
# 2698    (45, 58]
# 2699     [9, 30]
# 2700    (30, 45]
# 2701    (30, 45]
# 2702     [9, 30]
# 2703    (30, 45]
# 2704    (30, 45]
# 2705    (58, 93]
# 2706    (30, 45]
# 2707     [9, 30]
# 2708     [9, 30]
# 2709     [9, 30]
# 2710     [9, 30]
# 2711     [9, 30]
# 2712    (58, 93]
# 2713    (58, 93]
# 2714    (45, 58]
# 2715     [9, 30]
# 2716    (30, 45]
# 2717    (45, 58]
# 2718    (30, 45]
# 2719    (30, 45]
# 2720    (30, 45]
# 2721    (30, 45]
# 2722    (58, 93]
# 2723    (58, 93]
# 2724     [9, 30]
# 2725    (30, 45]
# 2726    (30, 45]
# Name: Idade, dtype: category
# Categories (4, object): [[9, 30] < (30, 45] < (45, 58] < (58, 93]]

# %%
y = normal.desfecho
X = normal.drop(['desfecho'],axis=1)

# %%
X.Idade = X.Idade.apply(lambda idade : 0 if idade)
# Out:
#      Prisão_2anos       Sexo Perda_peso_10percent Cicatriz_BCG Dispnéia  \
# 0             Não  Masculino                  Não          Sim      Não
# 1             Não   Feminino                  Não     ignorado      Sim
# 2             Não   Feminino                  Sim          Não      Não
# 3             Não   Feminino                  Não          Sim      Sim
# 4             Não  Masculino                  Não     ignorado      Sim
# 5             Não  Masculino                  Não          Sim      Sim
# 6             Não  Masculino                  Não          Não      Sim
# 7             Não   Feminino                  Não          Sim      Sim
# 8             Não  Masculino                  Sim          Não      Sim
# 9             Não  Masculino                  Não          Sim      Sim
# 10            Não  Masculino                  Sim          Sim      Sim
# 11            Não   Feminino                  Não     ignorado      Sim
# 12            Não  Masculino                  Sim          Sim      Sim
# 13            Não  Masculino                  Sim          Sim      Sim
# 14            Não   Feminino                  Não          Sim      Não
# 15            Não   Feminino                  Não          Sim      Não
# 16            Não  Masculino                  Não          Sim      Não
# 17            Não  Masculino                  Não     ignorado      Sim
# 18            Não   Feminino                  Não          Sim      Não
# 19            Não  Masculino                  Não     ignorado      Sim
# 20            Não  Masculino                  Não          Sim      Sim
# 21            Não  Masculino                  Sim          Não      Sim
# 22            Não   Feminino                  Não          Sim      Sim
# 23            Não  Masculino                  Sim          Sim      Sim
# 24            Não   Feminino                  Não          Sim      Não
# 25            Não  Masculino                  Não          Não      Sim
# 26            Não  Masculino                  Não     ignorado      Não
# 27            Não  Masculino                  Não          Sim      Sim
# 28            Não  Masculino                  Não     ignorado      Não
# 29            Não  Masculino                  Não          Sim      Não
# ...           ...        ...                  ...          ...      ...
# 2697          Não   Feminino                  Não          Não      Sim
# 2698          Não  Masculino                  Não          Sim      Sim
# 2699          Não  Masculino                  Não          Sim      Sim
# 2700          Não  Masculino                  Sim          Sim      Não
# 2701          Não  Masculino                  Não          Sim      Sim
# 2702          Não  Masculino                  Não     ignorado      Sim
# 2703          Não  Masculino                  Não          Sim      Sim
# 2704          Não   Feminino                  Não          Sim      Sim
# 2705          Não   Feminino                  Não          Não      Sim
# 2706          Não   Feminino                  Não     ignorado      Sim
# 2707          Não   Feminino                  Não          Sim      Não
# 2708          Não  Masculino                  Não          Sim      Não
# 2709          Não   Feminino                  Não     ignorado      Não
# 2710          Não  Masculino                  Sim     ignorado      Não
# 2711          Não  Masculino             ignorado          Sim      Não
# 2712          Não   Feminino                  Não     ignorado      Sim
# 2713          Não   Feminino             ignorado     ignorado      Sim
# 2714          Não  Masculino                  Não     ignorado      Sim
# 2715          Sim  Masculino                  Sim     ignorado      Não
# 2716          Não   Feminino             ignorado     ignorado      Sim
# 2717          Não  Masculino                  Não          Não      Sim
# 2718          Não   Feminino                  Sim          Sim      Sim
# 2719          Não   Feminino                  Não          Sim      Sim
# 2720          Não   Feminino             ignorado          Não      Sim
# 2721          Não   Feminino                  Sim          Sim      Sim
# 2722          Não  Masculino                  Não     ignorado      Sim
# 2723          Não  Masculino                  Não     ignorado      Sim
# 2724          Não  Masculino                  Não     ignorado      Sim
# 2725          Não  Masculino                  Não     ignorado      Sim
# 2726          Não  Masculino                  Não     ignorado      Não
#
#      Semanas_tosse Sudorese_noturna Febre  Estado_civil_viúvo Delegacia_2anos  \
# 0         ignorado              Não   Não                 0.0             Não
# 1              Não              Não   Não                 0.0             Não
# 2              Sim              Não   Sim                 1.0             Não
# 3              Sim              Não   Não                 0.0             Não
# 4              Não              Sim   Não                 0.0             Não
# 5              Sim              Sim   Sim                 0.0             Não
# 6              Sim              Não   Não                 0.0             Não
# 7              Não              Não   Não                 0.0             Não
# 8              Sim              Sim   Sim                 0.0             Não
# 9              Sim              Não   Não                 0.0             Não
# 10             Sim              Não   Sim                 0.0             Não
# 11             Não              Sim   Sim                 0.0             Não
# 12             Sim              Sim   Sim                 0.0             Não
# 13             Sim              Sim   Sim                 0.0             Não
# 14             Não              Não   Sim                 0.0             Não
# 15             Sim              Não   Sim                 0.0             Não
# 16             Não              Não   Não                 0.0             Não
# 17             Sim              Não   Sim                 0.0             Não
# 18             Não              Não   Não                 0.0             Não
# 19             Sim              Não   Sim                 0.0             Não
# 20             Sim              Sim   Sim                 0.0             Não
# 21             Sim              Sim   Não                 0.0             Não
# 22             Sim              Sim   Sim                 0.0             Não
# 23             Não              Sim   Sim                 0.0             Não
# 24             Sim              Sim   Não                 0.0             Não
# 25             Sim              Não   Não                 0.0             Não
# 26             Sim              Não   Sim                 0.0             Não
# 27             Sim              Não   Sim                 0.0             Não
# 28             Sim              Não   Não                 0.0             Não
# 29             Não              Sim   Sim                 0.0             Não
# ...            ...              ...   ...                 ...             ...
# 2697           Não              Não   Não                 0.0             Não
# 2698           Não              Não   Não                 0.0             Não
# 2699           Não              Sim   Sim                 0.0             Não
# 2700           Não              Não   Sim                 0.0             Não
# 2701           Não              Sim   Não                 0.0             Não
# 2702           Sim              Sim   Sim                 0.0             Não
# 2703           Não              Sim   Sim                 0.0             Não
# 2704           Sim              Não   Sim                 0.0             Não
# 2705           Não              Não   Sim                 0.0             Não
# 2706           Não              Não   Não                 0.0             Não
# 2707           Não              Não   Não                 0.0             Não
# 2708           Sim              Sim   Não                 0.0             Não
# 2709           Não              Não   Sim                 0.0             Não
# 2710           Não              Sim   Sim                 0.0             Não
# 2711           Sim              Não   Sim                 0.0             Não
# 2712           Não              Não   Sim                 0.0             Não
# 2713           Sim              Não   Não                 0.0             Não
# 2714           Sim              Sim   Não                 0.0             Não
# 2715           Não              Sim   Sim                 0.0             Sim
# 2716           Sim              Sim   Não                 0.0             Não
# 2717           Não              Sim   Não                 0.0             Não
# 2718           Sim              Sim   Não                 0.0             Não
# 2719           Sim              Não   Sim                 0.0             Não
# 2720           Não              Não   Não                 0.0             Não
# 2721           Não              Sim   Sim                 0.0             Não
# 2722           Sim              Não   Sim                 0.0             Não
# 2723           Não              Não   Não                 1.0             Não
# 2724           Não              Não   Sim                 0.0             Não
# 2725           Não              Sim   Não                 0.0             Não
# 2726           Sim              Não   Não                 0.0             Não
#
#       Estado_civil_Casado  Estado_civil_Solteiro Expectoração  Idade
# 0                     0.0                    1.0          Não     30
# 1                     0.0                    0.0          Sim     53
# 2                     0.0                    0.0          Sim     84
# 3                     0.0                    1.0          Não     18
# 4                     0.0                    1.0          Sim     36
# 5                     1.0                    0.0          Sim     71
# 6                     0.0                    1.0          Sim     26
# 7                     0.0                    1.0          Não     22
# 8                     1.0                    0.0          Sim     54
# 9                     0.0                    1.0          Não     52
# 10                    0.0                    1.0          Sim     57
# 11                    0.0                    1.0          Sim     32
# 12                    0.0                    1.0          Sim     21
# 13                    0.0                    1.0          Sim     23
# 14                    1.0                    0.0          Sim     50
# 15                    0.0                    1.0          Não     23
# 16                    0.0                    1.0          Sim     18
# 17                    0.0                    1.0          Sim     24
# 18                    0.0                    1.0          Sim     27
# 19                    0.0                    1.0          Não     19
# 20                    0.0                    1.0          Sim     36
# 21                    0.0                    1.0          Sim     58
# 22                    0.0                    1.0          Não     32
# 23                    1.0                    0.0          Sim     47
# 24                    1.0                    0.0          Sim     30
# 25                    1.0                    0.0          Sim     63
# 26                    1.0                    0.0          Não     46
# 27                    0.0                    1.0          Sim     22
# 28                    1.0                    0.0          Não     52
# 29                    0.0                    1.0          Sim     20
# ...                   ...                    ...          ...    ...
# 2697                  1.0                    0.0          Não     65
# 2698                  1.0                    0.0          Não     57
# 2699                  0.0                    1.0          Não     18
# 2700                  0.0                    1.0          Sim     35
# 2701                  0.0                    1.0          Não     45
# 2702                  0.0                    1.0          Não     25
# 2703                  1.0                    0.0          Sim     44
# 2704                  0.0                    1.0          Sim     36
# 2705                  1.0                    0.0          Não     62
# 2706                  1.0                    0.0          Não     38
# 2707                  0.0                    1.0          Não     24
# 2708                  0.0                    1.0          Não     24
# 2709                  0.0                    1.0          Não     24
# 2710                  0.0                    1.0          Não     29
# 2711                  0.0                    1.0          Sim     29
# 2712                  1.0                    0.0          Não     61
# 2713                  0.0                    0.0          Sim     59
# 2714                  1.0                    0.0          Não     58
# 2715                  0.0                    1.0          Sim     28
# 2716                  0.0                    1.0          Não     37
# 2717                  1.0                    0.0          Não     49
# 2718                  0.0                    1.0          Sim     44
# 2719                  0.0                    0.0          Sim     43
# 2720                  1.0                    0.0          Sim     33
# 2721                  1.0                    0.0          Sim     34
# 2722                  1.0                    0.0          Sim     60
# 2723                  0.0                    0.0          Sim     60
# 2724                  0.0                    1.0          Sim     18
# 2725                  1.0                    0.0          Não     43
# 2726                  0.0                    1.0          Não     42
#
# [2727 rows x 14 columns]

# %% [markdown]
# # Caso das features normais, desbalanceado

# %%
# Pré-processamento
X_train = training_data_chi2[training_data_chi2.columns[:-1]]
y_train = training_data_chi2[training_data_chi2.columns[-1]].values

# %%
# Pré-processamento
X_test = test_data_chi2[test_data_chi2.columns[:-1]]
y_test = test_data_chi2[test_data_chi2.columns[-1]].values

# %%
from sklearn.model_selection import cross_val_score

clf = NB()
val_score = cross_val_score(clf,X_train,y_train,cv=10)

# %%
X_test

# %% [markdown]
# # Caso das features expandidas, desbalanceado

# %%
# Pré-processamento
X_train_full = training_data_full_chi2[training_data_full_chi2.columns[:-1]]
y_train_full = training_data_full_chi2[training_data_full_chi2.columns[-1]].values

# %%
# Pré-processamento
X_test_full = test_data_full_chi2[test_data_full_chi2.columns[:-1]]
y_test_full = test_data_full_chi2[test_data_full_chi2.columns[-1]].values
