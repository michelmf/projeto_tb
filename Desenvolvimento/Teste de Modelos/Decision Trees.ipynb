# %% [markdown]
# # K-Nearest Neighbors

# %%
#
from sklearn.neighbors import ... as KNN

# %% [markdown]
# ## Modelo 1 : WHO

# %% [markdown]
# ### Considerando dados ignorados

# %% [markdown]
# ### One-hot Encoding

# %% [markdown]
# ## Modelo 2 : CHI2

# %% [markdown]
# ### Considerando dados ignorados

# %% [markdown]
# ### One-hot Encoding

# %% [markdown]
# ## Modelo 3 : Informação Mútua

# %% [markdown]
# ### Considerando dados ignorados

# %% [markdown]
# ### One-hot Encoding

# %% [markdown]
# ## Modelo 4 : Regressão Logística L1

# %% [markdown]
# ### Considerando dados ignorados

# %% [markdown]
# ### One-hot Encoding

# %% [markdown]
# ## Modelo 5 : Random Forests

# %% [markdown]
# ### Considerando dados ignorados

# %% [markdown]
# ### One-hot Encoding
