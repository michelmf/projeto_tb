# %% [markdown]
# # Análise dos dados
#
# Este notebook tem como objetivo verificar os exemplos presentes na base de dados e selecionar as features mais relevantes para a predição do desfecho.

# %% [markdown]
# ### Análise inicial dos dados

# %%
# Manipulação dos dados
import numpy  as np
import scipy  as sp
import pandas as pd

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn           as sns
# %matplotlib inline

# %%
# Carregando os dados
data = pd.read_csv('../Dados/labels.csv',low_memory=False)

# %%
# Visualização da tabela
data.head(5)
# Out:
#   TB_desfecho_final_Dri Tbafranio Obs_desfechoTB_Dri_Dani Data_inclusão  Nome  \
# 0                    TB       SIM                     NaN      3/abr/08   NaN
# 1                    TB       SIM                     NaN      3/out/06   NaN
# 2                    TB       SIM                     NaN     21/jun/07   NaN
# 3                    TB       SIM                     NaN     30/set/09   NaN
# 4                    TB       SIM                     NaN     19/jun/09   NaN
#
#   Desfecho_tuberculose_lista_Mauro Desfecho_TB_162_Revisão_ADRIANA  \
# 0                                9                              TB
# 1                               TB                              TB
# 2                               TB                              TB
# 3                               TB                              TB
# 4                               TB                          #NULL!
#
#   Observaça0_desfecho_TB Resultado_BAAR_1 Resultado_BAAR_2  \
# 0       TB PROBABILIDADE         Negativo         Negativo
# 1                    NaN         Negativo         Negativo
# 2          TB CONFIRMADA         Negativo         Negativo
# 3                    NaN         Negativo         Negativo
# 4                    NaN         Negativo         Negativo
#
#            ...          Perdeu_aula_hoje_CA Deixou_de_ganhar_dinheiro_hoje_CA  \
# 0          ...                          IGN                               IGN
# 1          ...                          IGN                               IGN
# 2          ...                          IGN                               IGN
# 3          ...                          IGN                               IGN
# 4          ...                          Não                               Não
#
#   Quanto_deixou_ganhar_CA Caso_acompanhado_quem_custeou_tudo_CA  \
# 0                Ignorado                                   IGN
# 1                Ignorado                                   IGN
# 2                Ignorado                                   IGN
# 3                Ignorado                                   IGN
# 4         "Não se aplica"                         não se aplica
#
#         Valor_CA  Avaliador_custo_CA Data_avaliação_custo_CA  \
# 0       ignorado                   9                9/set/99
# 1       ignorado                   9                9/set/99
# 2       ignorado                   9                9/set/99
# 3       ignorado                   9                9/set/99
# 4  não se aplica  Marcia  dos Santos               19/jun/09
#
#   Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER) ANO  de inclusao  \
# 0                                           Selected                  2008
# 1                                           Selected                  2006
# 2                                           Selected                  2007
# 3                                           Selected                  2009
# 4                                       Not Selected                  2009
#
#   Novocriteriotbafranio
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 281 columns]

# %%
# Tipos de dados presentes
data.dtypes.value_counts()
# Out:
# object     268
# int64       11
# float64      2
# dtype: int64

# %%
# Verificando os dados do tipo float64
print('Features do tipo float64: \n{}'.format(list(data.select_dtypes(include=['float64']).columns)))

# Verificando os dados do tipo int64
print('\nFeatures do tipo int64: \n{}'.format(list(data.select_dtypes(include=['int64']).columns)))

# Verificando os dados do tipo object
print('\nFeatures do tipo int64: \n{}'.format(list(data.select_dtypes(include=['object']).columns)))
# Out:
# Features do tipo float64:
# ['Nome', 'Número_cultura']
#
# Features do tipo int64:
# ['Probabilidade_TBP_sem_RX_ou_BAAR', 'Probabilidade_TBP_com_RX_e_BAAR', 'Número_geral', 'Idade', 'Telefone_1', 'Telefone_2', 'CEP', 'Valor_pts_escore', 'Descrever_outros_fármacos', 'ANO  de inclusao', 'Novocriteriotbafranio']
#
# Features do tipo int64:
# ['TB_desfecho_final_Dri', 'Tbafranio', 'Obs_desfechoTB_Dri_Dani', 'Data_inclusão', 'Desfecho_tuberculose_lista_Mauro', 'Desfecho_TB_162_Revisão_ADRIANA', 'Observaça0_desfecho_TB', 'Resultado_BAAR_1', 'Resultado_BAAR_2', 'Resultado_Cultutra_1', 'Resultado_Cultura_2', 'identificado_tb_ntb', 'Houve_desfecho_consulta_médica__inicial', 'Compareceram_consulta_medica', 'TTO_TB_confirmação_bacteriológica', 'TTO_TB_probabilidade', 'Transferência_internação_não_TB_outra_especialidade', 'TTO_pneumologia_patologia_não_TB', 'Alta', 'Descrever_outra_patologia', 'Asma', 'Em_caso_tto_TB_marcar_opções', 'TTO_anterior_TB_triagem_enfermeiro', 'Fator_risco_TBP_MDR', 'Médico_avaliador', 'Data_avaliação_médica', 'Cavitação_alta_média_probabilidade', 'RX_Padrão_TÍPICO_alta_média_probabilidade', 'RX_padrão_COMPATIVEL_alta_média_probabilidade', 'RX_Padrão_ATÍPICO_alta_média_probabilidade', 'RX_baixa_probabilidade_TB_INATIVA_SEQUELA', 'RX_baixa_probabilidade_TB_OUTRA_DOENÇA2', 'RX_baixa_probabilidade_NORMAL', 'Data_RX', 'Tto_TB_prescrito', 'Data_início_TTO', 'Rifampicina_TTO_TB', 'Isoniazida_TTO_TB', 'Pirazinamida_TTO_TB', 'Etambutol_TTO_TB', 'Data_coleta_escarro_1', 'Espécime_1', 'Data_coleta_escarro_2', 'Espécime_2', 'Número_cruzes_BAAR_1', 'Número_cruzes_BAAR_2', 'Resultado_BAAR_Final', 'Número_Cruzes_Cultura_1', 'Número_cruzes_Cultura_2', 'VAR00003', 'Escore_Cat', 'Probabilidade_médica_TB_ativa', 'Probabilidade_TBP_com_RX', 'Probabilidade_TBP_comRX_e_sem_BAAR', 'Probabilidade_TBP_com_RX_sem_BAAR_percent', 'Probabilidade_TBP_com_2_BAAR_negativos', 'Resultado_cultura_final', 'Realizou_RX', 'Karen_amostra', 'Prontuário_PAAP', 'TSA', 'Óbito', 'Causa_óbito', 'Número_laboratório', 'Detect_TB_Primeira_amostra', 'Número_cultura_segunda_amostra', 'Detect_TB_Segunda_amostra', 'Biometrix_inserido_tabela_por_nomes', 'Resultado_biometrix_CTMtb', 'Resultados_biometrix_CTinterno', 'Resultado_biometrix_bula', 'N°_TB', 'Cicatriz_BCG', 'Data_TB_passado', 'Desfecho_TB', 'Tto_anterior_TB_avaliação_médica', 'Tto_anterior_TB_INH', 'Tto_anterior_TB_RIF', 'Esquema_utilizado_tto_anterior', 'Quimio_prévia', 'Quimio_INH', 'Quimio_RIF', 'Data_quimio', 'Desfecho_quimio', 'HIV', 'Comorbidades', 'Nome_mãe', 'Endereço2', 'Bairro_Residência', 'Cidade_residência', 'Data_nascimento', 'Naturalidade_cidade', 'Naturalidade_estado2', 'Mora_no_Rio_há_quantos_anos', 'Sexo', 'Raça', 'Raça_2', 'Estado_civil', 'Tem_companheiro', 'Peso_habitual', 'Peso_atual', 'Altura_cm', 'Tosse', 'Semanas_tosse', 'Expectoração', 'Semanas_expectoração', 'Hemoptóicos', 'Semanas_hemoptóicos', 'Hemoptise', 'Semanas_hemoptise', 'Quantidade_hemoptise', 'Sudorese_noturna', 'Semanas_sudorese', 'Febre', 'Semanas_febre', 'Dispnéia', 'Dispnéia_semanas', 'Perda_de_apetite', 'Perda_apetite_semanas', 'Perda_peso_10percent', 'Perda_peso_semanas', 'Dor_torácica', 'Dor_torácica_semanas', 'Total_escore_Paulo', 'Internação_hospital_2anos', 'Prisão_2anos', 'Delegacia_2anos', 'Contato_TBP_2anos', 'TBP_Morava_com_vc', 'TBP_trabalhava_com_vc', 'TBP_amigo_parente_não_morava_com_vc', 'Contato_TBP_menor_3anos', 'Contato_TBP_Casa', 'Contato_TBP_Trabalho', 'Contato_TBP_Social', 'Fuma', 'Número_cigarros_dia', 'Número_anos', 'Cerveja', 'Vinho', 'Whisky', 'Cachaça', 'Outras_bebidas_alcoólicas', 'Nenhuma_bebida_alcoólica', 'CAGE', 'Desfecho_enfermeiro', 'Descrever_outros_defechos', 'Incluído_TB_Adapt', 'Critério_1_TB_Adapt_tosse_por_mais_2_semanas', 'Critério_2_TB_Adapt_assinou_TCLE', 'Data_assinatura_TCLE', 'Aplicou_PPD', 'Data_aplicação__PT', 'Leu_PT', 'Data_leitura_PT', 'Resultado_PPT_mm', 'Leitor_PT', 'Enfemeiro_avaliação', 'Data_avaliação', 'Data_HIV', 'IRC', 'Hepatopatia', 'Etilismo', 'Uso_corticoide', 'Neo_maligna', 'Transplante', 'DM_NID', 'DM_ID', 'Silicose', 'DPOC', 'Doença_pumonar_difusa', 'Outras', 'descrever_outras_comorbidades2', 'Critério_de_entrada_perfil_bacteriologico_Fup', 'Etionamida_TTO_TB', 'Estreptomicina_TTO_TB', 'Ofolxacino_TTO_TB', 'Outros_fármacos', 'Reação_Adversa_Fármacos_TTO_TB', 'Reação_adversa_maior', 'Exan ...

# %% [markdown]
# ### Seleção de features: primeiro filtro
#
# A primeira avaliação de features tem como objetivo eliminar variáveis que não possuem informação sobre a predição da doença. Tais variáveis a serem eliminadas são: informações pessoais do paciente, datas de exames, profissional avaliador, entre outras informações que não são relevantes.

# %% [markdown]
# #### Features do tipo float64

# %% [markdown]
# As features Nome e Número_cultura não apresentam informações relevantes para a predição dos desfechos, pois representam o nome do paciente e o número de identificação utilizado para catálogo do teste de cultura.

# %%
# Removendo os atributos irrelevantes do tipo float64
data.drop(['Nome', 'Número_cultura'],axis=1,inplace=True)

# %% [markdown]
# #### Features do tipo int64

# %% [markdown]
# As features Número_geral, Telefone_1, Telefone_2, CEP e ANO  de inclusao não possuem informações relevantes. A feature Novocriteriotbafranio representa um desfecho que não é considerado no estudo.

# %%
# Removendo os atributos irrelevantes
data.drop(['Número_geral', 'Telefone_1', 'Telefone_2', 'CEP', 'ANO  de inclusao', 'Valor_pts_escore'],axis=1,inplace=True)

# Novocriteriotbafranio: desfecho não considerado no estudo
data.drop(['Novocriteriotbafranio'],axis=1,inplace=True)

# %% [markdown]
# #### Features do tipo Object

# %% [markdown]
# As features a serem desconsideradas seguem o mesmo critério de seleção descrito anteriormente.

# %%
# Desfechos desconsiderados no estudo.
data.drop(['Tbafranio', 'Obs_desfechoTB_Dri_Dani', 'Data_inclusão', 
           'Desfecho_tuberculose_lista_Mauro', 'Desfecho_TB_162_Revisão_ADRIANA', 
           'Observaça0_desfecho_TB'],axis=1,inplace=True)

# %%
# Atributos com informações descorrelacionadas com o desfecho
data.drop(['Escore_Cat','VAR00003','Data_início_TTO','Data_coleta_escarro_1','Data_RX','Médico_avaliador', 'Data_avaliação_médica',
           'Médico_avaliador_Fup', 'Data_Fup', 'Onde_vc_mora_CA', 'Transporte_CA', 'Custo_transporte_reais_CA', 
           'Acompanhado_CA', 'Número_pessoas_CA', 'Horas_saiu_de_casa_CA', 'Horas_Chegou_posto_CA', 'Horas_viu_profissional_CA', 
           'Tempo_até_o_posto_minutos_CA', 'Caso_FORA_DO_RJ_retorno_onde_pernoitar_CA', 'Pagará_pernoite', 'Valor_pernoite_CA', 
           'Trouxe_algo_amigos_CA', 'Valor_algo_CA', 'Comeu_bebeu_CA', 'Valor_comida_bebida_CA', 'Pagou_algo_no_posto_CA', 'Valor_algo_posto_CA', 
           'Profissão_CA', 'Perdeu_aula_hoje_CA', 'Deixou_de_ganhar_dinheiro_hoje_CA', 'Quanto_deixou_ganhar_CA', 'Caso_acompanhado_quem_custeou_tudo_CA', 
           'Valor_CA', 'Avaliador_custo_CA', 'Data_avaliação_custo_CA', 'Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER)','Data_coleta_escarro_2',
           'Karen_amostra','Prontuário_PAAP', 'Óbito', 'Causa_óbito', 'Número_laboratório', 'Número_cultura_segunda_amostra', 'Biometrix_inserido_tabela_por_nomes', 
           'Resultado_biometrix_CTMtb','N°_TB', 'Data_TB_passado', 'Data_quimio', 'Nome_mãe', 'Endereço2','Bairro_Residência', 'Cidade_residência', 'Data_nascimento', 
           'Naturalidade_cidade', 'Naturalidade_estado2', 'Mora_no_Rio_há_quantos_anos', 'Total_escore_Paulo', 'Número_anos', 'Data_assinatura_TCLE', 
           'Data_aplicação__PT', 'Data_leitura_PT', 'Leitor_PT', 'Enfemeiro_avaliação', 'Data_avaliação', 'Data_HIV', 'Data_mudança', 'Motivo_mudança', 
           'Descrever_outro_motivo_mudança','Data_RX_Fup', 'Data_anti_HIV'],axis=1,inplace=True)

# %%
# Após a primeira avaliação das features
data.shape
# Out:
# (4381, 196)

# %% [markdown]
# Após análise inicial, foram eliminadas 84 variáveis.

# %%
# Verificação das features até o momento:
for feature in list(data.columns):
    print(feature,end='\n')
    print(data[feature].unique(),end='\n\n')
# Out:
# TB_desfecho_final_Dri
# ['TB' 'Não TB' 'IGN' '8']
#
# Resultado_BAAR_1
# ['Negativo' 'Positivo' 'Não realizado/Desconhecido' 'IGN']
#
# Resultado_BAAR_2
# ['Negativo' 'Positivo' 'Não realizado/Desconhecido' 'IGN']
#
# Resultado_Cultutra_1
# ['negativo' 'positivo' 'NR' 'contaminada' 'IGN' 'prejudicada']
#
# Resultado_Cultura_2
# ['negativo' 'positivo' 'NR' 'contaminada' 'prejudicada' 'IGN']
#
# identificado_tb_ntb
# [nan 'MTB' 'MNT']
#
# Houve_desfecho_consulta_médica__inicial
# ['Sim' 'IGN' '8' 'Não']
#
# Compareceram_consulta_medica
# ['Sim' 'Não']
#
# TTO_TB_confirmação_bacteriológica
# ['Não' 'Sim' 'IGN' 'não se aplica']
#
# TTO_TB_probabilidade
# ['Sim' 'Não' 'IGN' 'não se aplica']
#
# Transferência_internação_não_TB_outra_especialidade
# ['Não' 'Sim' 'IGN' 'não se aplica']
#
# TTO_pneumologia_patologia_não_TB
# ['Não' 'Sim' 'IGN' 'não se aplica']
#
# Alta
# ['Não' 'IGN' 'Sim' 'não se aplica']
#
# Descrever_outra_patologia
# ['TB Ganglionar-BX' 'SEQUELA TB' 'Sequela TB' 'Rinite + Sinusite' 'MNT'
#  'mnt' 'Em observação' 'Asma' '9' '8' 'Rinite' 'Pneumonia bacteriana'
#  'Pneumonia' 'Massa Pulmonar' 'Investigação por TC Torax'
#  'Investigação Massa Pulmonar' 'Enfisema Pulmonar' 'DPOC'
#  'Continuar ivestigação' 'Continuar investigação'
#  'Bronquiectasia Infectada' 'Abcesso Pulmonar' 'Sinusite' 'Asma? DPOC?'
#  'DPOC/SEQUELA TB' 'bronquite cronica' '0' 'Sequela TB + Pneumonia'
#  'Bronquite Crônica Tabágica' 'Pneumonia tratada' 'Observação'
#  'DPOC? Neo Pulmão? Derrame Pleural' 'Agurda cultura MTB'
#  'Aguarda Resultado Cutura' 'TB - IRA' 'Penumonia tratada'
#  'Derrame Pleural + sind. Consuptiva' 'Bronquiectasia por Sequela TB'
#  'asma+icc+sequela tb' 'Asma e Rinite' nan 'Tabagismo + DPOC' 'Tabagismo'
#  'Sinusite + Rinite' 'Sindrome Pulmonar Restritiva' 'Seuqela TB'
#  'Sequela Tb + Asma' 'SEQUELA TB - DPOC + Bronquiectasia'
#  'Rinossinusite + Pneumonia' 'Rinossinusite' 'Rinite+ Asma' 'Quadro Viral'
#  'Quadro Gripal Convalescido' 'Pneumonia bacteriana tratada'
#  'Pneumonia Bacteriana Periférica' 'Pneumonia Bacteriana já melhorada'
#  'Pneumonia + Sida' 'pneumonia' 'Penumonia + Sinusite'
#  'Paneumonia Bacteriana' 'Massa Torácica' 'Massa Bronquica'
#  'Infecção Bronquica + SIDA' 'DPOC+Pneumonia' 'DPOC, HAS'
#  'DPOC, Bronquiectasia Infectada' 'DPOC + Tabagismo' 'DPOC + Pneumonia'
#  'DPOC + Massa PUlmonar' 'Coronariopatia' 'c' 'bronquite Infeciosa'
#  'Bronquite Crônica' 'Bronquite crônica' 'Bronquite aguda' 'Bronquite'
#  'Bronquiectasias Infectadas' 'Bronquiectasias' 'Bronquiectasia'
#  'Bonquiectasia' 'Asma+Sinusite Aguda' 'Asma?' 'Asma Brônquica'
#  'Asma Bronquica' 'Asma + Sequela TB' 'Asma + Bronquite Tabágica' 'ASma'
#  'asma' 'Asma- SEQUELA TB' 'Anemia ferropriva + HIV +?'
#  'Adenomegalia + Odinofagia' 'Tabgismo + DPOC' 'Rinosinusite'
#  'Pneumonia Bacteriana' 'Pneumonia + Asma' 'ILTB?' 'Asma + Enfisema' '999'
#  'Rinossinusite + Asma' 'Penumonia já tratada' 'Contusão Pulmonar + DPOC'
#  'Bronquite Cr^nica tabágica' 'Asma bronquica']
#
# Asma
# ['Não' 'Sim' '#NULL!']
#
# Em_caso_tto_TB_marcar_opções
# ['retorno pós abandono' 'Recidiva' 'IGN' '0' 'Virgem de tto'
#  'não se aplica' 'Falência']
#
# TTO_anterior_TB_triagem_enfermeiro
# ['Sim' 'Não' 'IGN']
#
# Fator_risco_TBP_MDR
# ['IGN' '0' 'Suspeita de recidiva' 'Suspeita de falência' 'não se palica'
#  'Contato íntimo de caso TBP MDR']
#
# Cavitação_alta_média_probabilidade
# ['Não' 'IGN' 'Sim' 'não se aplica']
#
# RX_Padrão_TÍPICO_alta_média_probabilidade
# ['Não' 'Sim' 'IGN' 'não se aplica' '2' '3']
#
# RX_padrão_COMPATIVEL_alta_média_probabilidade
# ['Sim' 'Não' 'IGN' 'não se aplica']
#
# RX_Padrão_ATÍPICO_alta_média_probabilidade
# ['Não' 'Sim' 'IGN' 'não se aplica']
#
# RX_baixa_probabilidade_TB_INATIVA_SEQUELA
# ['não se aplica' 'Sim' 'Não' 'IGN']
#
# RX_baixa_probabilidade_TB_OUTRA_DOENÇA2
# ['não se aplica' 'Não' 'IGN' 'Sim']
#
# RX_baixa_probabilidade_NORMAL
# ['não se aplica' 'Não' 'IGN' 'Sim']
#
# Tto_TB_prescrito
# ['Sim' 'IGN' 'Não' nan]
#
# Rifampicina_TTO_TB
# ['Sim' 'IGN' '"não se aplica"' 'Não']
#
# Isoniazida_TTO_TB
# ['Sim' 'IGN' '"não se aplica"' 'Não' '2']
#
# Pirazinamida_TTO_TB
# ['Sim' 'IGN' '"não se aplica"' 'Não']
#
# Etambutol_TTO_TB
# ['Sim' 'Não' 'IGN' '"não se aplica"']
#
# Espécime_1
# ['Espontâneo' 'IGN' 'Induzido']
#
# Espécime_2
# ['Espontâneo' 'IGN' 'Induzido' '0' '8']
#
# Número_cruzes_BAAR_1
# ['não se aplica' '1+' '2+' '3+' 'IGN' '0' '4']
#
# Número_cruzes_BAAR_2
# ['não se aplica' '3+' '4' '1+' 'IGN' '2+']
#
# Resultado_BAAR_Final
# ['#NULL!' 'Negativo' 'Positivo' 'IGN']
#
# Número_Cruzes_Cultura_1
# ['não se aplica' '1+' '< 19 c' '2+' '3+' 'IGN']
#
# Número_cruzes_Cultura_2
# ['não se aplica' '1+' '< 19 c' '2+' '3+' 'IGN']
#
# Probabilidade_médica_TB_ativa
# ['Média' 'Baixa' 'IGN' 'Alta' nan]
#
# Probabilidade_TBP_sem_RX_ou_BAAR
# [ 50  20  40  10 999  60  65  75  30  70  15  25  45  80  55  35  95 888
#   90  85   5   1   0]
#
# Probabilidade_TBP_com_RX
# ['Média' 'Baixa' 'IGN' 'Alta' nan]
#
# Probabilidade_TBP_comRX_e_sem_BAAR
# ['Alta' 'Baixa' 'Média' 'IGN' nan]
#
# Probabilidade_TBP_com_RX_sem_BAAR_percent
# ['80' '20' '40' '30' '999' '75' '50' '70' '85' '90' '60' '65' '5' '45' '25'
#  '888' '10' '15' '55' '100' '95' '35' 'IGN' '2' '0']
#
# Probabilidade_TBP_com_2_BAAR_negativos
# ['Alta' 'Baixa' 'Média' 'IGN' '"não se aplica"']
#
# Probabilidade_TBP_com_RX_e_BAAR
# [ 90  15  10  30 999  75  80  50  70  85  60  65  25  95  40  35  20   5
#   55 888   1 100   0   9   8  45   2]
#
# Resultado_cultura_final
# ['Negativo' 'Positivo' 'NR' 'IGN']
#
# Realizou_RX
# ['Sim' 'Não']
#
# TSA
# ['na' 'sens' 'prej' 'ign' 'res']
#
# Detect_TB_Primeira_amostra
# ['#NULL!' 'Negativo' 'Positivo']
#
# Detect_TB_Segunda_amostra
# ['#NULL!' 'Negativo' 'Positivo']
#
# Resultados_biometrix_CTinterno
# ['#NULL!' '41,38' '22,86' '30,09' '27,18' '29,34' '20,60' '33,56'
#  '317899,00' '26,67' '30,53' '33,25' '33,24' '26,04' '22,76' '29,30'
#  '29,75' '30,41' '23,31' '26,47' '34,09' '21,94' '23,95' '25,78' '26,56'
#  '24,02' '25,34' '31,59' '31,83' '24,65' '28,24' '278807,00' '22,53'
#  '27,55' '25,19' '305554,00' '24,73' '28,15' '20,10' '23,16' '29,69'
#  '23,50' '22,31' '24,32' '28,72' '24,13' '28,63' '28,87' '25,28' '18,36'
#  '22,41' '282947,00' '27,65' '282562,00' '28,73' '20,51' '27,02' '27,86'
#  '28,86' '26,78' '24,33' '20,20' '26,08' '31,17' '29,14' '32,30' '21,30'
#  '22,18' '23,86' '26,46' '21,65' '214503,00' '32,01' '22,97' '28,46'
#  '21,38' '26,14' '26,25' '32,05' '26,68' '28,85' '25,13' '20,66'
#  '303174,00' '25,41' '19,83' '20,98' '193166,00' '25,61' '28,19' '26,65'
#  '200091,00' '25,29' '254576,00' '29,63' '21,15' '32,39' '28,26' '27,80'
#  '25,25' '29,55' '31,55' '28,89' '34,85' '224494,00' '26,64' '36,93'
#  '30,96' '28,70' '26,70' '31,25' '29,32' '35,79' '277391,00' '28,35'
#  '34,86' '31,74' '19,06' '22,00' '31,04' '19,24' '32,22' '271005,00'
#  '31,68' '27,59' '27,33' '27,20' '26,66' '286051,00' '30,20' '30,98'
#  '256222,00' '36,15' '31,84' '24,55' '36,61' '29,83' '27,15' '31,22'
#  '31,82' '25,68' '26,98' '269795,00' '27,51' '296621,00' '28,51' '25,94'
#  '20,90' '25,03' '27,72' '25,16' '28,58' '26,31' '28,42' '25,90' '33,40'
#  '21,59' '27,39' '26,00' '29,94' '32,84' '22,91' '21,35' '32,47' '26,83'
#  '23,68' '24,09' '27,93' '21,36' '25,80' '32,32' '32,37' '24,58' '28,92'
#  '27,88' 'Indeterminado' '29,07' '22,61' '34,99' '26,99' '26,29' '22,58'
#  '23,08' '25,53' '24,29' '31,71' '25,30' '29,92' '32,70' '29,40'
#  '212828,00' '24,71' '31,80' '27,26' '293154,00' '33,07' '19,48' '21,00'
#  '31,48' '27,66' '29,04' '26,32' '23,42' '22,95' '27,28' '30,29' '30,61'
#  '27,27' '312432,00' '22506,00' '27,63' '23,76' '30,17' '30,31' '32,17'
#  '26,16' '31,02' '25,96' '34,28' '272697,00' '30,30' '24,21' '26,40'
#  '319457,00' '29291,00' '27,01' '22,70' '23,55' '28,25' '27,50' '264277,00'
#  '30,03' '299632,00' '27,82' '32,83' '28,04' '29,33' '23,61' '30,62'
#  '27,49' '42,55' '24,06' '25,52' '28,88' '29,71' '32,07' '30,37' '22,64'
#  '31,35' '22,17' '22,35' '29,12' '28,69' '28,16' '27,54' '29,60'
#  '258841,00' '19,96' '28,32' '27,53']
#
# Resultado_biometrix_bula
# ['#NULL!' 'Amostra inválida' 'Negativo' 'Positivo']
#
# Cicatriz_BCG
# ['Sim' 'IGN' 'Não']
#
# Desfecho_TB
# ['Abandono' 'IGN' 'não se aplica' 'Cura' 'Completou tto' '0' 'Falência']
#
# Tto_anterior_TB_avaliação_médica
# ['Não' 'Sim' 'IGN' nan]
#
# Tto_anterior_TB_INH
# [nan 'Sim' 'IGN' 'Não']
#
# Tto_anterior_TB_RIF
# [nan 'Não' 'IGN' 'Sim']
#
# Esquema_utilizado_tto_anterior
# ['8' '9' 'RHZ' 'RIP' 'RHZE' 'RHZ 2004, RHZE 2005' 'RHZ, RHZE' 'I (RIF)'
#  'RHZEO' 'RHZ, RHZE, EESZ' '0' 'rhz' 'RHES' 'nao lembra' 'SM + R + INII'
#  'H+SM+Z' 'RHE']
#
# Quimio_prévia
# ['Não' 'Sim' 'IGN' nan]
#
# Quimio_INH
# [nan 'IGN' 'Sim' 'Não']
#
# Quimio_RIF
# [nan 'IGN' 'Não']
#
# Desfecho_quimio
# [nan 'IGN' 'Abandonou']
#
# HIV
# ['Negativo' 'Não realizado/Desconhecido' 'Positivo' 'IGN' nan]
#
# Comorbidades
# ['Sim' 'IGN' 'Não' '8']
#
# Idade
# [ 30  53  84  18  36  71  26  22  54  52  57  32  21  23  50  24  27  19
#   58  47  63  46  20  12  33  17  31  51  66  59  62  41  34  29  14  16
#   70  61  43  44  42  37  73  56  49  39  25  35  45  48  64  68  40  75
#   72  28  55  38  92  67  15  85  65  82  60  13  78  69  74  77  81  86
#   88  79 999  76  93  80  83  89  87  91   9   7   2  96   5   8]
#
# Sexo
# ['Masculino' 'Feminino' '2' 'IGN']
#
# Raça
# ['Não branco' 'Branco' 'IGN' '8']
#
# Raça_2
# ['Negro' 'Não se aplica' 'IGN' 'Mulato' 'Asiático' 'Não sabe' 'Índio']
#
# Estado_civil
# ['Solteiro' nan 'viúvo' 'Casado' 'IGN' 'Separado' '0']
#
# Tem_companheiro
# ['Não' 'Sim' 'IGN']
#
# Peso_habitual
# ['62,0' '75,0' '56,0' '51,0' '63,0' '76,0' '65,0' '55,0' '70,0' '69,0'
#  '45,0' '60,0' '44,0' '48,0' '58,0' '53,0' '92,0' '33,3' '95,0' '64,0'
#  '87,0' '70,5' '90,0' '34,0' '67,0' '999,0' '49,0' '78,0' '68,0' '59,0'
#  '74,0' '66,0' '80,0' '52,0' '91,0' '82,0' '100,0' '50,0' '54,0' '73,0'
#  '42,0' '89,0' '83,0' '77,0' '47,0' '58,4' '62,5' '61,0' '72,0' '79,0'
#  '58,2' '46,0' '81,0' '110,0' '53,5' '57,0' '70,3' '86,5' '140,0' '86,0'
#  '71,0' '55,9' '120,0' '88,0' '43,0' '57,2' '40,0' '57,4' '112,0' '41,0'
#  '84,2' '46,6' '53,8' '38,0' '35,0' '84,0' '54,7' '85,0' '108,0' '47,5'
#  '42,2' '47,8' '36,0' '98,0' '115,0' '102,0' '87,5' '49,5' '96,0' '57,1'
#  '130,0' '77,9' '93,0' '94,0' '57,5' '99,0' '117,0' '56,1' '46,5' '8,0'
#  '66,9' '107,0' '61,5' '77,5' '66,7' '71,6' '105,0' '58,8' '148,0' '68,8'
#  '113,0' '56,8' '111,0' '81,5' '144,0' '49,2' '71,4' '51,5' '48,1' '3,0'
#  '73,8' '56,7' '106,0' '104,3' '68,5' '58,5' '97,0' '54,3' '111,7' '155,0'
#  '66,2' '125,0' '60,6' '41,5' '61,9' '107,7' '45,6' '123,0' '101,0' '50,3'
#  '54,5' '88,8' '104,0' '76,8' '30,0' '127,0' '49,4' '75,6' '89,4' '54,4'
#  '109,0' '64,9' '49,8' '139,5' '39,0' '126,7' '67,5' '71,3' '103,0' '150,0'
#  '96,9' '66,5' '49,9' '69,8' '83,7' '57,9' '65,1' '37,0' '64,5' '58,3'
#  '61,3' '96,4' '48,4' '116,0' '76,5' '63,5' '81,4' '72,2' '122,0' '61,7'
#  '63,7' '91,8' '129,0' '132,0' '101,9' '160,0' '82,6' '60,3' '80,7' '45,5'
#  '33,0' '68,9' '18,5' '55,5' '48,5' '53,2' '78,5' '68,3' '41,3' '52,5'
#  '14,0' '63,9' '78,8' '60,4']
#
# Peso_atual
# ['62,0' '76,0' '48,0' '58,0' '69,0' '66,0' '49,4' '58,5' '43,0' '63,0'
#  '52,0' '42,0' '58,7' '56,0' '54,5' '55,0' '72,3' '84,0' '33,0' '74,5'
#  '66,5' '85,0' '65,0' '70,5' '92,5' '50,0' '32,0' '64,0' '57,0' '70,0'
#  '47,0' '92,3' '999,0' '72,5' '38,0' '35,0' '57,3' '59,5' '53,0' '68,0'
#  '71,0' '61,5' '75,0' '51,0' '67,0' '51,3' '59,0' '48,2' '78,0' '66,8'
#  '45,2' '91,0' '101,0' '44,0' '53,7' '60,0' '57,8' '61,0' '36,5' '73,5'
#  '91,3' '81,0' '41,3' '89,0' '50,5' '92,0' '59,8' '93,3' '82,0' '47,5'
#  '68,4' '54,0' '55,5' '79,0' '58,3' '87,5' '52,5' '46,0' '64,5' '41,5'
#  '51,5' '49,5' '66,3' '55,4' '49,0' '45,0' '73,0' '59,9' '67,7' '51,2'
#  '58,2' '55,7' '53,5' '36,4' '79,5' '72,0' '103,0' '80,3' '62,4' '43,6'
#  '86,5' '126,2' '79,3' '71,5' '36,0' '65,3' '55,1' '48,7' '61,4' '41,2'
#  '68,5' '58,8' '56,6' '48,5' '71,4' '72,1' '48,3' '40,0' '63,8' '41,0'
#  '45,4' '78,2' '53,8' '80,0' '40,6' '44,6' '61,1' '83,0' '58,9' '43,1'
#  '56,9' '79,9' '56,4' '68,3' '62,9' '55,3' '52,4' '47,8' '38,8' '57,2'
#  '62,7' '43,5' '74,8' '54,7' '37,0' '56,5' '75,5' '40,5' '45,3' '45,5'
#  '56,7' '78,8' '57,4' '86,0' '59,3' '62,5' '54,8' '44,5' '39,0' '90,0'
#  '46,7' '56,1' '43,7' '51,4' '45,1' '58,6' '74,0' '38,5' '64,7' '66,9'
#  '39,8' '49,7' '34,0' '52,2' '47,3' '28,0' '69,3' '61,2' '55,2' '48,8'
#  '77,4' '63,3' '63,5' '87,0' '59,4' '52,7' '78,3' '96,0' '85,1' '60,3'
#  '39,7' '77,0' '73,8' '57,5' '94,0' '49,2' '60,9' '87,7' '69,7' '52,9'
#  '50,6' '82,6' '84,8' '46,8' '41,4' '97,0' '52,8' '79,1' '65,7' '83,5'
#  '64,8' '60,5' '88,0' '77,9' '46,5' '70,3' '39,2' '95,0' '49,8' '93,0'
#  '78,5' '53,6' '65,5' '82,8' '45,7' '51,8' '65,8' '61,3' '84,2' '45,8'
#  '102,0' '43,2' '99,0' '117,0' '93,2' '54,6' '59,2' '88,5' '73,7' '67,5'
#  '38,7' '74,3' '44,1' '56,8' '61,7' '105,0' '61,8' '51,9' '110,5' '69,5'
#  '63,6' '53,2' '76,5' '73,9' '74,7' '77,8' '85,5' '48,4' '67,6' '80,7'
#  '52,6' '78,9' '74,4' '65,4' '60,8' '65,9' '48,9' '42,7' '66,7' '63,9'
#  '75,6' '64,6' '109,0' '68,2' '55,9' '65,6' '57,7' '76,8' '38,6' '49,3'
#  '140,0' '60,2' '54,4' '104,4' '62,8' '112,5' '33,7' '70,1' '111,0' '71,6'
#  '79,8' '144,0' '67,4' '72,4' '80,5' '68,7' '62,2' '93,5' '59,6' '57,6'
#  '76,2' '91,5' '59,7' '104,6' '72,2' '74,2' '67,1' '49,6' '78,7' '54,2'
#  '100,0' '68,8' '53,3' '54,9' '60,6' '89,6' '47,1' '58,4' '71,2' '77,5'
#  '67,2' '106,0' '32,3' '54,3' '89,5' '36,3' '46,3' '81,2' '110,0' '155,0'
#  '97,4' '81,5' '100,5' '96,6' '92,4' '116,7' '73,4' '70,8' '43,9' '47,2'
#  '69,6' '65,1' '50,8' '73,3' '67,9' '44,2' '40,2' '61,9' '96,5' '105,3'
#  '42,5' '39,3' '50,2' '47,4' '123,0' '34,5' '63,4' '92,8' '75,2' '37,5'
#  '68,6' '71,7' '72,7' '80,9' '83,9' '64,9' '50,4' '74,1' '77,1' '88,7'
#  '71,9' '71,1' '66,1' '62,6' '57,1' '64,2' '67,3' '67,8' '98,0' '104,0'
#  '119,0' '95,8' '86,8' '52,3' '42,8' '87,6' '82,2' '66,2' '41,9' '30,0'
#  '68,9' '38,3' '127,0' '37,2' '39,5' '89,4' '138,0' '73,6' '107,0' '139,0'
#  '82,5' '73,2' '125,0' '45,6' '84,4' '112,0' '118,0' '93,8' '43,3' '75,8'
#  '40,3' '63,2' '81,3' '95,5' '56,3' '150,0' '74,6' '117,3' '96,9' '63,7'
#  '85,7' '49,9' '83,7' '108,0' '50,3' '57,9' '132,0' '113,0' '130,0' '79,4'
#  '76,3' '60,4' '96,4' '96,8' '84,1' '52,1' '86,1' '47,6' '70,6' '85,2'
#  '97,8' '44,8' '85,3' '120,0' '98,4' '81,4' '55,6' '70,7' '77,6' '69,8'
#  '62,3' '81,8' '83,3' '83,4' '40,4' '31,0' '71,8' '94,2' '72,8' '44,3'
#  '103,6' '89,2' '103,5' '102,3' '81,1' '59,1' '76,6' '104,2' '74,9' '82,1'
#  '99,6' '94,6' '49,1' '39,4' '50,7' '51,1' '63,1' '80,2' '48,1' '77,7'
#  '42,3' '42,9' '36,2' '18,3' '38,2' '97,5' '84,6' '50,1' '60,7' '32,9'
#  '88,6' '31,4' '82,4' '88,8' '86,3' '60,1' '76,4' '91,2' '77,2' '90,1'
#  '76,7' '137,0' '115,0' '99,8' '35,1' '53,4' '43,8' '44,7' '85,8']
#
# Altura_cm
# ['172,00' '159,00' '150,00' '168,00' '174,00' '165,00' '164,00' '162,00'
#  '157,00' '163,00' '188,00' '181,00' '160,00' '169,00' '180,00' '175,00'
#  '183,00' '154,00' '176,00' '167,00' '177,00' '133,00' '166,00' '999,00'
#  '178,00' '170,00' '182,00' '155,00' '145,00' '161,00' '158,00' '156,00'
#  '171,00' '151,00' '149,00' '153,00' '187,00' '146,00' '173,00' '179,00'
#  '152,00' '144,00' '185,00' '142,00' '192,00' '147,00' '156,50' '189,00'
#  '190,00' '148,00' '198,00' '186,00' '191,00' '196,00' '140,00' '195,00'
#  '184,00' '143,00' '138,50' '138,00' '141,00' '127,00' '134,00' '139,00'
#  '137,00' '193,00' '115,00' '148,50']
#
# Tosse
# ['Sim' 'Não' 'IGN']
#
# Semanas_tosse
# ['ignorado' '2' '3' '20' '4' '104' '5' '1' '8' '0' '48' 'não se aplica'
#  '18' '12' '6' 'crônico+sempre' '16' '72' '10' '24' '52' '28' '32' '9' '40'
#  '7' '13' '180' '36' '14' '19' '448' '44' '50' '30' '96' '15' '56' '58'
#  '80' '38' '144']
#
# Expectoração
# ['Não' 'Sim' 'IGN' '8']
#
# Semanas_expectoração
# ['não se aplica' '2' '3' '4' '104' '5' '1' '8' '0' '18' '9' '6' '20' '24'
#  '12' '16' '48' '32' '10' '40' 'ignorado' '13' '7' '36' 'crônico+sempre'
#  '52' '14' '96' '19' '44' '50' '30' '333' '72' '15' '28' '58' '80' '38']
#
# Hemoptóicos
# ['Não' 'Sim' 'IGN' '8']
#
# Semanas_hemoptóicos
# ['não se aplica' '0' '52' '3' '1' '4' 'ignorado' '2' '8' '5' '6' '18' '12'
#  '16' '15' '9' '48' '32' '88' 'crônico+sempre' '24' '144']
#
# Hemoptise
# ['Não' 'Sim' 'IGN' '8']
#
# Semanas_hemoptise
# ['não se aplica' '3' '0' '4' '1' 'ignorado' '2' '8' '12' '6' '15' '16' '32']
#
# Quantidade_hemoptise
# ['888,0' '< 1 copinho de café' 'Não se aplica' '> 1 copinho de café' 'IGN'
#  '999,0' '>= 1 copo de geléia']
#
# Sudorese_noturna
# ['Não' 'Sim' '9']
#
# Semanas_sudorese
# ['não se aplica' '0' '3' '1' '4' '8' '2' '5' 'ignorado' '20' '6' '18' '12'
#  '24' '48' '9' '10' '16' 'crônico+sempre' '14' '19' '32' '88' '36' '28'
#  '96' '52' '180' '15']
#
# Febre
# ['Não' 'Sim' 'IGN']
#
# Semanas_febre
# ['não se aplica' '3' '0' '1' '4' '2' '8' '5' 'ignorado' '20' '6' '18' '10'
#  '12' '16' '88' '24' '48' '9' 'crônico+sempre' '7' '28' '96' '15']
#
# Dispnéia
# ['Não' 'Sim' 'IGN' '2']
#
# Dispnéia_semanas
# ['não se aplica' '2' '20' '4' '104' '1' '5' '8' '48' '3' 'ignorado' '12'
#  '0' '18' '6' '24' '32' 'crônico+sempre' '16' '9' '10' '40' '7' '14' '19'
#  '44' '52' '15' '56' '58' '28' '80' '78' '50' '30' '38' '180' '156' '36'
#  '96']
#
# Perda_de_apetite
# ['Não' 'IGN' 'Sim']
#
# Perda_apetite_semanas
# ['não se aplica' 'ignorado' '4' '3' '1' '8' '0' '5' '9' '20' '6' '2' '16'
#  '12' '24' '32' '18' '52' '10' 'crônico+sempre' '7' '48' '14' '30' '80'
#  '40']
#
# Perda_peso_10percent
# ['Não' 'Sim' 'IGN']
#
# Perda_peso_semanas
# ['não se aplica' '3' '4' '8' '12' '9' 'ignorado' '2' '6' '20' '48' '24'
#  '16' '1' '5' 'crônico+sempre' '17' '18' '10' '32' '90' '0' '40' '8888'
#  '30' '36' '15' '104' '29' '52' '28' '96' '38' '19' '44' '25']
#
# Dor_torácica
# ['Não' 'Sim' 'IGN']
#
# Dor_torácica_semanas
# ['não se aplica' '3' '20' '0' '104' '2' '1' '5' '8' '4' 'ignorado' '6' '18'
#  '24' '12' '32' '50' '16' '48' '9' '10' '7' '40' 'crônico+sempre' '14' '19'
#  '52' '96' '56' '58' '28' '80' '180' '44' '15']
#
# Internação_hospital_2anos
# ['Sim' 'Não' 'IGN']
#
# Prisão_2anos
# ['Não' 'Sim' 'IGN']
#
# Delegacia_2anos
# ['Não' 'IGN' 'Sim']
#
# Contato_TBP_2anos
# ['Não' 'Sim' 'IGN']
#
# TBP_Morava_com_vc
# ['não se aplica' 'Não' 'Sim' 'IGN']
#
# TBP_trabalhava_com_vc
# ['não se aplica' 'Não' 'Sim' 'IGN']
#
# TBP_amigo_parente_não_morava_com_vc
# ['não se aplica' 'Não' 'Sim' 'IGN']
#
# Contato_TBP_menor_3anos
# ['não se aplica' 'Não' 'Sim' 'IGN']
#
# Contato_TBP_Casa
# ['não se aplica' 'Não' 'Sim' 'IGN']
#
# Contato_TBP_Trabalho
# ['não se aplica' 'Não' 'Sim' 'IGN']
#
# Contato_TBP_Social
# ['não se aplica' 'Não' 'Sim' 'IGN']
#
# Fuma
# ['Fumante' 'Ex-fumante' 'Jamais fumante' 'IGN']
#
# Número_cigarros_dia
# ['5' '20' 'ignorado' 'não se aplica' '30' '40' '1' '60' '15' '6' '4' '10'
#  '12' '8' '7' '3' '2' '25' '50' '35' '18' '13' '80' '9' '120' '55' '21'
#  '14' '45' '99' '16' '100' '44' '0']
#
# Cerveja
# ['Sim' 'Não' 'IGN']
#
# Vinho
# ['Sim' 'Não' '10' 'IGN']
#
# Whisky
# ['Não' 'Sim' 'IGN']
#
# Cachaça
# ['Não' 'Sim' 'IGN']
#
# Outras_bebidas_alcoólicas
# ['Sim' 'Não' 'IGN']
#
# Nenhuma_bebida_alcoólica
# ['Não' 'Sim' 'IGN']
#
# CAGE
# ['Negativo' 'Positivo' 'IGN']
#
# Desfecho_enfermeiro
# ['Encaminhado para atendimento_pneumologia'
#  'Encaminhado para atendimento_TB' 'Outros' 'IGN'
#  'Encaminhado para atendimento_outra especialidade']
#
# Descrever_outros_defechos
# ['8' '9' 'Clinica Medica' 'Clinica Médica' 'Contactante Assintomática'
#  'ENTEGOU ESCARRO PAAP']
#
# Incluído_TB_Adapt
# ['Sim' 'Não' 'IGN']
#
# Critério_1_TB_Adapt_tosse_por_mais_2_semanas
# ['Sim' '8' 'IGN' 'Não']
#
# Critério_2_TB_Adapt_assinou_TCLE
# ['Não' 'IGN' 'Sim' '8']
#
# Aplicou_PPD
# ['Não' 'IGN' 'Sim']
#
# Leu_PT
# ['IGN' 'Sim' 'Não']
#
# Resultado_PPT_mm
# ['9' '0' 'não se aplica' '8' '2' '4' '11' '15' '7' '21' '10' '12' '14' '3'
#  '13' '5' '6' '17' 'ignorado' '23' '19' '16' '22' '18' '24' '31' '20' '25'
#  '1']
#
# IRC
# ['Não' 'IGN' '8' 'Sim']
#
# Hepatopatia
# ['Não' 'IGN' '8' 'Sim']
#
# Etilismo
# ['Não' 'IGN' '8' 'Sim']
#
# Uso_corticoide
# ['Não' 'IGN' '8' 'Sim']
#
# Neo_maligna
# ['Não' 'IGN' '8' 'Sim']
#
# Transplante
# ['Não' 'IGN' '8']
#
# DM_NID
# ['Não' 'IGN' '8' 'Sim']
#
# DM_ID
# ['Não' 'IGN' '8' 'Sim']
#
# Silicose
# ['Não' 'IGN' '8']
#
# DPOC
# ['Não' 'IGN' '8' 'Sim']
#
# Doença_pumonar_difusa
# ['Não' 'IGN' '8']
#
# Outras
# ['Sim' 'IGN' '8' 'Não']
#
# descrever_outras_comorbidades2
# ['HIV' '9' '8' 'Sida' 'Sindrome Down' 'icc' 'Asma' 'bronquite cronica'
#  'HAS + Asma' 'ICC' 'SIDA' 'Tabagismo' 'Usuário de drogas'
#  'dç hematologica anem' 'vitiligo' 'Hipertrofia Prostáti' 'tabagismo'
#  'Rinite' 'HAS' 'D. Hodgkin já tratad' 'bronquiectasia' 'Coronariopatia'
#  'HAS, Epilepsia' 'HAS = Bronquiectasia' 'RCU operada' 'asma bronquica'
#  'Asma + Tabaagismo' 'asma' 'HIV +' 'rinite alergica' 'CA Tireóide'
#  'ulcera gastrica' 'Bronquite cronica' 'Artrite reunmatoide'
#  'neo de tireoide oper' 'Silicose']
#
# Critério_de_entrada_perfil_bacteriologico_Fup
# ['IGN' '2 BAAR negativos + 1 ou 2 culturas positivas LJ'
#  '2 BAAR negativos + culturas negativas LJ'
#  '1 BAAR positivo + 1 ou 2 culturas positivas LJ' '8'
#  '2 BAAR positivos + 1 ou 2 culturas positivas LJ'
#  '2 BAAR positivos + culturas negativas LJ'
#  '1 BAAR negativo+ culturas negativas LJ']
#
# Etionamida_TTO_TB
# ['IGN' 'Não' '"não se aplica"' 'Sim']
#
# Estreptomicina_TTO_TB
# ['IGN' 'Não' 'Sim' '"não se aplica"']
#
# Ofolxacino_TTO_TB
# ['IGN' 'Não' '"não se aplica"']
#
# Outros_fármacos
# ['IGN' 'não se aplica' 'Não']
#
# Descrever_outros_fármacos
# [9 8 0]
#
# Reação_Adversa_Fármacos_TTO_TB
# ['IGN' 'Sim' 'Não' 'não se aplica']
#
# Reação_adversa_maior
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Exantema
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Confusão_mental
# ['IGN' 'não se aplica' 'Não']
#
# Icterícia
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Hepatotoxicidade
# ['IGN' 'não se aplica' 'Sim' 'Não']
#
# Vertigem
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Hipoacusia
# ['IGN' 'não se aplica' 'Não']
#
# Crise_convulsiva
# ['IGN' 'não se aplica' 'Sim' 'Não']
#
# Encefalopatia
# ['IGN' 'não se aplica' 'Não']
#
# Psicose
# ['IGN' 'não se aplica' 'Não']
#
# Neurite_óptica
# ['IGN' 'não se aplica' 'Não']
#
# Plaquetopenia_leucopenia_eosinofilia
# ['IGN' 'não se aplica' 'Não']
#
# Anemia_hemolítica_vasculite
# ['IGN' 'não se aplica' 'Não']
#
# Choque_púrpura
# ['IGN' 'não se aplica' 'Não']
#
# Nefrite
# ['IGN' 'não se aplica' 'Não']
#
# Insuficiência_renal_rabdomiólise
# ['IGN' 'não se aplica' 'Não']
#
# Reação_adversa_menor
# ['IGN' 'Não' 'Sim' 'não se aplica']
#
# Prurido
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Anorexia
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Náuseas_vômitos
# ['IGN' 'Sim' 'não se aplica' 'Não']
#
# Dor_abdominal
# ['IGN' 'Não' 'Sim' 'não se aplica']
#
# Dor_articular
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Neurite_periférica
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Euforia
# ['IGN' 'Não' 'não se aplica']
#
# Insônia_sonolência
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Ansiedade
# ['IGN' 'Não' 'não se aplica']
#
# Cefaléia
# ['IGN' 'Não' 'não se aplica']
#
# Acne
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Hiperuricemia
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Febre_AD
# ['IGN' 'Não' 'não se aplica']
#
# Hipotensão_ortostática
# ['IGN' 'Não' 'não se aplica']
#
# Ginecomastia
# ['IGN' 'Não' 'não se aplica']
#
# Mudança_esquema_tto_TB
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Rifampicina_mudança_tto
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Pirazinamida_mudança_tto
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Isoniazida_mudança_tto
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Etambutol_mudança_tto
# ['IGN' 'não se aplica' 'Sim' 'Não']
#
# Etionamida_mudança_tto
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Estreptomicina_mudança_tto
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Ofloxacino_mudança_tto
# ['IGN' 'não se aplica' 'Não' 'Sim']
#
# Outros_farmacos_mudança_tto2
# ['IGN' 'não se aplica' 'Sim' 'Não']
#
# Descrever_outros_farmacos_mudança_tto2
# ['IGN' 'não se aplica' 'Não']
#
# Tosse_diminuída
# ['IGN' 'Sim' 'Não' 'não se aplica']
#
# Peso_atual_Fup
# ['"ignorado"' '80,000' '75,000' '57,000' '56,400' '56,300' '85,000'
#  '57,700' '63,500' '92,300' '58,200' '43,500' '39,300' '888,000' '65,000'
#  '58,000' '44,000' '61,000' '51,000' '43,000' '59,300' '55,300' '62,000'
#  '64,000' '56,000' '79,000' '54,600' '60,500' '6,000' '92,000' '63,000'
#  '56,800' '52,800' '47,000' '55,000' '59,000' '64,100' '48,000' '58,300'
#  '53,300' '36,200' '66,000' '58,500' '63,100' '82,000' '78,500' '53,200'
#  '71,000' '53,700' '58,900' '48,300' '50,500' '49,500' '65,500' '49,000'
#  '60,700' '76,400' '56,700' '66,500' '81,500' '52,500' '55,500' '74,000'
#  '58,700' '65,300' '54,000' '52,000' '65,100' '59,500' '62,900' '42,800'
#  '64,700' '61,200' '59,900' '60,200' '69,000' '71,500' '60,000' '66,300'
#  '54,500' '61,300' '57,500' '41,000' '69,500' '51,400' '48,700' '51,100'
#  '57,200' '70,000' '45,000' '89,000' '58,800' '84,800' '52,600' '93,000'
#  '70,500' '72,000' '46,400' '67,000' '48,200' '38,500' '86,000' '61,500'
#  '42,600' '50,000' '54,400' '55,200' '74,200' '42,000' '46,200' '46,500'
#  '61,900' '60,300' '78,000' '69,200' '68,000' '88,000' '48,400' '56,100'
#  '49,100' '59,200' '35,500' '65,600' '64,400' '63,300' '50,300' '61,400'
#  '79,500' '72,300' '64,500' '51,300' '56,200' '65,200' '80,300' '66,600'
#  '53,900' '78,700' '53,600' '101,700' '68,500' '51,500' '37,800' '84,300'
#  '41,500' '82,700' '92,600' '48,500' '63,200' '65,400' '46,600' '56,900'
#  '90,300' '44,200' '67,900' '76,000' '46,000' '40,000' '81,000' '97,500'
#  '72,900' '87,500' '80,900' '45,300' '72,200' '3,000' '53,000' '73,000'
#  '84,400' '82,500' '70,400' '84,000' '91,000' '74,400' '49,700' '60,800'
#  '63,900' '75,600' '61,800' '39,400' '76,300' '60,900' '59,600' '47,300'
#  '45,500' '78,600' '65,700']
#
# Probabilidade_TB_com_RX_Fup
# ['IGN' 'Baixa' 'Média' 'Alta' '8']
#
# Cavitação__RX_Fup_Alta_média
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Padrão_RX_TIPICO_Fup_Alta_média
# ['IGN' 'Não' 'Sim' 'não se aplica' '2' '3' '999' '4']
#
# Padrão_RX_COMPATIVEL_Fup_Alta_Média
# ['IGN' 'Sim' 'Não' 'não se aplica']
#
# Padrão_RX_ATIPICO_Fup_Alta_Media
# ['IGN' 'Não' 'não se aplica' 'Sim']
#
# Padrão_RX_Fup_Baixa
# ['IGN' 'TB inativa - sequela' nan 'Normal' 'OUtra doença']
#
# Fup_RX
# ['IGN' 'Inalterado' 'Melhora' 'Piorado' '8']
#
# HIV_teste_Fup
# ['IGN' 'Não realizado / desconhecido' 'Positivo' 'Negativo' '8' '2']
#
# Diagnóstico_90_dias
# ['IGN' 'TBP' 'Não TB' '8' 'TBP + extra']
#
# Outro_diagnóstico_Fup
# ['ignorado' 'não se aplica' 'Outra' 'Pneumoconiose' 'Pneumonia bacteriana'
#  'CA pulmão' 'DPOC + Infecção brônquica inespecífica']
#
# Descrever_outro_diagnóstico
# ['9' '8' 'MNT' 'DPOC' 'DPOC + Infecção Bron' 'Asma' 'Rinossinusite'
#  'Rinite' 'Doença Crônica' 'Dispneia a esclarece']

# %% [markdown]
# ### Seleção de features: segundo filtro
#
# Utilização de tabelas de contingência e teste do chi-quadrado para verificação de independência entre as variáveis e o desfecho

# %%
from scipy.stats import chi2_contingency

# %%
# Separação entre atributos e desfecho
desfecho = data['TB_desfecho_final_Dri']
data.drop(['TB_desfecho_final_Dri'],axis=1,inplace=True)
