# %% [markdown]
# # Análise Exploratória de Dados

# %%
# Módulos para análise dos dados
import numpy  as np
import pandas as pd

# Visualização de dados
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# Configurações globais para o matplotlib
matplotlib.rcParams['figure.figsize'] = (16.0, 8.0)
matplotlib.rc('xtick', labelsize=9) 
matplotlib.rc('ytick', labelsize=9)

# %matplotlib inline

# %%
# Importação dos dados da base de triagem de pacientes com tuberculose
data = pd.read_excel('../../Data/Raw/Banco labels.xlsx')

# %% [markdown]
# ## Verificação inicial dos dados

# %%
# Visualização dos dados
data.head(5)
# Out:
#   TB_desfecho_final_Dri Tbafranio Obs_desfechoTB_Dri_Dani Data_inclusão  Nome  \
# 0                    TB       SIM                     NaN    2008-04-03   NaN
# 1                    TB       SIM                     NaN    2006-10-03   NaN
# 2                    TB       SIM                     NaN    2007-06-21   NaN
# 3                    TB       SIM                     NaN    2009-09-30   NaN
# 4                    TB       SIM                     NaN    2009-06-19   NaN
#
#   Desfecho_tuberculose_lista_Mauro Desfecho_TB_162_Revisão_ADRIANA  \
# 0                                9                              TB
# 1                               TB                              TB
# 2                               TB                              TB
# 3                               TB                              TB
# 4                               TB                             NaN
#
#   Observaça0_desfecho_TB Resultado_BAAR_1 Resultado_BAAR_2  \
# 0       TB PROBABILIDADE         Negativo         Negativo
# 1                    NaN         Negativo         Negativo
# 2          TB CONFIRMADA         Negativo         Negativo
# 3                    NaN         Negativo         Negativo
# 4                    NaN         Negativo         Negativo
#
#            ...          Perdeu_aula_hoje_CA Deixou_de_ganhar_dinheiro_hoje_CA  \
# 0          ...                          IGN                               IGN
# 1          ...                          IGN                               IGN
# 2          ...                          IGN                               IGN
# 3          ...                          IGN                               IGN
# 4          ...                          Não                               Não
#
#   Quanto_deixou_ganhar_CA Caso_acompanhado_quem_custeou_tudo_CA  \
# 0                Ignorado                                   IGN
# 1                Ignorado                                   IGN
# 2                Ignorado                                   IGN
# 3                Ignorado                                   IGN
# 4         "Não se aplica"                         não se aplica
#
#         Valor_CA  Avaliador_custo_CA Data_avaliação_custo_CA  \
# 0       ignorado                   9              1999-09-09
# 1       ignorado                   9              1999-09-09
# 2       ignorado                   9              1999-09-09
# 3       ignorado                   9              1999-09-09
# 4  não se aplica  Marcia  dos Santos              2009-06-19
#
#   Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER) ANO  de inclusao  \
# 0                                           Selected                  2008
# 1                                           Selected                  2006
# 2                                           Selected                  2007
# 3                                           Selected                  2009
# 4                                       Not Selected                  2009
#
#   Novocriteriotbafranio
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 281 columns]

# %%
for feature in list(data.columns):
    print(feature,end='\n')
# Out:
# TB_desfecho_final_Dri
# Tbafranio
# Obs_desfechoTB_Dri_Dani
# Data_inclusão
# Nome
# Desfecho_tuberculose_lista_Mauro
# Desfecho_TB_162_Revisão_ADRIANA
# Observaça0_desfecho_TB
# Resultado_BAAR_1
# Resultado_BAAR_2
# Resultado_Cultutra_1
# Resultado_Cultura_2
# identificado_tb_ntb
# Houve_desfecho_consulta_médica__inicial
# Compareceram_consulta_medica
# TTO_TB_confirmação_bacteriológica
# TTO_TB_probabilidade
# Transferência_internação_não_TB_outra_especialidade
# TTO_pneumologia_patologia_não_TB
# Alta
# Descrever_outra_patologia
# Asma
# Em_caso_tto_TB_marcar_opções
# TTO_anterior_TB_triagem_enfermeiro
# Fator_risco_TBP_MDR
# Médico_avaliador
# Data_avaliação_médica
# Cavitação_alta_média_probabilidade
# RX_Padrão_TÍPICO_alta_média_probabilidade
# RX_padrão_COMPATIVEL_alta_média_probabilidade
# RX_Padrão_ATÍPICO_alta_média_probabilidade
# RX_baixa_probabilidade_TB_INATIVA_SEQUELA
# RX_baixa_probabilidade_TB_OUTRA_DOENÇA2
# RX_baixa_probabilidade_NORMAL
# Data_RX
# Tto_TB_prescrito
# Data_início_TTO
# Rifampicina_TTO_TB
# Isoniazida_TTO_TB
# Pirazinamida_TTO_TB
# Etambutol_TTO_TB
# Data_coleta_escarro_1
# Espécime_1
# Data_coleta_escarro_2
# Espécime_2
# Número_cruzes_BAAR_1
# Número_cruzes_BAAR_2
# Resultado_BAAR_Final
# Número_Cruzes_Cultura_1
# Número_cruzes_Cultura_2
# VAR00003
# Escore_Cat
# Probabilidade_médica_TB_ativa
# Probabilidade_TBP_sem_RX_ou_BAAR
# Probabilidade_TBP_com_RX
# Probabilidade_TBP_comRX_e_sem_BAAR
# Probabilidade_TBP_com_RX_sem_BAAR_percent
# Probabilidade_TBP_com_2_BAAR_negativos
# Probabilidade_TBP_com_RX_e_BAAR
# Resultado_cultura_final
# Realizou_RX
# Karen_amostra
# Número_geral
# Prontuário_PAAP
# TSA
# Óbito
# Causa_óbito
# Número_laboratório
# Número_cultura
# Detect_TB_Primeira_amostra
# Número_cultura_segunda_amostra
# Detect_TB_Segunda_amostra
# Biometrix_inserido_tabela_por_nomes
# Resultado_biometrix_CTMtb
# Resultados_biometrix_CTinterno
# Resultado_biometrix_bula
# N°_TB
# Cicatriz_BCG
# Data_TB_passado
# Desfecho_TB
# Tto_anterior_TB_avaliação_médica
# Tto_anterior_TB_INH
# Tto_anterior_TB_RIF
# Esquema_utilizado_tto_anterior
# Quimio_prévia
# Quimio_INH
# Quimio_RIF
# Data_quimio
# Desfecho_quimio
# HIV
# Comorbidades
# Nome_mãe
# Idade
# Endereço2
# Bairro_Residência
# Cidade_residência
# Telefone_1
# Telefone_2
# CEP
# Data_nascimento
# Naturalidade_cidade
# Naturalidade_estado2
# Mora_no_Rio_há_quantos_anos
# Sexo
# Raça
# Raça_2
# Estado_civil
# Tem_companheiro
# Peso_habitual
# Peso_atual
# Altura_cm
# Tosse
# Semanas_tosse
# Expectoração
# Semanas_expectoração
# Hemoptóicos
# Semanas_hemoptóicos
# Hemoptise
# Semanas_hemoptise
# Quantidade_hemoptise
# Sudorese_noturna
# Semanas_sudorese
# Febre
# Semanas_febre
# Dispnéia
# Dispnéia_semanas
# Perda_de_apetite
# Perda_apetite_semanas
# Perda_peso_10percent
# Perda_peso_semanas
# Dor_torácica
# Dor_torácica_semanas
# Total_escore_Paulo
# Valor_pts_escore
# Internação_hospital_2anos
# Prisão_2anos
# Delegacia_2anos
# Contato_TBP_2anos
# TBP_Morava_com_vc
# TBP_trabalhava_com_vc
# TBP_amigo_parente_não_morava_com_vc
# Contato_TBP_menor_3anos
# Contato_TBP_Casa
# Contato_TBP_Trabalho
# Contato_TBP_Social
# Fuma
# Número_cigarros_dia
# Número_anos
# Cerveja
# Vinho
# Whisky
# Cachaça
# Outras_bebidas_alcoólicas
# Nenhuma_bebida_alcoólica
# CAGE
# Desfecho_enfermeiro
# Descrever_outros_defechos
# Incluído_TB_Adapt
# Critério_1_TB_Adapt_tosse_por_mais_2_semanas
# Critério_2_TB_Adapt_assinou_TCLE
# Data_assinatura_TCLE
# Aplicou_PPD
# Data_aplicação__PT
# Leu_PT
# Data_leitura_PT
# Resultado_PPT_mm
# Leitor_PT
# Enfemeiro_avaliação
# Data_avaliação
# Data_HIV
# IRC
# Hepatopatia
# Etilismo
# Uso_corticoide
# Neo_maligna
# Transplante
# DM_NID
# DM_ID
# Silicose
# DPOC
# Doença_pumonar_difusa
# Outras
# descrever_outras_comorbidades2
# Critério_de_entrada_perfil_bacteriologico_Fup
# Etionamida_TTO_TB
# Estreptomicina_TTO_TB
# Ofolxacino_TTO_TB
# Outros_fármacos
# Descrever_outros_fármacos
# Reação_Adversa_Fármacos_TTO_TB
# Reação_adversa_maior
# Exantema
# Confusão_mental
# Icterícia
# Hepatotoxicidade
# Vertigem
# Hipoacusia
# Crise_convulsiva
# Encefalopatia
# Psicose
# Neurite_óptica
# Plaquetopenia_leucopenia_eosinofilia
# Anemia_hemolítica_vasculite
# Choque_púrpura
# Nefrite
# Insuficiência_renal_rabdomiólise
# Reação_adversa_menor
# Prurido
# Anorexia
# Náuseas_vômitos
# Dor_abdominal
# Dor_articular
# Neurite_periférica
# Euforia
# Insônia_sonolência
# Ansiedade
# Cefaléia
# Acne
# Hiperuricemia
# Febre_AD
# Hipotensão_ortostática
# Ginecomastia
# Mudança_esquema_tto_TB
# Data_mudança
# Rifampicina_mudança_tto
# Pirazinamida_mudança_tto
# Isoniazida_mudança_tto
# Etambutol_mudança_tto
# Etionamida_mudança_tto
# Estreptomicina_mudança_tto
# Ofloxacino_mudança_tto
# Outros_farmacos_mudança_tto2
# Descrever_outros_farmacos_mudança_tto2
# Motivo_mudança
# Descrever_outro_motivo_mudança
# Tosse_diminuída
# Peso_atual_Fup
# Probabilidade_TB_com_RX_Fup
# Cavitação__RX_Fup_Alta_média
# Padrão_RX_TIPICO_Fup_Alta_média
# Padrão_RX_COMPATIVEL_Fup_Alta_Média
# Padrão_RX_ATIPICO_Fup_Alta_Media
# Padrão_RX_Fup_Baixa
# Data_RX_Fup
# Fup_RX
# HIV_teste_Fup
# Data_anti_HIV
# Diagnóstico_90_dias
# Outro_diagnóstico_Fup
# Descrever_outro_diagnóstico
# Médico_avaliador_Fup
# Data_Fup
# Onde_vc_mora_CA
# Transporte_CA
# Custo_transporte_reais_CA
# Acompanhado_CA
# Número_pessoas_CA
# Horas_saiu_de_casa_CA
# Horas_Chegou_posto_CA
# Horas_viu_profissional_CA
# Tempo_até_o_posto_minutos_CA
# Caso_FORA_DO_RJ_retorno_onde_pernoitar_CA
# Pagará_pernoite
# Valor_pernoite_CA
# Trouxe_algo_amigos_CA
# Valor_algo_CA
# Comeu_bebeu_CA
# Valor_comida_bebida_CA
# Pagou_algo_no_posto_CA
# Valor_algo_posto_CA
# Profissão_CA
# Perdeu_aula_hoje_CA
# Deixou_de_ganhar_dinheiro_hoje_CA
# Quanto_deixou_ganhar_CA
# Caso_acompanhado_quem_custeou_tudo_CA
# Valor_CA
# Avaliador_custo_CA
# Data_avaliação_custo_CA
# Resultado_cultura_final < 3 & Realizou_RX = 1  (FILTER)
# ANO  de inclusao
# Novocriteriotbafranio

# %% [markdown]
# ## Remoção de atributos da base
#
# Selecionar somente as variáveis escolhidas por especialistas, de acordo com o trabalho do Fabio.

# %%
features_selecionadas   = [
                        # Variáveis relacionadas ao desfecho
                        'TB_desfecho_final_Dri', 
                        'Observaça0_desfecho_TB', 
    
                        # Features referentes aos testes 
                        'Número_cruzes_BAAR_1',
                        'Número_cruzes_BAAR_2',
                        'Resultado_BAAR_Final',
                        'Número_Cruzes_Cultura_1',
                        'Número_cruzes_Cultura_2',
    
                        # Sintomas e outros
                        'Asma', 
                        'TTO_anterior_TB_triagem_enfermeiro', 
                        'Cicatriz_BCG',                         
                        'Tto_anterior_TB_avaliação_médica', 
                        'Tto_anterior_TB_INH', 
                        'Tto_anterior_TB_RIF', 
                        'Quimio_prévia', 
                        'Quimio_INH', 
                        'Quimio_RIF', 
                        'Desfecho_quimio', 
                        'HIV', 
                        'Comorbidades', 
                        'Idade', 
                        'Sexo', 
                        'Raça', 
                        'Raça_2', 
                        'Estado_civil', 
                        'Tem_companheiro', 
                        'Tosse', 
                        'Semanas_tosse', 
                        'Expectoração', 
                        'Semanas_expectoração', 
                        'Hemoptóicos', 
                        'Semanas_hemoptóicos', 
                        'Hemoptise', 
                        'Semanas_hemoptise', 
                        'Quantidade_hemoptise', 
                        'Sudorese_noturna', 
                        'Semanas_sudorese', 
                        'Febre', 
                        'Semanas_febre', 
                        'Dispnéia', 
                        'Dispnéia_semanas', 
                        'Perda_de_apetite', 
                        'Perda_apetite_semanas', 
                        'Perda_peso_10percent', 
                        'Perda_peso_semanas', 
                        'Dor_torácica', 
                        'Dor_torácica_semanas', 
                        'Internação_hospital_2anos', 
                        'Prisão_2anos', 
                        'Delegacia_2anos', 
                        'Contato_TBP_2anos', 
                        'TBP_Morava_com_vc', 
                        'TBP_trabalhava_com_vc', 
                        'TBP_amigo_parente_não_morava_com_vc', 
                        'Contato_TBP_menor_3anos', 
                        'Contato_TBP_Casa', 
                        'Contato_TBP_Trabalho', 
                        'Contato_TBP_Social', 
                        'Fuma', 
                        'Número_cigarros_dia', 
                        'Número_anos', 
                        
                        # Variáveis relacionadas ao consumo de álcool do paciente
                        'Cerveja', 
                        'Vinho', 
                        'Whisky', 
                        'Cachaça', 
                        'Outras_bebidas_alcoólicas', 
                        'Nenhuma_bebida_alcoólica', 
                        'CAGE',
                        'Etilismo', 
                        'Hepatopatia', 
                        'Uso_corticoide', 
                        'Neo_maligna', 
                        'Transplante',  
                        'Silicose', 
                        'Doença_pumonar_difusa']

# %%
# Dados das features pré-filtradas 
dados_selecionados = data[features_selecionadas]

# Salvandos os dados pré-filtrados
dados_selecionados.to_csv('../../Data/Processed/filtered.csv',index=False)

print('Quantidade de features selecionadas: {}'.format(len(features_selecionadas)))
# Out:
# Quantidade de features selecionadas: 74

# %% [markdown]
# ## Codificação da base de dados

# %% [markdown]
# #### Verificação dos labels relacionadas ao desfecho

# %%
# Verificação dos dados relacionados ao desfecho/target.
dados_selecionados.rename(index=str,columns={'TB_desfecho_final_Dri' : 'target'},inplace=True)
# Out:
# /Users/Michel/anaconda/lib/python3.5/site-packages/pandas/core/frame.py:2754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
dados_selecionados.head(5)
# Out:
#   target Observaça0_desfecho_TB Número_cruzes_BAAR_1 Número_cruzes_BAAR_2  \
# 0     TB       TB PROBABILIDADE        não se aplica        não se aplica
# 1     TB                    NaN        não se aplica        não se aplica
# 2     TB          TB CONFIRMADA        não se aplica        não se aplica
# 3     TB                    NaN        não se aplica        não se aplica
# 4     TB                    NaN        não se aplica        não se aplica
#
#   Resultado_BAAR_Final Número_Cruzes_Cultura_1 Número_cruzes_Cultura_2 Asma  \
# 0                  NaN           não se aplica           não se aplica  Não
# 1             Negativo           não se aplica                      1+  Não
# 2                  NaN           não se aplica                  < 19 c  Não
# 3                  NaN           não se aplica                      1+  Não
# 4                  NaN           não se aplica                      1+  Não
#
#   TTO_anterior_TB_triagem_enfermeiro Cicatriz_BCG          ...            \
# 0                                Sim          Sim          ...
# 1                                Sim          IGN          ...
# 2                                Não          Não          ...
# 3                                Não          Sim          ...
# 4                                Sim          IGN          ...
#
#   Outras_bebidas_alcoólicas Nenhuma_bebida_alcoólica      CAGE Etilismo  \
# 0                       Sim                      Não  Negativo      Não
# 1                       Não                      Sim  Negativo      IGN
# 2                       Não                      Sim  Negativo      IGN
# 3                       Não                      Sim  Negativo        8
# 4                       Não                      Não  Positivo      Sim
#
#   Hepatopatia Uso_corticoide Neo_maligna Transplante Silicose  \
# 0         Não            Não         Não         Não      Não
# 1         IGN            IGN         IGN         IGN      IGN
# 2         IGN            IGN         IGN         IGN      IGN
# 3           8              8           8           8        8
# 4         Não            Não         Não         Não      Não
#
#    Doença_pumonar_difusa
# 0                    Não
# 1                    IGN
# 2                    IGN
# 3                      8
# 4                    Não
#
# [5 rows x 74 columns]

# %%
# Verificação dos possíveis valores para o target:
dados_selecionados.target.value_counts()
# Out:
# Não TB    1856
# IGN       1633
# TB         871
# 8           21
# Name: target, dtype: int64

# %%
# Alterando os labels:
dados_selecionados.target.replace(['Não TB','IGN','TB',8],['TB+','ignorado','TB-','ignorado'],inplace=True)
# Out:
# /Users/Michel/anaconda/lib/python3.5/site-packages/pandas/core/generic.py:3443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
print('Informações gerais sobre a base de dados:\n')

# Tamanho da base de dados
print('-> Quantidade de pacientes presentes na base de dados: {}'.format(len(data)))

# Quantidade de pacientes com TB+ e TB-
print('-> Quantidade de pacientes com TB+: {}\n-> Quantidade de pacientes com TB-: {}'.format(len(dados_selecionados[dados_selecionados.target == 'TB+']),
                                                                                              len(dados_selecionados[dados_selecionados.target == 'TB-'])))

# Proporcão da base
print('-> Proporção de pacientes TB+ e TB-: {:.2f}% de casos TB+ e {:.2f}% de casos TB-'.format(100 * len(dados_selecionados[dados_selecionados.target == 'TB+'])/len(dados_selecionados),
                                                                                                100 * len(dados_selecionados[dados_selecionados.target == 'TB-'])/len(dados_selecionados)))

print('-> Proporção de desfechos ignorados: {:.2f}% de casos ignorados'.format(100 * len(dados_selecionados[dados_selecionados.target == 'ignorado'])/len(dados_selecionados)))

# Quantidade de features presentes
print('-> Quantidade de atributos presentes: {}\n'.format(len(dados_selecionados.columns)))
# Out:
# Informações gerais sobre a base de dados:
#
# -> Quantidade de pacientes presentes na base de dados: 4381
# -> Quantidade de pacientes com TB+: 1856
# -> Quantidade de pacientes com TB-: 871
# -> Proporção de pacientes TB+ e TB-: 42.36% de casos TB+ e 19.88% de casos TB-
# -> Proporção de desfechos ignorados: 37.75% de casos ignorados
# -> Quantidade de atributos presentes: 74

# %% [markdown]
# ## Verificação das variáveis
#
# ### Variáveis com discrepância entre rótulos e dados

# %% [markdown]
# De acordo com o trabalho do fabio, as variáveis Doença_pumonar_difusa, Transplante e Silicose foram retiradas por apresentarem discrepância entre os rótulos e os dados. <br>
# Verificando...

# %%
# Verificando os dados presentes 
for feature in ['Doença_pumonar_difusa','Transplante','Silicose']:
    print('Possíveis valores para a feature {}: {}'.format(feature,dados_selecionados[feature].unique()))
# Out:
# Possíveis valores para a feature Doença_pumonar_difusa: ['Não' 'IGN' 8]
# Possíveis valores para a feature Transplante: ['Não' 'IGN' 8]
# Possíveis valores para a feature Silicose: ['Não' 'IGN' 8]

# %%
# Excluindo do modelo as features acima:
dados_selecionados.drop(['Doença_pumonar_difusa','Transplante','Silicose'],axis=1,inplace=True)
# Out:
# /Users/Michel/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Variáveis por insuficiência no quantitativo de amostrar com valor presente ou expressivo numero de casos ausentes

# %%
# Features indicadas na Tabela II.5
features = ['Tto_anterior_TB_INH','Tto_anterior_TB_RIF','Quimio_prévia','Quimio_INH','Quimio_RIF','Desfecho_quimio','HIV','Hepatopatia','Uso_corticoide','Neo_maligna']

for feature in features:
    print('Possíveis valores para a feature {}: {}'.format(feature,dados_selecionados[feature].unique()))
# Out:
# Possíveis valores para a feature Tto_anterior_TB_INH: [nan 'Sim' 'IGN' 'Não']
# Possíveis valores para a feature Tto_anterior_TB_RIF: [nan 'Não' 'IGN' 'Sim']
# Possíveis valores para a feature Quimio_prévia: ['Não' 'Sim' 'IGN' nan]
# Possíveis valores para a feature Quimio_INH: [nan 'IGN' 'Sim' 'Não']
# Possíveis valores para a feature Quimio_RIF: [nan 'IGN' 'Não']
# Possíveis valores para a feature Desfecho_quimio: [nan 'IGN' 'Abandonou']
# Possíveis valores para a feature HIV: ['Negativo' 'Não realizado/Desconhecido' 'Positivo' 'IGN' nan]
# Possíveis valores para a feature Hepatopatia: ['Não' 'IGN' 8 'Sim']
# Possíveis valores para a feature Uso_corticoide: ['Não' 'IGN' 8 'Sim']
# Possíveis valores para a feature Neo_maligna: ['Não' 'IGN' 8 'Sim']

# %%
# Features com Sim, Não, IGN e nan:
features = ['Tto_anterior_TB_INH','Tto_anterior_TB_RIF','Quimio_prévia','Quimio_INH','Quimio_RIF','Hepatopatia','Uso_corticoide','Neo_maligna']

for feature in features:
    dados_selecionados[feature].replace([np.nan,'Positivo','IGN','Negativo',8],['ignorado','positivo','ignorado','negativo','ignorado'],inplace=True)
# Out:
# /Users/Michel/anaconda/lib/python3.5/site-packages/pandas/core/generic.py:3443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
# Feature HIV
dados_selecionados['HIV'].replace([np.nan,'Sim','IGN','Não','Não realizado/Desconhecido'],['ignorado','sim','ignorado','não','ignorado'],inplace=True)
# Out:
# /Users/Michel/anaconda/lib/python3.5/site-packages/pandas/core/generic.py:3443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
# Substituindo os dados da feature Desfecho_quimio
dados_selecionados['Desfecho_quimio'].replace([np.nan,'IGN','Abandonou'],['ignorado','ignorado','ignorado'],inplace=True)
# Out:
# /Users/Michel/anaconda/lib/python3.5/site-packages/pandas/core/generic.py:3443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
for feature in features:
    print('Possíveis valores para a feature {}: {}'.format(feature,dados_selecionados[feature].value_counts()),end='\n\n')
# Out:
# Possíveis valores para a feature Tto_anterior_TB_INH: ignorado    4073
# Sim          305
# Não            3
# Name: Tto_anterior_TB_INH, dtype: int64
#
# Possíveis valores para a feature Tto_anterior_TB_RIF: ignorado    4075
# Sim          302
# Não            4
# Name: Tto_anterior_TB_RIF, dtype: int64
#
# Possíveis valores para a feature Quimio_prévia: ignorado    2855
# Não         1524
# Sim            2
# Name: Quimio_prévia, dtype: int64
#
# Possíveis valores para a feature Quimio_INH: ignorado    4378
# Sim            2
# Não            1
# Name: Quimio_INH, dtype: int64
#
# Possíveis valores para a feature Quimio_RIF: ignorado    4380
# Não            1
# Name: Quimio_RIF, dtype: int64
#
# Possíveis valores para a feature Hepatopatia: ignorado    4102
# Não          278
# Sim            1
# Name: Hepatopatia, dtype: int64
#
# Possíveis valores para a feature Uso_corticoide: ignorado    4103
# Não          277
# Sim            1
# Name: Uso_corticoide, dtype: int64
#
# Possíveis valores para a feature Neo_maligna: ignorado    4102
# Não          277
# Sim            2
# Name: Neo_maligna, dtype: int64

# %%
# Removendo as features
dados_selecionados.drop(features,axis=1,inplace=True)
# Out:
# /Users/Michel/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dados_selecionados.dtypes
# Out:
# target                                 object
# Observaça0_desfecho_TB                 object
# Número_cruzes_BAAR_1                   object
# Número_cruzes_BAAR_2                   object
# Resultado_BAAR_Final                   object
# Número_Cruzes_Cultura_1                object
# Número_cruzes_Cultura_2                object
# Asma                                   object
# TTO_anterior_TB_triagem_enfermeiro     object
# Cicatriz_BCG                           object
# Tto_anterior_TB_avaliação_médica       object
# Tto_anterior_TB_INH                    object
# Tto_anterior_TB_RIF                    object
# Quimio_prévia                          object
# Quimio_INH                             object
# Quimio_RIF                             object
# Desfecho_quimio                        object
# HIV                                    object
# Comorbidades                           object
# Idade                                   int64
# Sexo                                   object
# Raça                                   object
# Raça_2                                 object
# Estado_civil                           object
# Tem_companheiro                        object
# Tosse                                  object
# Semanas_tosse                          object
# Expectoração                           object
# Semanas_expectoração                   object
# Hemoptóicos                            object
#                                         ...
# Perda_apetite_semanas                  object
# Perda_peso_10percent                   object
# Perda_peso_semanas                     object
# Dor_torácica                           object
# Dor_torácica_semanas                   object
# Internação_hospital_2anos              object
# Prisão_2anos                           object
# Delegacia_2anos                        object
# Contato_TBP_2anos                      object
# TBP_Morava_com_vc                      object
# TBP_trabalhava_com_vc                  object
# TBP_amigo_parente_não_morava_com_vc    object
# Contato_TBP_menor_3anos                object
# Contato_TBP_Casa                       object
# Contato_TBP_Trabalho                   object
# Contato_TBP_Social                     object
# Fuma                                   object
# Número_cigarros_dia                    object
# Número_anos                            object
# Cerveja                                object
# Vinho                                  object
# Whisky                                 object
# Cachaça                                object
# Outras_bebidas_alcoólicas              object
# Nenhuma_bebida_alcoólica               object
# CAGE                                   object
# Etilismo                               object
# Hepatopatia                            object
# Uso_corticoide                         object
# Neo_maligna                            object
# dtype: object

# %%
# Verificando 

for feature in list(dados_selecionados.columns):
    if dados_selecionados[feature].dtypes == 'object':
        print('Possíveis valores para a feature {}: {}'.format(feature,dados_selecionados[feature].value_counts()),end='\n\n')
# Out:
# Possíveis valores para a feature target: TB+         1856
# ignorado    1654
# TB-          871
# Name: target, dtype: int64
#
# Possíveis valores para a feature Observaça0_desfecho_TB: TB PROBABILIDADE                                                         64
# TB CONFIRMADA                                                            45
# NÃO TB                                                                   19
# TB                                                                        9
# TB PROBABILIDADE - ESCARRO LAB. PAAP                                      7
# TB PROBBABILIDADE                                                         4
# NÃO ENCONTRADO                                                            3
# NÃO TB - ESCARRO PAAP                                                     3
# NÃO TB - ESCARRO LAB. PAAP                                                2
# TB CONFIRMADA - ESCARRO LAB. PAAP                                         2
# TB PROBABILIDADE ESCARRO LAB. PAAP                                        2
# NÃO ENCONTRADA                                                            2
# MNT                                                                       2
# TB probabilidade                                                          2
# TB CONFIRMADA - ESCARRO LAB PAAP                                          2
# TB PROBABILIDADE - LAB PAAP                                               2
# TB PROBABILIDADE - LAB. PAAP                                              2
# tb probabilidade                                                          1
# TB CONFIRMADA -  ESCARRO LAB PAAP                                         1
# TB CONFIRMADA - PACIENTE NÃO COMPARECE PARA TRATAR NA PAAP                1
# Amostras enviadas ao lab da PAAP. Tb no ano anterior- curou               1
# TB CONFIRMADA POR CULTURA                                                 1
# NÃO TB - TEVE TB NO ANO ANTERIOR                                          1
# TB CONFIRMADA - ESCARRO LA. PAAP                                          1
# NÃO TB - ESCARRO LAB. PAAP - TB EM 2006                                   1
# TBCONFIRMADA                                                              1
# Não encontrado livro TB PAAP- não entregou amostras labPAAP               1
# TB CONFIRMADA -LAB.PAAP                                                   1
# NÃO TB - ABANDONO TTO ANTERIOR                                            1
# NÃO ENCONTRADA - SEM RX E LAB                                             1
#                                                                          ..
# TB CONFIRMADA - ESCARRO  LAB. PAAP                                        1
# TB PROBABILIDADE- ESCARRO LAB. PAAP                                       1
# TB CONFIRMADA - ESCARRO PAAP                                              1
# NÃO TB - SEM RX E SEM ESCARRO                                             1
# Não entregou amostras-  não encontrado no livro.TB no ano de 2007         1
# NÃO TB 2008/ TB 2007                                                      1
# TB endobronquica                                                          1
# NÃO TB - ESCARRO LAB PAAP - NESTA AVALIAÇÃOÉ NÃO TB                       1
# Não TB neste ano e nesta avaliação. É TB no ano de 2009.                  1
# NÃO TB - ESCARRO LAB.PAAP                                                 1
# TB CONFIRMADA - ESCAROO LAB.PAAP                                          1
# TB pulmonar- recidiva                                                     1
# NÃO TB COM RESULTADO CULTURA NEGATIVA                                     1
# NÃO TB - NÃO ENCONTRADO - É CULTURA NEG                                   1
# TB CONFIRMADA EM CULTURA                                                  1
# TB CONFIRMADA - ESCARRO LAB. PAAP - PORÉM PACIENTE NÃO TRATOU NA PAAP     1
# NÃO ENCONTRADO - BAAR NEG PAAP / TB 05-09                                 1
# NÃO TB - FOI TB PROBABILIDADE EM 2006                                     1
# NÃO TB 2007/TB 2006                                                       1
# TB probabilidade- amostras PAAP                                           1
# NÃO TB - NÃO ENCONTRADA - SEM RX E LAB.                                   1
# TB - LAB.PAAP                                                             1
# NÃO TB - NÃO ENCONTRADO RESULTADO ESCARRO REALIZADO PAAP                  1
# NÃO TB- ESCARRO PAAP                                                      1
# TB - AMOSTRAS LAB DA PAAP                                                 1
# NÃO TB - FOI TB EM 2007                                                   1
# NÃO TB - MNT2009/ TB2008                                                  1
# Tb probabilidade -  amostras na PAAP                                      1
# TB CONFIRMADA - LAB PAAP                                                  1
# TB PROBABILIDADE - ESCARRO LAB PAAP                                       1
# Name: Observaça0_desfecho_TB, dtype: int64
#
# Possíveis valores para a feature Número_cruzes_BAAR_1: não se aplica    2924
# IGN               908
# 1+                232
# 3+                187
# 2+                127
# 0                   2
# 4                   1
# Name: Número_cruzes_BAAR_1, dtype: int64
#
# Possíveis valores para a feature Número_cruzes_BAAR_2: não se aplica    3016
# IGN               915
# 1+                192
# 3+                148
# 2+                108
# 4                   2
# Name: Número_cruzes_BAAR_2, dtype: int64
#
# Possíveis valores para a feature Resultado_BAAR_Final: Negativo    239
# Positivo     71
# IGN          36
# Name: Resultado_BAAR_Final, dtype: int64
#
# Possíveis valores para a feature Número_Cruzes_Cultura_1: não se aplica    2788
# IGN              1059
# 1+                218
# 2+                144
# 3+                133
# < 19 c             39
# Name: Número_Cruzes_Cultura_1, dtype: int64
#
# Possíveis valores para a feature Número_cruzes_Cultura_2: não se aplica    2871
# IGN              1060
# 1+                183
# 3+                123
# 2+                119
# < 19 c             25
# Name: Número_cruzes_Cultura_2, dtype: int64
#
# Possíveis valores para a feature Asma: Não    258
# Sim     97
# Name: Asma, dtype: int64
#
# Possíveis valores para a feature TTO_anterior_TB_triagem_enfermeiro: Não    3387
# Sim     963
# IGN      31
# Name: TTO_anterior_TB_triagem_enfermeiro, dtype: int64
#
# Possíveis valores para a feature Cicatriz_BCG: IGN    1765
# Sim    1514
# Não    1102
# Name: Cicatriz_BCG, dtype: int64
#
# Possíveis valores para a feature Tto_anterior_TB_avaliação_médica: IGN    1759
# Não    1152
# Sim     379
# Name: Tto_anterior_TB_avaliação_médica, dtype: int64
#
# Possíveis valores para a feature Tto_anterior_TB_INH: ignorado    4073
# Sim          305
# Não            3
# Name: Tto_anterior_TB_INH, dtype: int64
#
# Possíveis valores para a feature Tto_anterior_TB_RIF: ignorado    4075
# Sim          302
# Não            4
# Name: Tto_anterior_TB_RIF, dtype: int64
#
# Possíveis valores para a feature Quimio_prévia: ignorado    2855
# Não         1524
# Sim            2
# Name: Quimio_prévia, dtype: int64
#
# Possíveis valores para a feature Quimio_INH: ignorado    4378
# Sim            2
# Não            1
# Name: Quimio_INH, dtype: int64
#
# Possíveis valores para a feature Quimio_RIF: ignorado    4380
# Não            1
# Name: Quimio_RIF, dtype: int64
#
# Possíveis valores para a feature Desfecho_quimio: ignorado    4381
# Name: Desfecho_quimio, dtype: int64
#
# Possíveis valores para a feature HIV: ignorado    4198
# Positivo      93
# Negativo      90
# Name: HIV, dtype: int64
#
# Possíveis valores para a feature Comorbidades: IGN    2251
# 8      1052
# Não     792
# Sim     286
# Name: Comorbidades, dtype: int64
#
# Possíveis valores para a feature Sexo: Masculino    2290
# Feminino     2078
# IGN             8
# 2               5
# Name: Sexo, dtype: int64
#
# Possíveis valores para a feature Raça: Não branco    2283
# Branco        2061
# IGN             35
# 8                2
# Name: Raça, dtype: int64
#
# Possíveis valores para a feature Raça_2: Não se aplica    2321
# Mulato            992
# Negro             712
# IGN               345
# Índio               9
# Não sabe            1
# Asiático            1
# Name: Raça_2, dtype: int64
#
# Possíveis valores para a feature Estado_civil: Solteiro    2335
# Casado      1357
# viúvo        374
# Separado     244
# IGN           63
# 0              6
# Name: Estado_civil, dtype: int64
#
# Possíveis valores para a feature Tem_companheiro: Sim    2268
# Não    2023
# IGN      90
# Name: Tem_companheiro, dtype: int64
#
# Possíveis valores para a feature Tosse: Sim    3674
# Não     705
# IGN       2
# Name: Tosse, dtype: int64
#
# Possíveis valores para a feature Semanas_tosse: não se aplica     738
# 2                 720
# 4                 621
# 1                 496
# 8                 369
# 3                 330
# 12                264
# 0                 202
# 6                 110
# 16                 97
# 24                 85
# 5                  76
# crônico+sempre     48
# 48                 43
# 20                 40
# ignorado           30
# 32                 16
# 18                 14
# 10                 12
# 9                   8
# 40                  8
# 7                   6
# 52                  6
# 28                  5
# 58                  5
# 36                  4
# 80                  4
# 96                  3
# 180                 3
# 15                  2
# 14                  2
# 50                  2
# 30                  2
# 72                  2
# 19                  1
# 144                 1
# 104                 1
# 56                  1
# 44                  1
# 38                  1
# 13                  1
# 448                 1
# Name: Semanas_tosse, dtype: int64
#
# Possíveis valores para a feature Expectoração: Sim    2939
# Não    1434
# IGN       7
# 8         1
# Name: Expectoração, dtype: int64
#
# Possíveis valores para a feature Semanas_expectoração: não se aplica     1458
# 2                  583
# 4                  496
# 1                  464
# 8                  285
# 3                  250
# 0                  197
# 12                 168
# 6                   93
# 16                  71
# 24                  64
# ignorado            54
# 5                   53
# 48                  31
# crônico+sempre      28
# 20                  19
# 32                  10
# 40                   8
# 18                   7
# 10                   7
# 52                   5
# 9                    5
# 96                   4
# 7                    4
# 58                   2
# 14                   2
# 13                   1
# 44                   1
# 15                   1
# 50                   1
# 19                   1
# 28                   1
# 72                   1
# 30                   1
# 80                   1
# 36                   1
# 104                  1
# 38                   1
# 333                  1
# Name: Semanas_expectoração, dtype: int64
#
# Possíveis valores para a feature Hemoptóicos: Não    3674
# Sim     677
# IGN      29
# 8         1
# Name: Hemoptóicos, dtype: int64
#
# Possíveis valores para a feature Semanas_hemoptóicos: não se aplica     3682
# 0                  257
# 1                  167
# ignorado            87
# 2                   74
# 4                   47
# 3                   22
# 8                   15
# 12                  10
# 6                    4
# 16                   4
# 24                   2
# 88                   1
# crônico+sempre       1
# 5                    1
# 9                    1
# 52                   1
# 144                  1
# 18                   1
# 32                   1
# 48                   1
# 15                   1
# Name: Semanas_hemoptóicos, dtype: int64
#
# Possíveis valores para a feature Hemoptise: Não    4040
# Sim     305
# IGN      34
# 8         2
# Name: Hemoptise, dtype: int64
#
# Possíveis valores para a feature Semanas_hemoptise: não se aplica    4052
# 1                  99
# 0                  94
# ignorado           58
# 2                  32
# 4                  17
# 8                   9
# 12                  7
# 3                   6
# 6                   3
# 15                  2
# 32                  1
# 16                  1
# Name: Semanas_hemoptise, dtype: int64
#
# Possíveis valores para a feature Quantidade_hemoptise: 888                    2484
# Não se aplica          1453
# < 1 copinho de café     277
# IGN                      79
# > 1 copinho de café      41
# 999                      37
# >= 1 copo de geléia      10
# Name: Quantidade_hemoptise, dtype: int64
#
# Possíveis valores para a feature Sudorese_noturna: Não    3003
# Sim    1361
# 9        17
# Name: Sudorese_noturna, dtype: int64
#
# Possíveis valores para a feature Semanas_sudorese: não se aplica     2998
# 1                  312
# 2                  261
# 4                  198
# 0                  166
# 3                  111
# 8                   90
# ignorado            70
# 12                  56
# 6                   35
# 16                  20
# 5                   15
# 24                  13
# 48                   7
# 20                   6
# 18                   5
# 9                    3
# 88                   3
# 10                   2
# 15                   1
# 14                   1
# 32                   1
# 180                  1
# 19                   1
# 28                   1
# 52                   1
# 96                   1
# crônico+sempre       1
# 36                   1
# Name: Semanas_sudorese, dtype: int64
#
# Possíveis valores para a feature Febre: Não    2641
# Sim    1726
# IGN      14
# Name: Febre, dtype: int64
#
# Possíveis valores para a feature Semanas_febre: não se aplica     2698
# 1                  458
# 2                  323
# 0                  283
# 4                  213
# 3                  121
# 8                   95
# ignorado            54
# 12                  39
# 6                   26
# 16                  18
# 5                   12
# 20                   8
# 24                   8
# 18                   6
# 10                   4
# 88                   4
# crônico+sempre       2
# 9                    2
# 28                   2
# 48                   2
# 15                   1
# 7                    1
# 96                   1
# Name: Semanas_febre, dtype: int64
#
# Possíveis valores para a feature Dispnéia: Sim    2977
# Não    1396
# IGN       7
# 2         1
# Name: Dispnéia, dtype: int64
#
# Possíveis valores para a feature Dispnéia_semanas: não se aplica     1449
# 1                  498
# 2                  474
# 4                  411
# 0                  259
# 8                  256
# 3                  182
# 12                 176
# ignorado           163
# crônico+sempre      93
# 24                  77
# 6                   71
# 16                  67
# 5                   43
# 48                  37
# 20                  31
# 32                  16
# 18                   9
# 40                   9
# 9                    9
# 10                   9
# 80                   6
# 58                   6
# 52                   5
# 28                   4
# 44                   3
# 7                    2
# 14                   2
# 104                  2
# 50                   2
# 156                  1
# 96                   1
# 19                   1
# 56                   1
# 36                   1
# 30                   1
# 78                   1
# 15                   1
# 180                  1
# 38                   1
# Name: Dispnéia_semanas, dtype: int64
#
# Possíveis valores para a feature Perda_de_apetite: IGN    1697
# Não    1490
# Sim    1194
# Name: Perda_de_apetite, dtype: int64
#
# Possíveis valores para a feature Perda_apetite_semanas: ignorado          1739
# não se aplica     1501
# 1                  223
# 2                  220
# 4                  200
# 0                  134
# 8                   93
# 3                   67
# 12                  65
# 6                   33
# 16                  29
# 5                   20
# 24                  17
# 20                  16
# crônico+sempre       7
# 18                   3
# 9                    2
# 10                   2
# 32                   2
# 48                   2
# 80                   1
# 52                   1
# 40                   1
# 7                    1
# 30                   1
# 14                   1
# Name: Perda_apetite_semanas, dtype: int64
#
# Possíveis valores para a feature Perda_peso_10percent: Não    3139
# Sim     962
# IGN     280
# Name: Perda_peso_10percent, dtype: int64
#
# Possíveis valores para a feature Perda_peso_semanas: não se aplica     3201
# ignorado           347
# 4                  156
# 8                  135
# 12                 110
# 16                  59
# 2                   59
# 24                  56
# 3                   43
# 1                   41
# 6                   38
# 48                  30
# 20                  23
# 40                  13
# 0                    9
# 32                   9
# 5                    7
# 10                   7
# 9                    7
# crônico+sempre       4
# 18                   4
# 36                   3
# 52                   3
# 28                   3
# 17                   2
# 104                  2
# 96                   1
# 38                   1
# 29                   1
# 15                   1
# 44                   1
# 19                   1
# 30                   1
# 8888                 1
# 25                   1
# 90                   1
# Name: Perda_peso_semanas, dtype: int64
#
# Possíveis valores para a feature Dor_torácica: Sim    2924
# Não    1447
# IGN      10
# Name: Dor_torácica, dtype: int64
#
# Possíveis valores para a feature Dor_torácica_semanas: não se aplica     1470
# 2                  535
# 1                  498
# 4                  433
# 0                  303
# 8                  257
# 3                  204
# 12                 166
# ignorado           145
# 6                   79
# 16                  62
# 24                  60
# 5                   37
# 20                  31
# 48                  26
# crônico+sempre      23
# 40                   7
# 18                   6
# 52                   6
# 32                   6
# 10                   4
# 9                    3
# 58                   3
# 7                    2
# 28                   2
# 80                   2
# 104                  2
# 14                   2
# 19                   1
# 180                  1
# 15                   1
# 50                   1
# 56                   1
# 96                   1
# 44                   1
# Name: Dor_torácica_semanas, dtype: int64
#
# Possíveis valores para a feature Internação_hospital_2anos: Não    3714
# Sim     630
# IGN      37
# Name: Internação_hospital_2anos, dtype: int64
#
# Possíveis valores para a feature Prisão_2anos: Não    4248
# Sim      89
# IGN      44
# Name: Prisão_2anos, dtype: int64
#
# Possíveis valores para a feature Delegacia_2anos: Não    4251
# Sim      85
# IGN      45
# Name: Delegacia_2anos, dtype: int64
#
# Possíveis valores para a feature Contato_TBP_2anos: Não    3212
# Sim    1113
# IGN      56
# Name: Contato_TBP_2anos, dtype: int64
#
# Possíveis valores para a feature TBP_Morava_com_vc: não se aplica    2014
# Não              1800
# Sim               497
# IGN                70
# Name: TBP_Morava_com_vc, dtype: int64
#
# Possíveis valores para a feature TBP_trabalhava_com_vc: Não              2193
# não se aplica    2015
# Sim               100
# IGN                73
# Name: TBP_trabalhava_com_vc, dtype: int64
#
# Possíveis valores para a feature TBP_amigo_parente_não_morava_com_vc: não se aplica    2015
# Não              1715
# Sim               580
# IGN                71
# Name: TBP_amigo_parente_não_morava_com_vc, dtype: int64
#
# Possíveis valores para a feature Contato_TBP_menor_3anos: não se aplica    2015
# Não              1483
# Sim               799
# IGN                84
# Name: Contato_TBP_menor_3anos, dtype: int64
#
# Possíveis valores para a feature Contato_TBP_Casa: não se aplica    2015
# Não              1740
# Sim               547
# IGN                79
# Name: Contato_TBP_Casa, dtype: int64
#
# Possíveis valores para a feature Contato_TBP_Trabalho: Não              2177
# não se aplica    2015
# Sim               110
# IGN                79
# Name: Contato_TBP_Trabalho, dtype: int64
#
# Possíveis valores para a feature Contato_TBP_Social: não se aplica    2015
# Não              1853
# Sim               439
# IGN                74
# Name: Contato_TBP_Social, dtype: int64
#
# Possíveis valores para a feature Fuma: Jamais fumante    1829
# Fumante           1323
# Ex-fumante        1194
# IGN                 35
# Name: Fuma, dtype: int64
#
# Possíveis valores para a feature Número_cigarros_dia: não se aplica    1105
# 20                822
# ignorado          805
# 40                343
# 10                303
# 30                124
# 5                 122
# 15                105
# 60                100
# 3                 100
# 2                  84
# 4                  73
# 1                  66
# 6                  57
# 7                  40
# 8                  37
# 12                 21
# 50                 16
# 18                 13
# 25                 11
# 80                  9
# 13                  4
# 9                   4
# 35                  4
# 16                  3
# 100                 2
# 14                  1
# 120                 1
# 21                  1
# 44                  1
# 45                  1
# 55                  1
# 99                  1
# 0                   1
# Name: Número_cigarros_dia, dtype: int64
#
# Possíveis valores para a feature Número_anos: não se aplica    1105
# ignorado          815
# 30                223
# 20                216
# 40                174
# 10                148
# 15                 98
# 1                  89
# 50                 88
# 25                 82
# 35                 74
# 5                  68
# 4                  61
# 2                  60
# 3                  53
# 6                  46
# 8                  40
# 45                 38
# 12                 38
# 18                 34
# 32                 34
# 13                 31
# 14                 30
# 60                 28
# 16                 28
# 42                 28
# 33                 28
# 36                 27
# 23                 27
# 22                 27
#                  ...
# 9                  13
# 0                  13
# 52                 13
# 47                 12
# 44                 11
# 53                 11
# 54                 11
# 41                 10
# 39                  9
# 46                  9
# 58                  8
# 56                  7
# 51                  6
# 57                  6
# 59                  6
# 70                  6
# 65                  3
# 64                  2
# 66                  2
# 62                  2
# 68                  1
# 71                  1
# 72                  1
# 73                  1
# 74                  1
# 75                  1
# 67                  1
# 85                  1
# 0.6                 1
# 1.3                 1
# Name: Número_anos, dtype: int64
#
# Possíveis valores para a feature Cerveja: Não    2378
# Sim    1973
# IGN      30
# Name: Cerveja, dtype: int64
#
# Possíveis valores para a feature Vinho: Não    3616
# Sim     733
# IGN      30
# 10        2
# Name: Vinho, dtype: int64
#
# Possíveis valores para a feature Whisky: Não    4280
# Sim      69
# IGN      32
# Name: Whisky, dtype: int64
#
# Possíveis valores para a feature Cachaça: Não    4015
# Sim     336
# IGN      30
# Name: Cachaça, dtype: int64
#
# Possíveis valores para a feature Outras_bebidas_alcoólicas: Não    4078
# Sim     273
# IGN      30
# Name: Outras_bebidas_alcoólicas, dtype: int64
#
# Possíveis valores para a feature Nenhuma_bebida_alcoólica: Não    2256
# Sim    2095
# IGN      30
# Name: Nenhuma_bebida_alcoólica, dtype: int64
#
# Possíveis valores para a feature CAGE: Negativo    3481
# Positivo     888
# IGN           12
# Name: CAGE, dtype: int64
#
# Possíveis valores para a feature Etilismo: IGN    2290
# 8      1808
# Sim     196
# Não      87
# Name: Etilismo, dtype: int64
#
# Possíveis valores para a feature Hepatopatia: ignorado    4102
# Não          278
# Sim            1
# Name: Hepatopatia, dtype: int64
#
# Possíveis valores para a feature Uso_corticoide: ignorado    4103
# Não          277
# Sim            1
# Name: Uso_corticoide, dtype: int64
#
# Possíveis valores para a feature Neo_maligna: ignorado    4102
# Não          277
# Sim            2
# Name: Neo_maligna, dtype: int64
