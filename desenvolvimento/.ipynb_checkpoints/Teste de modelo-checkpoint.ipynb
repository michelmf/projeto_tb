# %% [markdown]
# # Análise Exploratória de Dados
#
# Análise inicial dos dados presentes na base de dados de tuberculose.

# %%
# Módulos para análise dos dados
import numpy  as np
import pandas as pd

# Visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importação dos dados da base de triagem de pacientes com tuberculose
data = pd.read_excel('../dados/Banco de Dados.xlsx')

# %% [markdown]
# # Verificação inicial dos dados

# %%
# Visualização dos dados
data.head(5)
# Out:
#    ID  TB_desfecho_final_Dri  Tbafranio Obs_desfechoTB_Dri_Dani Data_inclusão  \
# 0   1                      1          1                     NaN    2008-04-03
# 1   2                      1          1                     NaN    2006-10-03
# 2   3                      1          1                     NaN    2007-06-21
# 3   4                      1          1                     NaN    2009-09-30
# 4   5                      1          1                     NaN    2009-06-19
#
#    Nome  Desfecho_tuberculose_lista_Mauro  Desfecho_TB_162_Revisão_ADRIANA  \
# 0   NaN                                 9                              1.0
# 1   NaN                                 1                              1.0
# 2   NaN                                 1                              1.0
# 3   NaN                                 1                              1.0
# 4   NaN                                 1                              NaN
#
# ...

# %% [markdown]
# ### Dúvidas sobre os valores da base de dados
#
# Algumas variáveis presentes representam se o paciente tem TB+ ou não. Qual a correta? Todas as variáveis concordam ?
#
# Variáveis que indicam a presença de TB:
#
# | Variável | Valor para TB+ | Valor para TB- |    Ignorados   |    Outros      |
# | -------- |:--------------:|:--------------:|:--------------:|:--------------:|
#
#
#
#
#
# - TB_desfecho_final_Dri            : 1 -> TB+ ; 2 -> TB- ; 9 -> Ignorado
# - Tbafranio                        : 0 -> TB- ; 1 -> TB+
# - Desfecho_tuberculose_lista_Mauro : 0 -> TB- ; 1 -> TB+ ; 2 -> Paciente não encontrado na lista do Mauro (?)
# - Desfecho_TB_162_Revisão_ADRIANA  : 0 -> TB- ; 1 -> TB+ ; 2 -> Paciente não encontrado
# -

# %% [markdown]
# ### Labels de outras variáveis
#
# - Asma : 1 = Sim, 2 = Não

# %%
print('Informações gerais sobre a base de dados:\n')

# Tamanho da base de dados
print('-> Quantidade de pacientes presentes na base de dados: {}'.format(len(data)))

# Quantidade de pacientes com TB+ e TB-
print('-> Quantidade de pacientes com TB+: {}\n-> Quantidade de pacientes com TB-: {}'.format(1,1))

# Proporcão da base
print('-> Proporção de pacientes TB+ e TB-: {}% de casos TB+ e {}% de casos TB-'.format(1,1))

# Quantidade de features presentes
print('-> Quantidade de atributos presentes: {}\n'.format(len(data.columns)))
# Out:
# Informações gerais sobre a base de dados:
#
# -> Quantidade de pacientes presentes na base de dados: 4381
# -> Quantidade de pacientes com TB+: 1
# -> Quantidade de pacientes com TB-: 1
# -> Proporção de pacientes TB+ e TB-: 1% de casos TB+ e 1% de casos TB-
# -> Quantidade de atributos presentes: 283
